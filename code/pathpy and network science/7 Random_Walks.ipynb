# %% [markdown]
# # P09-01: Random Walks
#
# *June 18 2020*
#
# In the first unit we explore random walks, a simple yet powerful stochastic model for diffusion processes in networks. Random walk processes are not only important as a model for diffusion. Their stationary distribution can also be used to define centrality measures based on the eigenvectors of the transition matrix. Studying both the stationary state as well as the speed of diffusion processes:

# %%
import pathpy as pp
import numpy as np
from tqdm.auto import tqdm

import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use('default')
sns.set_style("whitegrid")
    
from numpy import linalg as npl
import scipy as sp
# Out:
#     <script charset="utf-8">
#     // Load via requireJS if available (jupyter notebook environment)
#     try {
#     require.config({
#     paths: {
#     d3: "https://d3js.org/d3.v5.min.js".replace(".js", "")
#     }
#     });
#     console.log("OKAY: requireJS was detected");
#     }
#     catch(err){
#     console.log(err);
#     console.log("ERROR: NO requireJS was detected");
#     };
#     require(['d3'], function(d3){
#     console.log("OKAY: d3js was detected");
#     });
#     </script>

# %%
n = pp.Network(directed=True)
n.add_edge('a', 'b', weight=2)
n.add_edge('a', 'c', weight=1)
n.add_edge('b', 'c', weight=1)
n.add_edge('b', 'a', weight=2)
n.add_edge('c', 'a', weight=5)
n.plot()
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="xec8d84ac5c394582a338b869986d4018"></div>
# <div id="x1369f02577d143a2bdba404fc71c9732"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#     var config = {"width": 800.0, "height": 550.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": false, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "forceCharge": -10, "forceRepel": -300, "forceAlpha": 0.1, "chargeDistance": 200, "repelDistance": 200, "velocityDecay": 0.2, "alphaMin": 0.1, "lookoutStrokeWidth": 1, "lookoutOpacity": 0.5, "lookoutWeight": 0.0, "radiusMinSize": 4, "radiusMaxSize": 16, "nodeTransitionDuration": 100, "defaultEdgeWeight": 1, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "label_centered": true, "label_enabled": true, "label_color": "white", "curved": true, "directed": true, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#    var data = {"nodes": [{"uid": "a", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "b", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "c", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}], "links": [{"uid": "0x22957039580", "size": 2.0, "color": "black", "opacity": 1, "source": "a", "target": "b", "directed": true, "curved": 0.5}, {"uid": "0x22957039760", "size": 2.0, "color": "black", "opacity": 1, "source": "a", "target": "c", "directed": true, "curved": 0.5}, {"uid": "0x229570398b0", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "c", "directed": true, "curved": 0.5}, {"uid": "0x229570399a0", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "a", "directed": true, "curved": 0.5}, {"uid": "0x22957039a60", "size": 2.0, "color": "black", "opacity": 1, "source": "c", "target": "a", "directed": true, "curved": 0.5}]}
#
#    function tooltip(tooltipId, width){
#      // Local variable to hold tooltip div for
#      // manipulation in other functions.
#      var tt = d3.select('body')
#                 .append('div')
#                 .attr('class', 'tooltip')
#                 .attr('id', tooltipId)
#                 .style('pointer-events', 'none');
#
#      // Set a width if it is provided.
#      if (width) {
#        tt.style('width', width);
#      }
#
#      // Initially it is hidden.
#      hideTooltip();
#
#      /*
#       * Display tooltip with provided content.
#       * content is expected to be HTML string.
#       * event is d3.event for positioning.
#       */
#      function showTooltip(content, event) {
#        tt.style('opacity', 1.0)
#          .html(content);
#
#        updatePosition(event);
#      }
#
#      /*
#       * Hide the tooltip div.
#       */
#      function hideTooltip() {
#        tt.style('opacity', 0.0);
#      }
#
#      /*
#       * Figure out where to place the tooltip
#       * based on d3 mouse event.
#       */
#      function updatePosition(event) {
#        var xOffset = 20;
#        var yOffset = 10;
#
#        var ttw = tt.style('width');
#        var tth = tt.style('height');
#
#        var wscrY = window.scrollY;
#        var wscrX = window.scrollX;
#
#        var curX = (document.all) ? event.clientX + wscrX : event.pageX;
#        var curY = (document.all) ? event.clientY + wscrY : event.pageY;
#        var ttleft = ((curX - wscrX + xOffset * 2 + ttw) > window.innerWidth) ?
#                     curX - ttw - xOffset * 2 : curX + xOffset;
#
#        if (ttleft < wscrX + xOffset) {
#          ttleft = wscrX + xOffset;
#        }
#
#        var tttop = ((curY - wscrY + yOffset * 2 + tth) > window.innerHeight) ?
#                    curY - tth - yOffset * 2 : curY + yOffset;
#
#        if (tttop < wscrY + yOffset) {
#          tttop = curY + yOffset;
#        }
#
#        tt
#          .style('top', tttop + 'px')
#          .style('left', ttleft + 'px');
#      }
#
#      if (config.w

# %% [markdown]
# ## Transition matrices
#
#
# `pathpy` provides a function that computes a (row- or right-stochastic) transition matrix of a random walk process for a given network. The method should work for weighted, unweighted, directed, and undirected networks represented by a `pathpy.Network` object.

# %%
pp.algorithms.transition_matrix(n, weight = "weight").todense()
# Out:
# matrix([[0.        , 0.66666667, 0.33333333],
#         [0.66666667, 0.        , 0.33333333],
#         [1.        , 0.        , 0.        ]])

# %% [markdown]
# Write a function that computes the visitation probability $\pi^{(t)}$ of a random walk after $t$ steps, based on a given initial distribution $\pi^{(0)}$ and a given network topology. You can use built-in `numpy` functions for matrix powers and matrix multiplication. For matrix multiplication, you should have a look at the `dot` function in `numpy`. For the calculation of matrix powers, you should look into the package `numpy.linalg`.

# %%
def visitation_probabilities(network, initial_dist, t):
    T = pp.algorithms.transition_matrix(network, weight="weight").todense()
    p_t = np.dot(initial_dist, npl.matrix_power(T,t))
    return p_t

# %%
print("zeroth step: {}".format(visitation_probabilities(n, np.array([1, 0, 0]), 0)))
print("zerotfirst step: {}".format(visitation_probabilities(n, np.array([1, 0, 0]), 1)))
print("five hundreth step: {}".format(visitation_probabilities(n, np.array([1, 0, 0]), 500)))
# Out:
# zeroth step: [[1. 0. 0.]]
# zerotfirst step: [[0.         0.66666667 0.33333333]]
# five hundreth step: [[0.45 0.3  0.25]]

# %% [markdown]
# We can compute the stationary distribution of the random walk:

# %%
def stationary_distribution(network):
    T =  pp.algorithms.transition_matrix(network).todense()
    eigenvalues, eigenvectors = sp.linalg.eig(T, left=True, right=False)
    # Here we take the **leading eigenvector**, i.e. the eigenvector
    # corresponding to the **largest eigenvalue** of one
    # numpy.argsort returns an array of indices that would sort an array
    # note the multi-dimensional slicing :,x, which returns all entries 
    # in column x
    pi = eigenvectors[:,np.argsort(-eigenvalues)][:,0]

    # We make sure that the eigenvector is normalised
    pi = pi/sum(pi)
    return pi

# %%
stationary_distribution(n)
# Out:
# array([0.44444444-0.j, 0.22222222-0.j, 0.33333333-0.j])

# %% [markdown]
# Generate a connected, undirected example network with $10$ nodes and $15$ links and test your function by computing the visitation probabilities after $t=10$ and $t=100$ steps for different initial distributions.
#
# Do the visitation probabilities converge to a stationary distribution? How do the visitation probabilities after $100$ steps differ across different initial distributions?

# %%
er_net = pp.generators.random_graphs.ER_nm(n = 10, m = 15)

pp.algorithms.components.largest_connected_component(er_net)
n = er_net.number_of_nodes()

for i in range(n):
    initial_dist = [0]*n
    initial_dist[i] = 1
    pi = visitation_probabilities(er_net, initial_dist, 10)
    print("visitation probabilities after 10 steps = \n", pi)
    pi = visitation_probabilities(er_net, initial_dist, 500)
    print("visitation probabilities after 500 steps = \n", pi)
    print()
# Out:
# visitation probabilities after 10 steps =
#  [[0.10218747 0.09471402 0.23840708 0.03634786 0.12006207 0.01916492
#   0.05537899 0.09647042 0.04340433 0.19386283]]
# visitation probabilities after 500 steps =
#  [[0.06666667 0.1        0.16666667 0.06666667 0.13333333 0.03333333
#   0.06666667 0.13333333 0.06666667 0.16666667]]
#
# visitation probabilities after 10 steps =
#  [[0.06314268 0.10562108 0.16326488 0.0627753  0.13369117 0.03163573
#   0.06949405 0.13172295 0.06610541 0.17254677]]
# visitation probabilities after 500 steps =
#  [[0.06666667 0.1        0.16666667 0.06666667 0.13333333 0.03333333
#   0.06666667 0.13333333 0.06666667 0.16666667]]
#
# visitation probabilities after 10 steps =
#  [[0.09536283 0.09795893 0.22755278 0.0396886  0.12114951 0.02052368
#   0.05735529 0.10170143 0.04624324 0.19246372]]
# visitation probabilities after 500 steps =
#  [[0.06666667 0.1        0.16666667 0.06666667 0.13333333 0.03333333
#   0.06666667 0.13333333 0.06666667 0.16666667]]
#
# visitation probabilities after 10 steps =
#  [[0.03634786 0.09416295 0.09922149 0.1087616  0.14435282 0.05209229
#   0.07053756 0.17757741 0.09204857 0.12489745]]
# visitation probabilities after 500 steps =
#  [[0.06666667 0.1        0.16666667 0.06666667 0.13333333 0.03333333
#   0.06666667 0.13333333 0.06666667 0.16666667]]
#
# visitation probabilities after 10 steps =
#  [[0.06003104 0.10026837 0.15143688 0.07217641 0.13741606 0.03629327
#   0.06995129 0.13993304 0.07176659 0.16072705]]
# visitation probabilities after 500 steps =
#  [[0.06666667 0.1        0.16666667 0.06666667 0.13333333 0.03333333
#   0.06666667 0.13333333 0.06666667 0.16666667]]
#
# visitation probabilities after 10 steps =
#  [[0.03832984 0.09490718 0.1026184  0.10418458 0.14517306 0.0505786
#   0.0718922  0.17308216 0.09063617 0.12859781]]
# visitation probabilities after 500 steps =
#  [[0.06666667 0.1        0.16666667 0.06666667 0.13333333 0.03333333
#   0.06666667 0.13333333 0.06666667 0.16666667]]
#
# visitation probabilities after 10 steps =
#  [[0.05537899 0.10424107 0.14338822 0.07053756 0.13990258 0.0359461
#   0.07392463 0.1403005  0.07319729 0.16318305]]
# visitation probabilities after 500 steps =
#  [[0.06666667 0.1        0.16666667 0.06666667 0.13333333 0.03333333
#   0.06666667 0.13333333 0.06666667 0.16666667]]
#
# visitation probabilities after 10 steps =
#  [[0.04823521 0.09879221 0.12712678 0.0887887  0.13993304 0.04327054
#   0.07015025 0.15754906 0.0808594  0.14529481]]
# visitation probabilities after 500 steps =
#  [[0.06666667 0.1        0.16666667 0.06666667 0.13333333 0.03333333
#   0.06666667 0.13333333 0.06666667 0.16666667]]
#
# visitation probabilities after 10 steps =
#  [[0.04340433 0.09915811 0.11560811 0.09204857 0.14353318 0.04531808
#   0.07319729 0.16171879 0.08470577 0.14130776]]
# visitation probabilities after 500 steps =
#  [[0.06666667 0.1        0.16666667 0.06666667 0.13333333 0.03333333
#   0.06666667 0.13333333 0.06666667 0.16666667]]
#
# visitation probabilities after 10 steps =
#  [[0.07754513 0.10352806 0.19246372 0.04995898 0.12858164 0.02571956
#   0.06527322 0.11623585 0.0565231  0.18417074]]
# visitation probabilities after 500 steps =
#  [[0.06666667 0.1        0.16666667 0.06666667 0.13333333 0.03333333
#   0.06666667 0.13333333 0.06666667 0.16666667]]

# %% [markdown]
# ## Random walks in `pathpy`
#
# `pathpy` offers direct support for the simulation of random walk processes in a network, as well as for the calculation of transition matrices, stationary states and total variation distance. To initialise a new random walk process in a given network, we can write:

# %%
n = pp.Network(directed=True)
n.add_edge('a', 'b', weight=2)
n.add_edge('a', 'c', weight=1)
n.add_edge('b', 'c', weight=1)
n.add_edge('b', 'a', weight=2)
n.add_edge('c', 'a', weight=5)
# n.plot()

# %%
rw = pp.processes.RandomWalk(n, start_node='a', weight=True)
# Out:
# c:\users\vince\anaconda3\envs\devenv\lib\site-packages\scipy\sparse\_index.py:84: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])

# %% [markdown]
# If we omit the parameter `start_node` the initial node will be chosen uniformly at random among all nodes in the network. At any point, we can print the current time (i.e. number of steps taken so far), the current steps, and the current visitation probabilities as follows:

# %%
print(rw.t)
# Out:
# 0

# %%
print(rw.state)
# Out:
# a

# %%
print(rw.visitation_frequencies())
# Out:
# [1. 0. 0.]

# %%
print(rw.total_variation_distance)
# Out:
# 0.5499999999999998

# %% [markdown]
# Calling the function `transition` makes a single transition, which updates the time, state, and visitation frequencies of the random walk. The transition method returns the node that is visited:

# %%
x = rw.transition()
print('Random walker is in node =', rw.state)
print('Current time =', rw.t)
print('Current visitation_frequencies =', rw.visitation_frequencies())
# Out:
# Random walker is in node = c
# Current time = 1
# Current visitation_frequencies = [0.5 0.  0.5]

# %%
print(rw.stationary_probabilities())
# Out:
# [0.45 0.3  0.25]

# %%
rw.total_variation_distance
# Out:
# 0.29999999999999993

# %%
print(rw.visitation_probabilities(t=1, start_node='a'))
# Out:
# [[0.         0.66666667 0.33333333]]

# %%
for v in rw.walk(10000):
    pass
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 10000/10000 [00:02<00:00, 4266.60it/s]

# %%
print(rw.visitation_frequencies())
# Out:
# [0.45240952 0.30183963 0.24575085]

# %%
rw.total_variation_distance
# Out:
# 0.004249150169965951

# %% [markdown]
# # P09-02: Diffusion Speed in Networks
#
# *June 18 2020*
#
# In the second unit we study the speed of diffusion in different network topologies. We use experiments to test the analytical predictions that we developed in the theory lecture.

# %% [markdown]
# ### Total Variation Distance
#
# To calculate diffusion speed, we first write a function that computes the total variation distance between two stochastic vectors $\pi$ and $\pi'$.

# %%
def tvd(p1, p2):
    assert len(p1) == len(p2)
    tvd = 0
    for i in range(len(p1)):
        tvd +=abs(p1[i] - p2[i])
    return tvd/2

# %% [markdown]
# The following helper function returns the total variation distances between the stationary distribution $\pi$ and the visitation probability $\pi^s$ for $s=0, \ldots, t$ steps of a random walk process.

# %%
def compute_tvd(network, t, epsilon=0.005):

    t_min = np.inf
    
    T = pp.processes.RandomWalk.transition_matrix(network).todense()
    
    # We use a **right-stochastic matrix**, so what we want to
    # compute is the **left** eigenvectors (see lecture L08)
    eigenvalues, eigenvectors = sp.linalg.eig(T, left=True, right=False)
    
    # Here we take the **leading eigenvector**, i.e. the eigenvector
    # corresponding to the **largest eigenvalue** of one
    # numpy.argsort returns an array of indices that would sort an array
    # note the multi-dimensional slicing :,x, which returns all entries 
    # in column x
    pi = eigenvectors[:,np.argsort(-eigenvalues)][:,0]
    
    # We make sure that the eigenvector is normalised
    pi = pi/sum(pi)

    # We set the initial distribution
    initial_dist = np.array([0]*network.number_of_nodes())
    initial_dist[0] = 1

    # We calculate the total variation dist after each step
    tvds = []
    for s in range(t):
        x = np.ravel(np.dot(initial_dist, np.linalg.matrix_power(T, s)))
        d = tvd(pi,x)
        if d <= epsilon and t_min > s:
            t_min = s
        tvds.append(d)
    return tvds, t_min

# %% [markdown]
# We use the function above to calculate and plot the evolution of the total variation distance for the undirected example network shown in lecture 08.

# %%
n = pp.Network(directed=False)
n.add_edge('a', 'b')
n.add_edge('b', 'c')
n.add_edge('a', 'c')
n.add_edge('b', 'd')
n.add_edge('d', 'f')
n.add_edge('d', 'g')
n.add_edge('d', 'e')
n.add_edge('e', 'f')
n.add_edge('f', 'g')
n.plot()

d, tmin = compute_tvd(n, 100, epsilon=0.05)
plt.plot(np.arange(100), d)
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x3b76abdb98b942a494c8243d57fa55a9"></div>
# <div id="xfc3ec8d377fb4088bc3b6227f3f0b85c"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#     var config = {"width": 800.0, "height": 550.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": false, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "forceCharge": -10, "forceRepel": -300, "forceAlpha": 0.1, "chargeDistance": 200, "repelDistance": 200, "velocityDecay": 0.2, "alphaMin": 0.1, "lookoutStrokeWidth": 1, "lookoutOpacity": 0.5, "lookoutWeight": 0.0, "radiusMinSize": 4, "radiusMaxSize": 16, "nodeTransitionDuration": 100, "defaultEdgeWeight": 1, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "label_centered": true, "label_enabled": true, "label_color": "white", "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#    var data = {"nodes": [{"uid": "a", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "b", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "c", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "d", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "f", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "g", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "e", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}], "links": [{"uid": "0x229572e77f0", "size": 2.0, "color": "black", "opacity": 1, "source": "a", "target": "b", "directed": false, "curved": 0.5}, {"uid": "0x229572e7df0", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "c", "directed": false, "curved": 0.5}, {"uid": "0x229572e7bb0", "size": 2.0, "color": "black", "opacity": 1, "source": "a", "target": "c", "directed": false, "curved": 0.5}, {"uid": "0x229572e7a60", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "d", "directed": false, "curved": 0.5}, {"uid": "0x229572e7970", "size": 2.0, "color": "black", "opacity": 1, "source": "d", "target": "f", "directed": false, "curved": 0.5}, {"uid": "0x229572d8fd0", "size": 2.0, "color": "black", "opacity": 1, "source": "d", "target": "g", "directed": false, "curved": 0.5}, {"uid": "0x229572d8fa0", "size": 2.0, "color": "black", "opacity": 1, "source": "d", "target": "e", "directed": false, "curved": 0.5}, {"uid": "0x229572d8040", "size": 2.0, "color": "black", "opacity": 1, "source": "e", "target": "f", "directed": false, "curved": 0.5}, {"uid": "0x229572d83a0", "size": 2.0, "color": "black", "opacity": 1, "source": "f", "target": "g", "directed": false, "curved": 0.5}]}
#
#    function tooltip(tooltipId, width){
#      // Local variable to hold tooltip div for
#      // manipulation in other functions.
#      var tt = d3.select('body')
#                 .append('div')
#                 .attr('class', 'tooltip')
#                 .attr('id', tooltipId)
#                 .style('pointer-events', 'none');
#
#      // Set a width if it is provided.
#      if (width) {
#        tt.style('width', width);
#      }
#
#      // Initially it is hidden.
#      hideTooltip();
#
#      /*
#       * Display tooltip with provided content.
#       * content is expected to be HTML string.
#       * event is d3.event for positioning.
#       */
#      function showTooltip(content, event) {
#        tt.style('opacity', 1.0)
#          .html(content);
#
#        updatePosition(event);
#      }
#
#      /*
#       * Hide the tooltip div.
#       */
#      function hideTooltip() {
#        tt.style('opacity', 0.0);
#      }
#
#      /*
#       * Figure out where to place the tooltip
#       * based on d3 mouse event.
#       */
#      function updatePosit
# c:\users\vince\anaconda3\envs\devenv\lib\site-packages\scipy\sparse\_index.py:84: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])

# %%
print('t_min =', tmin)
# Out:
# t_min = 14

# %%
def lambda_2(network):
    T = pp.processes.RandomWalk.transition_matrix(network).todense()
    eigenvalues, eigenvectors = sp.linalg.eig(T, left=True, right=False)
    x = eigenvalues[np.argsort(-eigenvalues)]
    return np.abs(x[1])

# %%
print('prediction =', np.log(0.05)/np.log(lambda_2(n)))
# Out:
# prediction = 15.780738151107203
# c:\users\vince\anaconda3\envs\devenv\lib\site-packages\scipy\sparse\_index.py:84: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])

# %% [markdown]
# ## Network Topology and Diffusion Speed
#
# Using code from previous exercises or corresponding `pathpy` functions, we now generate six different types of random networks:
#
#    1. an Erdös-Renyi network with $n=200$ nodes and $m=400$ links
#    2. an Erdös-Renyi network with $n=200$ nodes and $m=600$ links
#    3. a modular network consisting of two $5$-regular random networks with $100$ nodes each, which are joined together by crossing the endpoints of two arbitrary chosen links
#    4. a scale-free network with $200$ nodes and exponent $\gamma=2.7$
#    5. a Watts-Strogatz ring lattice with the parameters $n=200$, $m=5$ and rewiring probability $p=0$
#    6. a Watts-Strogatz small-world network with the parameters $n=200$, $m=5$ and rewiring probability $p=0.05$
#
# For each of the six networks we use the function from above to compute the evolution of total variation distance $\delta(\pi^{(t)}, \pi)$ for $t \in \left[0, 500\right]$ where $\pi$ is the stationary distribution.
#
# ### Experiment 1: Erdös-Renyi network with 200 nodes and 400 links

# %%
er_1 = pp.generators.random_graphs.ER_nm(n=100, m=200)
er_1 = pp.algorithms.components.largest_connected_component(er_1)

d, tmin = compute_tvd(er_1, 500)

plt.clf()
plt.grid()
plt.loglog(np.arange(500), d)
plt.xlabel("t")
plt.ylabel(r"$\delta$")
plt.show()
# Out:
# c:\users\vince\anaconda3\envs\devenv\lib\site-packages\scipy\sparse\_index.py:84: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])

# %%
print('t_min =', tmin)
print('prediction =', np.abs(np.log(0.005)/np.log(lambda_2(er_1))))
# Out:
# t_min = 33
# c:\users\vince\anaconda3\envs\devenv\lib\site-packages\scipy\sparse\_index.py:84: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])
# prediction = 31.63458082316748

# %% [markdown]
# ### Experiment 2: Erdös-Renyi network with 100 nodes and 300 links

# %%
er_2 = pp.generators.random_graphs.ER_nm(n=100, m=300)
er_2 = pp.algorithms.components.largest_connected_component(er_2)

d, tmin = compute_tvd(er_2, 500)

plt.clf()
plt.grid()
plt.loglog(np.arange(500), d)
plt.show()
# Out:
# c:\users\vince\anaconda3\envs\devenv\lib\site-packages\scipy\sparse\_index.py:84: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])

# %%
print('t_min =', tmin)
print('prediction =', np.abs(np.log(0.005)/np.log(lambda_2(er_2))))
# Out:
# t_min = 16
# c:\users\vince\anaconda3\envs\devenv\lib\site-packages\scipy\sparse\_index.py:84: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])
# prediction = 16.752921253736698

# %% [markdown]
# ### Experiment 3: Modular network consisting of two 5-regular random networks with a total of 100 nodes

# %%
regular_1 = pp.generators.random_graphs.Molloy_Reed([5]*50, node_uids=[str(i) for i in range(50)])
regular_2 = pp.generators.random_graphs.Molloy_Reed([5]*50, node_uids=[str(i) for i in range(50,100)])
modular = regular_1 + regular_2

e1 = list(modular.edges)[1]
e2 = list(modular.edges)[200] 

modular.remove_edge(e1.v, e1.w)
modular.remove_edge(e2.v, e2.w)
modular.add_edge(e1.v, e2.w)
modular.add_edge(e2.v, e1.w)

d, tmin = compute_tvd(modular, 500)

plt.clf()
plt.grid()
plt.loglog(range(500), d)
plt.show()
# Out:
# c:\users\vince\anaconda3\envs\devenv\lib\site-packages\scipy\sparse\_index.py:84: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])

# %%
print('t_min =', tmin)
print('prediction =', np.abs(np.log(0.005)/np.log(lambda_2(modular))))
# Out:
# t_min = 419
# c:\users\vince\anaconda3\envs\devenv\lib\site-packages\scipy\sparse\_index.py:84: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])
# prediction = 534.4147052077856

# %% [markdown]
# ### Experiment 5: A Watts-Strogatz ring lattice with n=100, m=5 and p=0.

# %%
ring = pp.generators.random_graphs.Watts_Strogatz(n = 100, s = 5, p = 0)

d, tmin = compute_tvd(ring, 500)

plt.clf()
plt.grid()
plt.loglog(range(500), d)
plt.show()
# Out:
# c:\users\vince\anaconda3\envs\devenv\lib\site-packages\scipy\sparse\_index.py:84: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])

# %%
print('t_min =', tmin)
print('prediction =', np.abs(np.log(0.005)/np.log(lambda_2(ring))))
# Out:
# t_min = 223
# c:\users\vince\anaconda3\envs\devenv\lib\site-packages\scipy\sparse\_index.py:84: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])
# prediction = 242.78903135743565

# %% [markdown]
# ### Network 6: A Watts-Strogatz small-world network with n = 200, m=5 and p = 0.05

# %%
ws = pp.generators.random_graphs.Watts_Strogatz(n = 100, s = 5, p = 0.05)

d, tmin = compute_tvd(ws, 500)

plt.clf()
plt.grid()
plt.loglog(range(500), d)
plt.show()
# Out:
# c:\users\vince\anaconda3\envs\devenv\lib\site-packages\scipy\sparse\_index.py:84: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])

# %%
print('t_min =', tmin)
print('prediction =', np.abs(np.log(0.005)/np.log(lambda_2(ws))))
# Out:
# t_min = 62
# c:\users\vince\anaconda3\envs\devenv\lib\site-packages\scipy\sparse\_index.py:84: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])
# prediction = 85.48354569143112

# %% [markdown]
# ### Interpretation of results  TO BE MODIFIED!!!
#
# We make the following observations:
#
# 1. In a random network, the network with more links (quite expectedly) leads to faster diffusion than the network with fewer links. Moreover, the random network with 600 links gives rise to the **fastest diffusion**, across the studied network topologies.
# 2. In the network with 200 nodes and two modules, diffusion is orders of magnitude (!) slower than in a random network.
# 3. In the network with two modules, we see an interesting plateau in the evolution of the total variation distance, which is related to the presence of the two communities.
# 4. In the scale-free network, diffusion is omuch slower than in random Erdös-Rényi networks.
# 5. In the ring topology ($p=0$), **diffusion is the slowest (comparable to the modular network)**.
# 6. Randomly rewiring $5 \%$ of the links increases diffusion speed by a factor of ten.
