# %% [markdown]
# # P09-01: Random Walks
#
# *June 18 2020*
#
# In the first unit we explore random walks, a simple yet powerful stochastic model for diffusion processes in networks. Random walk processes are not only important as a model for diffusion. Their stationary distribution can also be used to define centrality measures based on the eigenvectors of the transition matrix. Studying both the stationary state as well as the speed of diffusion processes:

# %%
import pathpy as pp
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use('default')
sns.set_style("whitegrid")
    
from numpy import linalg as npl
import scipy as sp

# %%
n = pp.Network(directed=True)
n.add_edge('a', 'b', weight=2)
n.add_edge('a', 'c', weight=1)
n.add_edge('b', 'c', weight=1)
n.add_edge('b', 'a', weight=2)
n.add_edge('c', 'a', weight=5)
n.plot()
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="xc5d981dfd0cc4014bf196e40ef2a792b"></div>
# <div id="x919b17122fdb4ac9ab0458aa130972ce"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 1200.0, "height": 1000.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": false, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "curved": true, "directed": true, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "a", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "b", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "c", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}], "links": [{"uid": "0x23a9141cfa0", "size": 2.0, "color": "black", "opacity": 1, "source": "a", "target": "b", "directed": true, "curved": 0.5}, {"uid": "0x23a91326f70", "size": 2.0, "color": "black", "opacity": 1, "source": "a", "target": "c", "directed": true, "curved": 0.5}, {"uid": "0x23a91326eb0", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "c", "directed": true, "curved": 0.5}, {"uid": "0x23a913265b0", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "a", "directed": true, "curved": 0.5}, {"uid": "0x23a8f260940", "size": 2.0, "color": "black", "opacity": 1, "source": "c", "target": "a", "directed": true, "curved": 0.5}]}
#
#  function tooltip(tooltipId, width){
#    // Local variable to hold tooltip div for
#    // manipulation in other functions.
#    var tt = d3.select('body')
#               .append('div')
#               .attr('class', 'tooltip')
#               .attr('id', tooltipId)
#               .style('pointer-events', 'none');
#
#    // Set a width if it is provided.
#    if (width) {
#      tt.style('width', width);
#    }
#
#    // Initially it is hidden.
#    hideTooltip();
#
#    /*
#     * Display tooltip with provided content.
#     * content is expected to be HTML string.
#     * event is d3.event for positioning.
#     */
#    function showTooltip(content, event) {
#      tt.style('opacity', 1.0)
#        .html(content);
#
#      updatePosition(event);
#    }
#
#    /*
#     * Hide the tooltip div.
#     */
#    function hideTooltip() {
#      tt.style('opacity', 0.0);
#    }
#
#    /*
#     * Figure out where to place the tooltip
#     * based on d3 mouse event.
#     */
#    function updatePosition(event) {
#      var xOffset = 20;
#      var yOffset = 10;
#
#      var ttw = tt.style('width');
#      var tth = tt.style('height');
#
#      var wscrY = window.scrollY;
#      var wscrX = window.scrollX;
#
#      var curX = (document.all) ? event.clientX + wscrX : event.pageX;
#      var curY = (document.all) ? event.clientY + wscrY : event.pageY;
#      var ttleft = ((curX - wscrX + xOffset * 2 + ttw) > window.innerWidth) ?
#                   curX - ttw - xOffset * 2 : curX + xOffset;
#
#      if (ttleft < wscrX + xOffset) {
#        ttleft = wscrX + xOffset;
#      }
#
#      var tttop = ((curY - wscrY + yOffset * 2 + tth) > window.innerHeight) ?
#                  curY - tth - yOffset * 2 : curY + yOffset;
#
#      if (tttop < wscrY + yOffset) {
#        tttop = curY + yOffset;
#      }
#
#      tt
#        .style('top', tttop + 'px')
#        .style('left', ttleft + 'px');
#    }
#
#    if (config.widgets.tooltip.enabled === true){
#      return {
#        showTooltip: showTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    } else {
#      return {
#        showTooltip: hideTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    };
#  };
#  /*
#   * network
#   */
#  function network(config){
#
#    // Constants for sizing
#    var width = config.width || 400;
#    var height = config.height || 400;
#    var temporal = config.temporal || fals

# %% [markdown]
# ## Transition matrices
#
#
# `pathpy` provides a function that computes a (row- or right-stochastic) transition matrix of a random walk process for a given network. The method should work for weighted, unweighted, directed, and undirected networks represented by a `pathpy.Network` object.

# %%
pp.algorithms.transition_matrix(n, weight = "weight").todense()
# Out:
# matrix([[0.        , 0.66666667, 0.33333333],
#         [0.66666667, 0.        , 0.33333333],
#         [1.        , 0.        , 0.        ]])

# %% [markdown]
# Write a function that computes the visitation probability $\pi^{(t)}$ of a random walk after $t$ steps, based on a given initial distribution $\pi^{(0)}$ and a given network topology. You can use built-in `numpy` functions for matrix powers and matrix multiplication. For matrix multiplication, you should have a look at the `dot` function in `numpy`. For the calculation of matrix powers, you should look into the package `numpy.linalg`.

# %%
def visitation_probabilities(network, initial_dist, t):
    T = pp.algorithms.transition_matrix(network, weight="weight").todense()
    p_t = np.dot(initial_dist, npl.matrix_power(T,t))
    return p_t

# %%
visitation_probabilities(n, np.array([1, 0, 0]), 0)
# Out:
# matrix([[1., 0., 0.]])

# %%
visitation_probabilities(n, np.array([1, 0, 0]), 1)
# Out:
# matrix([[0.        , 0.66666667, 0.33333333]])

# %%
visitation_probabilities(n, np.array([1, 0, 0]), 500)
# Out:
# matrix([[0.45, 0.3 , 0.25]])

# %% [markdown]
# We can compute the stationary distribution of the random walk:

# %%
def stationary_distribution(network):
    T =  pp.algorithms.transition_matrix(network).todense()
    eigenvalues, eigenvectors = sp.linalg.eig(T, left=True, right=False)
    # Here we take the **leading eigenvector**, i.e. the eigenvector
    # corresponding to the **largest eigenvalue** of one
    # numpy.argsort returns an array of indices that would sort an array
    # note the multi-dimensional slicing :,x, which returns all entries 
    # in column x
    pi = eigenvectors[:,np.argsort(-eigenvalues)][:,0]

    # We make sure that the eigenvector is normalised
    pi = pi/sum(pi)
    return pi

# %%
stationary_distribution(n)
# Out:
# array([0.44444444-0.j, 0.22222222-0.j, 0.33333333-0.j])

# %% [markdown]
# Generate a connected, undirected example network with $10$ nodes and $15$ links and test your function by computing the visitation probabilities after $t=10$ and $t=100$ steps for different initial distributions.
#
# Do the visitation probabilities converge to a stationary distribution? How do the visitation probabilities after $100$ steps differ across different initial distributions?

# %%
er_net = pp.generators.random_graphs.ER_nm(n = 10, m = 15)

pp.algorithms.components.largest_connected_component(er_net)
n = er_net.number_of_nodes()

for i in range(n):
    initial_dist = [0]*n
    initial_dist[i] = 1
    pi = visitation_probabilities(er_net, initial_dist, 10)
    print("visitation probabilities after 10 steps = ", pi)
    pi = visitation_probabilities(er_net, initial_dist, 500)
    print("visitation probabilities after 500 steps = ", pi)
# Out:
# visitation probabilities after 10 steps =  [[0.17062864 0.20650307 0.07838528 0.13909384 0.07746232 0.08273016
#   0.10255652 0.04606864 0.07260505 0.02396647]]
# visitation probabilities after 500 steps =  [[0.13333333 0.16666667 0.1        0.13333333 0.1        0.1
#   0.1        0.06666667 0.06666667 0.03333333]]
# visitation probabilities after 10 steps =  [[0.16520245 0.21542595 0.07188789 0.12234488 0.08274999 0.09684702
#   0.11745601 0.04630093 0.05945042 0.02233445]]
# visitation probabilities after 500 steps =  [[0.13333333 0.16666667 0.1        0.13333333 0.1        0.1
#   0.1        0.06666667 0.06666667 0.03333333]]
# visitation probabilities after 10 steps =  [[0.10451371 0.11981315 0.12818749 0.14717818 0.11563553 0.09899411
#   0.07914309 0.08650399 0.07545528 0.04457546]]
# visitation probabilities after 500 steps =  [[0.13333333 0.16666667 0.1        0.13333333 0.1        0.1
#   0.1        0.06666667 0.06666667 0.03333333]]
# visitation probabilities after 10 steps =  [[0.13909384 0.15293111 0.11038364 0.15642169 0.09407454 0.08042856
#   0.07816642 0.06784274 0.0842084  0.03644906]]
# visitation probabilities after 500 steps =  [[0.13333333 0.16666667 0.1        0.13333333 0.1        0.1
#   0.1        0.06666667 0.06666667 0.03333333]]
# visitation probabilities after 10 steps =  [[0.10328309 0.13791665 0.11563553 0.12543271 0.11884655 0.11581937
#   0.10044451 0.08308232 0.05897926 0.04056001]]
# visitation probabilities after 500 steps =  [[0.13333333 0.16666667 0.1        0.13333333 0.1        0.1
#   0.1        0.06666667 0.06666667 0.03333333]]
# visitation probabilities after 10 steps =  [[0.11030688 0.1614117  0.09899411 0.10723808 0.11581937 0.12889129
#   0.12237466 0.07415187 0.04694857 0.03386346]]
# visitation probabilities after 500 steps =  [[0.13333333 0.16666667 0.1        0.13333333 0.1        0.1
#   0.1        0.06666667 0.06666667 0.03333333]]
# visitation probabilities after 10 steps =  [[0.13674203 0.19576001 0.07914309 0.1042219  0.10044451 0.12237466
#   0.13174152 0.0579036  0.04608173 0.02558696]]
# visitation probabilities after 500 steps =  [[0.13333333 0.16666667 0.1        0.13333333 0.1        0.1
#   0.1        0.06666667 0.06666667 0.03333333]]
# visitation probabilities after 10 steps =  [[0.09213729 0.11575232 0.12975599 0.13568547 0.12462348 0.11122781
#   0.08685541 0.09209291 0.0656658  0.04620353]]
# visitation probabilities after 500 steps =  [[0.13333333 0.16666667 0.1        0.13333333 0.1        0.1
#   0.1        0.06666667 0.06666667 0.03333333]]
# visitation probabilities after 10 steps =  [[0.1452101  0.14862605 0.11318292 0.16841681 0.08846889 0.07042286
#   0.06912259 0.0656658  0.09445249 0.03643149]]
# visitation probabilities after 500 steps =  [[0.13333333 0.16666667 0.1        0.13333333 0.1        0.1
#   0.1        0.06666667 0.06666667 0.03333333]]
# visitation probabilities after 10 steps =  [[0.09586589 0.11167227 0.13372638 0.14579625 0.12168002 0.10159037
#   0.07676089 0.09240705 0.07286297 0.04763789]]
# visitation probabilities after 500 steps =  [[0.13333333 0.16666667 0.1        0.13333333 0.1        0.1
#   0.1        0.06666667 0.06666667 0.03333333]]

# %% [markdown]
# ## Random walks in `pathpy`
#
# `pathpy` offers direct support for the simulation of random walk processes in a network, as well as for the calculation of transition matrices, stationary states and total variation distance. To initialise a new random walk process in a given network, we can write:

# %%
rw = pp.processes.RandomWalk(n, start_node='a', weight=True)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-25-6ef78ae94f11> in <module>
# ----> 1 rw = pp.processes.RandomWalk(n, start_node='a', weight=True)
#
# c:\users\vince\documents\external packages\pathpy\pathpy\processes\random_walk.py in __init__(self, network, weight, start_node, restart_prob)
#      72
#      73         # transition matrix for the random walk
# ---> 74         self._transition_matrix = RandomWalk.transition_matrix(network, weight, restart_prob)
#      75
#      76         # uids of the nodes
#
# c:\users\vince\documents\external packages\pathpy\pathpy\processes\random_walk.py in transition_matrix(network, weight, restart_prob)
#     205
#     206         """
# --> 207         A = adjacency_matrix(network, weight=weight)
#     208         D = A.sum(axis=1)
#     209         n = network.number_of_nodes()
#
# c:\users\vince\anaconda3\envs\devenv\lib\functools.py in wrapper(*args, **kw)
#     872                             '1 positional argument')
#     873
# --> 874         return dispatch(args[0].__class__)(*args, **kw)
#     875
#     876     funcname = getattr(func, '__name__', 'singledispatch function')
#
# c:\users\vince\documents\external packages\pathpy\pathpy\algorithms\matrices.py in adjacency_matrix(self, weight, transposed, directed, **kwargs)
#      76
#      77     """
# ---> 78     raise NotImplementedError
#      79
#      80
#
# NotImplementedError:

# %% [markdown]
# If we omit the parameter `start_node` the initial node will be chosen uniformly at random among all nodes in the network. At any point, we can print the current time (i.e. number of steps taken so far), the current steps, and the current visitation probabilities as follows:

# %%
print(rw.t)
# Out:
# 0

# %%
print(rw.state)
# Out:
# a

# %%
print(rw.visitation_frequencies())
# Out:
# [1. 0. 0.]

# %%
print(rw.total_variation_distance)
# Out:
# 0.5499999999999998

# %% [markdown]
# Calling the function `transition` makes a single transition, which updates the time, state, and visitation frequencies of the random walk. The transition method returns the node that is visited:

# %%
x = rw.transition()
print('Random walker is in node =', rw.state)
print('Current time =', rw.t)
print('Current visitation_frequencies =', rw.visitation_frequencies())
# Out:
# Random walker is in node = b
# Current time = 1
# Current visitation_frequencies = [0.5 0.5 0. ]

# %%
print(rw.stationary_probabilities())
# Out:
# [0.45 0.3  0.25]

# %%
rw.total_variation_distance
# Out:
# 0.24999999999999994

# %%
print(rw.visitation_probabilities(t=1, start_node='a'))
# Out:
# [[0.         0.66666667 0.33333333]]

# %%
for v in rw.walk(10000):
    pass
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 10000/10000 [00:01<00:00, 5525.88it/s]

# %%
print(rw.visitation_frequencies())
# Out:
# [0.45040992 0.30133973 0.24825035]

# %%
rw.total_variation_distance
# Out:
# 0.001749650069985939

# %% [markdown]
# # P09-02: Diffusion Speed in Networks
#
# *June 18 2020*
#
# In the second unit we study the speed of diffusion in different network topologies. We use experiments to test the analytical predictions that we developed in the theory lecture.

# %%
import pathpy as pp
import numpy as np
from tqdm.auto import tqdm

import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use('default')
sns.set_style("whitegrid")
    
from numpy import linalg as npl
import scipy as sp

# %% [markdown]
# ### Total Variation Distance
#
# To calculate diffusion speed, we first write a function that computes the total variation distance between two stochastic vectors $\pi$ and $\pi'$ as defined in lecture 8.

# %%
def tvd(p1, p2):
    assert len(p1) == len(p2)
    tvd = 0
    for i in range(len(p1)):
        tvd +=abs(p1[i] - p2[i])
    return tvd/2

# %% [markdown]
# The following helper function returns the total variation distances between the stationary distribution $\pi$ and the visitation probability $\pi^s$ for $s=0, \ldots, t$ steps of a random walk process.

# %%
def compute_tvd(network, t, epsilon=0.005):

    t_min = np.inf
    
    T = pp.processes.RandomWalk.transition_matrix(network).todense()
    
    # We use a **right-stochastic matrix**, so what we want to
    # compute is the **left** eigenvectors (see lecture L08)
    eigenvalues, eigenvectors = sp.linalg.eig(T, left=True, right=False)
    
    # Here we take the **leading eigenvector**, i.e. the eigenvector
    # corresponding to the **largest eigenvalue** of one
    # numpy.argsort returns an array of indices that would sort an array
    # note the multi-dimensional slicing :,x, which returns all entries 
    # in column x
    pi = eigenvectors[:,np.argsort(-eigenvalues)][:,0]
    
    # We make sure that the eigenvector is normalised
    pi = pi/sum(pi)

    # We set the initial distribution
    initial_dist = np.array([0]*network.number_of_nodes())
    initial_dist[0] = 1

    # We calculate the total variation dist after each step
    tvds = []
    for s in range(t):
        x = np.ravel(np.dot(initial_dist, np.linalg.matrix_power(T, s)))
        d = tvd(pi,x)
        if d <= epsilon and t_min > s:
            t_min = s
        tvds.append(d)
    return tvds, t_min

# %% [markdown]
# We use the function above to calculate and plot the evolution of the total variation distance for the undirected example network shown in lecture 08.

# %%
n = pp.Network(directed=False)
n.add_edge('a', 'b')
n.add_edge('b', 'c')
n.add_edge('a', 'c')
n.add_edge('b', 'd')
n.add_edge('d', 'f')
n.add_edge('d', 'g')
n.add_edge('d', 'e')
n.add_edge('e', 'f')
n.add_edge('f', 'g')
n.plot()

d, tmin = compute_tvd(n, 100, epsilon=0.05)
plt.plot(np.arange(100), d)
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x7135aa254dc64cc6b0bdf76c4d13ef6c"></div>
# <div id="xdafbfb814b484e919276fd8d52094a30"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 1200.0, "height": 1000.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": false, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "a", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "b", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "c", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "d", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "f", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "g", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "e", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}], "links": [{"uid": "0x23a91b9c280", "size": 2.0, "color": "black", "opacity": 1, "source": "a", "target": "b", "directed": true, "curved": 0.5}, {"uid": "0x23a91887190", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "c", "directed": true, "curved": 0.5}, {"uid": "0x23a91887610", "size": 2.0, "color": "black", "opacity": 1, "source": "a", "target": "c", "directed": true, "curved": 0.5}, {"uid": "0x23a91887310", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "d", "directed": true, "curved": 0.5}, {"uid": "0x23a91887220", "size": 2.0, "color": "black", "opacity": 1, "source": "d", "target": "f", "directed": true, "curved": 0.5}, {"uid": "0x23a9129e160", "size": 2.0, "color": "black", "opacity": 1, "source": "d", "target": "g", "directed": true, "curved": 0.5}, {"uid": "0x23a91e034c0", "size": 2.0, "color": "black", "opacity": 1, "source": "d", "target": "e", "directed": true, "curved": 0.5}, {"uid": "0x23a91b72820", "size": 2.0, "color": "black", "opacity": 1, "source": "e", "target": "f", "directed": true, "curved": 0.5}, {"uid": "0x23a91ec9100", "size": 2.0, "color": "black", "opacity": 1, "source": "f", "target": "g", "directed": true, "curved": 0.5}]}
#
#  function tooltip(tooltipId, width){
#    // Local variable to hold tooltip div for
#    // manipulation in other functions.
#    var tt = d3.select('body')
#               .append('div')
#               .attr('class', 'tooltip')
#               .attr('id', tooltipId)
#               .style('pointer-events', 'none');
#
#    // Set a width if it is provided.
#    if (width) {
#      tt.style('width', width);
#    }
#
#    // Initially it is hidden.
#    hideTooltip();
#
#    /*
#     * Display tooltip with provided content.
#     * content is expected to be HTML string.
#     * event is d3.event for positioning.
#     */
#    function showTooltip(content, event) {
#      tt.style('opacity', 1.0)
#        .html(content);
#
#      updatePosition(event);
#    }
#
#    /*
#     * Hide the tooltip div.
#     */
#    function hideTooltip() {
#      tt.style('opacity', 0.0);
#    }
#
#    /*
#     * Figure out where to place the tooltip
#     * based on d3 mouse event.
#     */
#    function updatePosition(event) {
#      var xOffset = 20;
#      var yOffset = 10;
#
#      var ttw = tt.style('width');
#      var tth = tt.style('height');
#
#      var wscrY = window.scrollY;
#      var wscrX = window.scrollX;
#
#      var curX = (document.all) ? event.clientX + wscrX : event.pageX;
#      var curY = (document.all) ? event.clientY + wscrY : event.pageY;
#      var ttleft = ((curX - wscrX + xOffset * 2 + ttw) > window.innerWidth) ?
#                   curX - ttw - xOffset * 2 : cur
# c:\users\vince\anaconda3\envs\devenv\lib\site-packages\scipy\sparse\_index.py:84: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])

# %%
print('t_min =', tmin)
# Out:
# t_min = 14

# %%
def lambda_2(network):
    T = pp.processes.RandomWalk.transition_matrix(network).todense()
    eigenvalues, eigenvectors = sp.linalg.eig(T, left=True, right=False)
    x = eigenvalues[np.argsort(-eigenvalues)]
    return np.abs(x[1])

# %%
print('prediction =', np.log(0.05)/np.log(lambda_2(n)))
# Out:
# prediction = 15.780738151107203
# c:\users\vince\anaconda3\envs\devenv\lib\site-packages\scipy\sparse\_index.py:84: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])

# %% [markdown]
# ## Network Topology and Diffusion Speed
#
# Using code from previous exercises or corresponding `pathpy` functions, we now generate six different types of random networks:
#
#    1. an Erdös-Renyi network with $n=200$ nodes and $m=400$ links
#    2. an Erdös-Renyi network with $n=200$ nodes and $m=600$ links
#    3. a modular network consisting of two $5$-regular random networks with $100$ nodes each, which are joined together by crossing the endpoints of two arbitrary chosen links
#    4. a scale-free network with $200$ nodes and exponent $\gamma=2.7$
#    5. a Watts-Strogatz ring lattice with the parameters $n=200$, $m=5$ and rewiring probability $p=0$
#    6. a Watts-Strogatz small-world network with the parameters $n=200$, $m=5$ and rewiring probability $p=0.05$
#
# For each of the six networks we use the function from above to compute the evolution of total variation distance $\delta(\pi^{(t)}, \pi)$ for $t \in \left[0, 500\right]$ where $\pi$ is the stationary distribution.
#
# ### Experiment 1: Erdös-Renyi network with 200 nodes and 400 links

# %%
er_1 = pp.generators.random_graphs.ER_nm(n=200, m=400)
er_1 = pp.algorithms.components.largest_connected_component(er_1)

d, tmin = compute_tvd(er_1, 500)

plt.clf()
plt.grid()
plt.loglog(np.arange(500), d)
plt.show()
# Out:
# c:\users\vince\anaconda3\envs\devenv\lib\site-packages\scipy\sparse\_index.py:84: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])

# %%
print('t_min =', tmin)
print('prediction =', np.abs(np.log(0.005)/np.log(lambda_2(er_1))))
# Out:
# t_min = 28
# c:\users\vince\anaconda3\envs\devenv\lib\site-packages\scipy\sparse\_index.py:84: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])
# prediction = 29.45658216150769

# %% [markdown]
# ### Experiment 2: Erdös-Renyi network with 200 nodes and 600 links

# %%
er_2 = pp.generators.random_graphs.ER_nm(n=200, m=600)
er_2 = pp.algorithms.components.largest_connected_component(er_2)

d, tmin = compute_tvd(er_2, 500)

plt.clf()
plt.grid()
plt.loglog(np.arange(500), d)
plt.show()

# %%
print('t_min =', tmin)
print('prediction =', np.abs(np.log(0.005)/np.log(lambda_2(er_2))))
# Out:
# t_min = 16
# prediction = 15.814735843969592

# %% [markdown]
# ### Experiment 3: Modular network consisting of two 5-regular random networks with a total of 200 nodes

# %%
regular_1 = pp.generators.random_graphs.Molloy_Reed([5]*100, node_uids=[str(i) for i in range(100)])
regular_2 = pp.generators.random_graphs.Molloy_Reed([5]*100, node_uids=[str(i) for i in range(100,200)])
modular = regular_1 + regular_2

e1 = list(modular.edges)[1]
e2 = list(modular.edges)[400] 

modular.remove_edge(e1.v, e1.w)
modular.remove_edge(e2.v, e2.w)
modular.add_edge(e1.v, e2.w)
modular.add_edge(e2.v, e1.w)

d, tmin = compute_tvd(modular, 500)

plt.clf()
plt.grid()
plt.loglog(range(500), d)
plt.show()

# %%
print('t_min =', tmin)
print('prediction =', np.abs(np.log(0.005)/np.log(lambda_2(modular))))
# Out:
# t_min = inf
# prediction = 1072.1284384143698

# %% [markdown]
# ### Experiment 4: A scale-free network with power law exponent 2.7 and 200 nodes

# %%
degrees_zipf = [1]
while not pp.generators.random_graphs.is_graphic_Erdos_Gallai(degrees_zipf):
    degrees_zipf = [int(x) for x in np.random.zipf(2.7, 200)]

sf = pp.generators.random_graphs.Molloy_Reed(degrees_zipf)
sf = pp.algorithms.components.largest_connected_component(sf)

d, tmin = compute_tvd(sf, 500)

plt.clf()
plt.grid()
plt.loglog(range(500), d)
plt.show()

# %%
print('t_min =', tmin)
print('prediction =', np.abs(np.log(0.005)/np.log(lambda_2(sf))))
# Out:
# t_min = inf
# prediction = 536.8793089809878

# %% [markdown]
# ### Experiment 5: A Watts-Strogatz ring lattice with n=200, m=5 and p=0.

# %%
ring = pp.generators.random_graphs.Watts_Strogatz(n = 200, s = 5, p = 0)

d, tmin = compute_tvd(ring, 500)

plt.clf()
plt.grid()
plt.loglog(range(500), d)
plt.show()

# %%
print('t_min =', tmin)
print('prediction =', np.abs(np.log(0.005)/np.log(lambda_2(ring))))
# Out:
# t_min = inf
# prediction = 974.8362834948579

# %% [markdown]
# ### Network 6: A Watts-Strogatz small-world network with n = 200, m=5 and p = 0.05

# %%
ws = pp.generators.random_graphs.Watts_Strogatz(n = 200, s = 5, p = 0.05)

d, tmin = compute_tvd(ws, 500)

plt.clf()
plt.grid()
plt.loglog(range(500), d)
plt.show()

# %%
print('t_min =', tmin)
print('prediction =', np.abs(np.log(0.005)/np.log(lambda_2(ws))))
# Out:
# t_min = 108
# prediction = 113.9427883462654

# %% [markdown]
# ### Interpretation of results
#
# We make the following observations:
#
# 1. In a random network, the network with more links (quite expectedly) leads to faster diffusion than the network with fewer links. Moreover, the random network with 600 links gives rise to the **fastest diffusion**, across the studied network topologies.
# 2. In the network with 200 nodes and two modules, diffusion is orders of magnitude (!) slower than in a random network.
# 3. In the network with two modules, we see an interesting plateau in the evolution of the total variation distance, which is related to the presence of the two communities.
# 4. In the scale-free network, diffusion is omuch slower than in random Erdös-Rényi networks.
# 5. In the ring topology ($p=0$), **diffusion is the slowest (comparable to the modular network)**.
# 6. Randomly rewiring $5 \%$ of the links increases diffusion speed by a factor of ten.

# %% [markdown]
# ### Final experiment: Fully connected network

# %%
full = pp.generators.random_graphs.ER_np(n=50, p=1, loops=True)

d, tmin = compute_tvd(full, 10)
plt.clf()
plt.grid()
plt.loglog(range(10), d)
plt.show()

# %%
print('t_min =', tmin)
print('prediction =', np.abs(np.log(0.005)/np.log(lambda_2(full))))
# Out:
# t_min = 1
# prediction = 0.03747943862359303
