# %% [markdown]
# # P01 - 12: Visualising networks with `pathpy`
#
# **April 23 2020**
# *Ingo Scholtes*
#
# A key feature of `pathpy` is its support for custiumizable interactive visualisations that can be embedded in jupyter notebooks or stored as stand-alone files. In the following, we show this functionality in some toy exammples before moving to real data sets in the next unit. We first import `pathpy` as usual.

# %%
import pathpy as pp
import sqlite3
# Out:
#     <script charset="utf-8">
#     // Load via requireJS if available (jupyter notebook environment)
#     try {
#     require.config({
#     paths: {
#     d3: "https://d3js.org/d3.v5.min.js".replace(".js", "")
#     }
#     });
#     console.log("OKAY: requireJS was detected");
#     }
#     catch(err){
#     console.log(err);
#     console.log("ERROR: NO requireJS was detected");
#     };
#     require(['d3'], function(d3){
#     console.log("OKAY: d3js was detected");
#     });
#     </script>

# %% [markdown]
# ## Interactive network visualisation in `jupyter`
#
# We first create a simple toy example by adding two edges between three nodes.

# %%
n = pp.Network(directed=False)
n.add_edges(('a', 'b'), ('b', 'c'))
print(n)
# Out:
# Uid:			0x27c2bc38e48
# Type:			Network
# Directed:		False
# Multi-Edges:		False
# Number of nodes:	3
# Number of edges:	2

# %% [markdown]
# Calling the `print` function on a network instance will generate a string representation that can be printed on the console. The simplest way to graphically visualise the network in a jupyter noteboo is to simply type the variable name of the network:

# %%
n
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x604dacfaf4394dc48027e4b116c4dd5f"></div>
# <div id="x79a93251556542b6896dbea3ea6c6d47"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 800.0, "height": 550.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": false, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "a", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "b", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "c", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}], "links": [{"uid": "0x27c2bc38eb8", "size": 2.0, "color": "black", "opacity": 1, "source": "a", "target": "b", "directed": true, "curved": 0.5}, {"uid": "0x27c2bc78198", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "c", "directed": true, "curved": 0.5}]}
#
#  function tooltip(tooltipId, width){
#    // Local variable to hold tooltip div for
#    // manipulation in other functions.
#    var tt = d3.select('body')
#               .append('div')
#               .attr('class', 'tooltip')
#               .attr('id', tooltipId)
#               .style('pointer-events', 'none');
#
#    // Set a width if it is provided.
#    if (width) {
#      tt.style('width', width);
#    }
#
#    // Initially it is hidden.
#    hideTooltip();
#
#    /*
#     * Display tooltip with provided content.
#     * content is expected to be HTML string.
#     * event is d3.event for positioning.
#     */
#    function showTooltip(content, event) {
#      tt.style('opacity', 1.0)
#        .html(content);
#
#      updatePosition(event);
#    }
#
#    /*
#     * Hide the tooltip div.
#     */
#    function hideTooltip() {
#      tt.style('opacity', 0.0);
#    }
#
#    /*
#     * Figure out where to place the tooltip
#     * based on d3 mouse event.
#     */
#    function updatePosition(event) {
#      var xOffset = 20;
#      var yOffset = 10;
#
#      var ttw = tt.style('width');
#      var tth = tt.style('height');
#
#      var wscrY = window.scrollY;
#      var wscrX = window.scrollX;
#
#      var curX = (document.all) ? event.clientX + wscrX : event.pageX;
#      var curY = (document.all) ? event.clientY + wscrY : event.pageY;
#      var ttleft = ((curX - wscrX + xOffset * 2 + ttw) > window.innerWidth) ?
#                   curX - ttw - xOffset * 2 : curX + xOffset;
#
#      if (ttleft < wscrX + xOffset) {
#        ttleft = wscrX + xOffset;
#      }
#
#      var tttop = ((curY - wscrY + yOffset * 2 + tth) > window.innerHeight) ?
#                  curY - tth - yOffset * 2 : curY + yOffset;
#
#      if (tttop < wscrY + yOffset) {
#        tttop = curY + yOffset;
#      }
#
#      tt
#        .style('top', tttop + 'px')
#        .style('left', ttleft + 'px');
#    }
#
#    if (config.widgets.tooltip.enabled === true){
#      return {
#        showTooltip: showTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    } else {
#      return {
#        showTooltip: hideTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    };
#  };
#  /*
#   * network
#   */
#  function network(config){
#
#    // Constants for sizing
#    var width = config.width || 400;
#    var height = config.height || 400;
#    var temporal = config.temporal || false;
#    var tooltipSize = config.widgets.tooltip.size || '100px';
#
#
#    var labelCentered = config.label.centered || false;
#    var labelEnabled = config.label.enabled || false;
#    var labelColor = config.label.color || '#fff';
#
#    var curved = config.curved || false;
#    var directed = config.directed || false;
#
#    var radiusMinSize = config.radiusMinSize || 4;
#    var radiusMaxSize = config.radiusMaxSiz

# %% [markdown]
# This will create an interactive HTML visualisation of the network, where we can zoom, pan, and drag nodes. The same visualisation is generated if we explicitly call the function `plot` on the network instance. Try to zoom and pan the network (by holding the shift key and using the mouse/mouse wheel). Try what happens if you drag a node and release the mouse button. Try to search for a node with a specific uid or name:

# %%
n.plot()
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x8c2265e5142e4a8490eb2f8e9f1ee588"></div>
# <div id="x2259bbd5353f4ae982182967a0779f64"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 800.0, "height": 550.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": false, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "a", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "b", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "c", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}], "links": [{"uid": "0x27c2bc38eb8", "size": 2.0, "color": "black", "opacity": 1, "source": "a", "target": "b", "directed": true, "curved": 0.5}, {"uid": "0x27c2bc78198", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "c", "directed": true, "curved": 0.5}]}
#
#  function tooltip(tooltipId, width){
#    // Local variable to hold tooltip div for
#    // manipulation in other functions.
#    var tt = d3.select('body')
#               .append('div')
#               .attr('class', 'tooltip')
#               .attr('id', tooltipId)
#               .style('pointer-events', 'none');
#
#    // Set a width if it is provided.
#    if (width) {
#      tt.style('width', width);
#    }
#
#    // Initially it is hidden.
#    hideTooltip();
#
#    /*
#     * Display tooltip with provided content.
#     * content is expected to be HTML string.
#     * event is d3.event for positioning.
#     */
#    function showTooltip(content, event) {
#      tt.style('opacity', 1.0)
#        .html(content);
#
#      updatePosition(event);
#    }
#
#    /*
#     * Hide the tooltip div.
#     */
#    function hideTooltip() {
#      tt.style('opacity', 0.0);
#    }
#
#    /*
#     * Figure out where to place the tooltip
#     * based on d3 mouse event.
#     */
#    function updatePosition(event) {
#      var xOffset = 20;
#      var yOffset = 10;
#
#      var ttw = tt.style('width');
#      var tth = tt.style('height');
#
#      var wscrY = window.scrollY;
#      var wscrX = window.scrollX;
#
#      var curX = (document.all) ? event.clientX + wscrX : event.pageX;
#      var curY = (document.all) ? event.clientY + wscrY : event.pageY;
#      var ttleft = ((curX - wscrX + xOffset * 2 + ttw) > window.innerWidth) ?
#                   curX - ttw - xOffset * 2 : curX + xOffset;
#
#      if (ttleft < wscrX + xOffset) {
#        ttleft = wscrX + xOffset;
#      }
#
#      var tttop = ((curY - wscrY + yOffset * 2 + tth) > window.innerHeight) ?
#                  curY - tth - yOffset * 2 : curY + yOffset;
#
#      if (tttop < wscrY + yOffset) {
#        tttop = curY + yOffset;
#      }
#
#      tt
#        .style('top', tttop + 'px')
#        .style('left', ttleft + 'px');
#    }
#
#    if (config.widgets.tooltip.enabled === true){
#      return {
#        showTooltip: showTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    } else {
#      return {
#        showTooltip: hideTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    };
#  };
#  /*
#   * network
#   */
#  function network(config){
#
#    // Constants for sizing
#    var width = config.width || 400;
#    var height = config.height || 400;
#    var temporal = config.temporal || false;
#    var tooltipSize = config.widgets.tooltip.size || '100px';
#
#
#    var labelCentered = config.label.centered || false;
#    var labelEnabled = config.label.enabled || false;
#    var labelColor = config.label.color || '#fff';
#
#    var curved = config.curved || false;
#    var directed = config.directed || false;
#
#    var radiusMinSize = config.radiusMinSize || 4;
#    var radiusMaxSize = config.radiusMaxSiz

# %% [markdown]
# Using the two top-left buttons in the visualisatin you can export the current view of the network as a SVG vector graphics or a PNG pixel graphics file. By default a default style is applied to the network but pathpy allows to fully style the network based on (i) node and edge attributes that are automatically considered in the visualisation, or (ii) a custom style dictionary that can be passed to the plot function. If we want to change the color of nodes we can simply assign a `color` attribute to the nodes:

# %%
n.nodes['a']['color'] = 'red'
n.nodes['b']['color'] = 'green'
n.nodes['c']['color'] = 'blue'
n.plot()
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x7e8ca496d3064078a6b838884a0d868d"></div>
# <div id="x0aa9edf81197460e8fdfe75fcb02a4a5"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 800.0, "height": 550.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": false, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "a", "size": 15.0, "color": "red", "opacity": 0.2, "id_as_label": true}, {"uid": "b", "size": 15.0, "color": "green", "opacity": 0.2, "id_as_label": true}, {"uid": "c", "size": 15.0, "color": "blue", "opacity": 0.2, "id_as_label": true}], "links": [{"uid": "0x27c2bc38eb8", "size": 2.0, "color": "black", "opacity": 1, "source": "a", "target": "b", "directed": true, "curved": 0.5}, {"uid": "0x27c2bc78198", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "c", "directed": true, "curved": 0.5}]}
#
#  function tooltip(tooltipId, width){
#    // Local variable to hold tooltip div for
#    // manipulation in other functions.
#    var tt = d3.select('body')
#               .append('div')
#               .attr('class', 'tooltip')
#               .attr('id', tooltipId)
#               .style('pointer-events', 'none');
#
#    // Set a width if it is provided.
#    if (width) {
#      tt.style('width', width);
#    }
#
#    // Initially it is hidden.
#    hideTooltip();
#
#    /*
#     * Display tooltip with provided content.
#     * content is expected to be HTML string.
#     * event is d3.event for positioning.
#     */
#    function showTooltip(content, event) {
#      tt.style('opacity', 1.0)
#        .html(content);
#
#      updatePosition(event);
#    }
#
#    /*
#     * Hide the tooltip div.
#     */
#    function hideTooltip() {
#      tt.style('opacity', 0.0);
#    }
#
#    /*
#     * Figure out where to place the tooltip
#     * based on d3 mouse event.
#     */
#    function updatePosition(event) {
#      var xOffset = 20;
#      var yOffset = 10;
#
#      var ttw = tt.style('width');
#      var tth = tt.style('height');
#
#      var wscrY = window.scrollY;
#      var wscrX = window.scrollX;
#
#      var curX = (document.all) ? event.clientX + wscrX : event.pageX;
#      var curY = (document.all) ? event.clientY + wscrY : event.pageY;
#      var ttleft = ((curX - wscrX + xOffset * 2 + ttw) > window.innerWidth) ?
#                   curX - ttw - xOffset * 2 : curX + xOffset;
#
#      if (ttleft < wscrX + xOffset) {
#        ttleft = wscrX + xOffset;
#      }
#
#      var tttop = ((curY - wscrY + yOffset * 2 + tth) > window.innerHeight) ?
#                  curY - tth - yOffset * 2 : curY + yOffset;
#
#      if (tttop < wscrY + yOffset) {
#        tttop = curY + yOffset;
#      }
#
#      tt
#        .style('top', tttop + 'px')
#        .style('left', ttleft + 'px');
#    }
#
#    if (config.widgets.tooltip.enabled === true){
#      return {
#        showTooltip: showTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    } else {
#      return {
#        showTooltip: hideTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    };
#  };
#  /*
#   * network
#   */
#  function network(config){
#
#    // Constants for sizing
#    var width = config.width || 400;
#    var height = config.height || 400;
#    var temporal = config.temporal || false;
#    var tooltipSize = config.widgets.tooltip.size || '100px';
#
#
#    var labelCentered = config.label.centered || false;
#    var labelEnabled = config.label.enabled || false;
#    var labelColor = config.label.color || '#fff';
#
#    var curved = config.curved || false;
#    var directed = config.directed || false;
#
#    var radiusMinSize = config.radiusMinSize || 4;
#    var radiusMaxSize = config.radiusMaxSize || 16;
#    // variables to re

# %% [markdown]
# We can additionally change the size of the nodes as follows:

# %%
n.nodes['a']['size'] = 20
n.nodes['b']['size'] = 10
n.nodes['c']['size'] = 20
n.plot()
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x2939b9435ff542df8cc9d9de80616444"></div>
# <div id="x330c07a22912468cbb5878d8f1be6220"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 800.0, "height": 550.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": false, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "a", "size": 20.0, "color": "red", "opacity": 0.2, "id_as_label": true}, {"uid": "b", "size": 10.0, "color": "green", "opacity": 0.2, "id_as_label": true}, {"uid": "c", "size": 20.0, "color": "blue", "opacity": 0.2, "id_as_label": true}], "links": [{"uid": "0x27c2bc38eb8", "size": 2.0, "color": "black", "opacity": 1, "source": "a", "target": "b", "directed": true, "curved": 0.5}, {"uid": "0x27c2bc78198", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "c", "directed": true, "curved": 0.5}]}
#
#  function tooltip(tooltipId, width){
#    // Local variable to hold tooltip div for
#    // manipulation in other functions.
#    var tt = d3.select('body')
#               .append('div')
#               .attr('class', 'tooltip')
#               .attr('id', tooltipId)
#               .style('pointer-events', 'none');
#
#    // Set a width if it is provided.
#    if (width) {
#      tt.style('width', width);
#    }
#
#    // Initially it is hidden.
#    hideTooltip();
#
#    /*
#     * Display tooltip with provided content.
#     * content is expected to be HTML string.
#     * event is d3.event for positioning.
#     */
#    function showTooltip(content, event) {
#      tt.style('opacity', 1.0)
#        .html(content);
#
#      updatePosition(event);
#    }
#
#    /*
#     * Hide the tooltip div.
#     */
#    function hideTooltip() {
#      tt.style('opacity', 0.0);
#    }
#
#    /*
#     * Figure out where to place the tooltip
#     * based on d3 mouse event.
#     */
#    function updatePosition(event) {
#      var xOffset = 20;
#      var yOffset = 10;
#
#      var ttw = tt.style('width');
#      var tth = tt.style('height');
#
#      var wscrY = window.scrollY;
#      var wscrX = window.scrollX;
#
#      var curX = (document.all) ? event.clientX + wscrX : event.pageX;
#      var curY = (document.all) ? event.clientY + wscrY : event.pageY;
#      var ttleft = ((curX - wscrX + xOffset * 2 + ttw) > window.innerWidth) ?
#                   curX - ttw - xOffset * 2 : curX + xOffset;
#
#      if (ttleft < wscrX + xOffset) {
#        ttleft = wscrX + xOffset;
#      }
#
#      var tttop = ((curY - wscrY + yOffset * 2 + tth) > window.innerHeight) ?
#                  curY - tth - yOffset * 2 : curY + yOffset;
#
#      if (tttop < wscrY + yOffset) {
#        tttop = curY + yOffset;
#      }
#
#      tt
#        .style('top', tttop + 'px')
#        .style('left', ttleft + 'px');
#    }
#
#    if (config.widgets.tooltip.enabled === true){
#      return {
#        showTooltip: showTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    } else {
#      return {
#        showTooltip: hideTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    };
#  };
#  /*
#   * network
#   */
#  function network(config){
#
#    // Constants for sizing
#    var width = config.width || 400;
#    var height = config.height || 400;
#    var temporal = config.temporal || false;
#    var tooltipSize = config.widgets.tooltip.size || '100px';
#
#
#    var labelCentered = config.label.centered || false;
#    var labelEnabled = config.label.enabled || false;
#    var labelColor = config.label.color || '#fff';
#
#    var curved = config.curved || false;
#    var directed = config.directed || false;
#
#    var radiusMinSize = config.radiusMinSize || 4;
#    var radiusMaxSize = config.radiusMaxSize || 16;
#    // variables to re

# %% [markdown]
# An alternative method to style the network is by means of a key-value arguments with node and edge properties that are passed to the plot function. We can either assign the same property to all nodes, or we can assign different properties to different nodes based on a dictionary:

# %%
n.plot(node_color='red', node_size=10)
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x86360a39046b4d7185c4f036f7940395"></div>
# <div id="xb7064c4f2dd74c369d71961a01f64a29"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 800.0, "height": 550.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": false, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "a", "size": 10.0, "color": "red", "opacity": 0.2, "id_as_label": true}, {"uid": "b", "size": 10.0, "color": "red", "opacity": 0.2, "id_as_label": true}, {"uid": "c", "size": 10.0, "color": "red", "opacity": 0.2, "id_as_label": true}], "links": [{"uid": "0x27c2bc38eb8", "size": 2.0, "color": "black", "opacity": 1, "source": "a", "target": "b", "directed": true, "curved": 0.5}, {"uid": "0x27c2bc78198", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "c", "directed": true, "curved": 0.5}]}
#
#  function tooltip(tooltipId, width){
#    // Local variable to hold tooltip div for
#    // manipulation in other functions.
#    var tt = d3.select('body')
#               .append('div')
#               .attr('class', 'tooltip')
#               .attr('id', tooltipId)
#               .style('pointer-events', 'none');
#
#    // Set a width if it is provided.
#    if (width) {
#      tt.style('width', width);
#    }
#
#    // Initially it is hidden.
#    hideTooltip();
#
#    /*
#     * Display tooltip with provided content.
#     * content is expected to be HTML string.
#     * event is d3.event for positioning.
#     */
#    function showTooltip(content, event) {
#      tt.style('opacity', 1.0)
#        .html(content);
#
#      updatePosition(event);
#    }
#
#    /*
#     * Hide the tooltip div.
#     */
#    function hideTooltip() {
#      tt.style('opacity', 0.0);
#    }
#
#    /*
#     * Figure out where to place the tooltip
#     * based on d3 mouse event.
#     */
#    function updatePosition(event) {
#      var xOffset = 20;
#      var yOffset = 10;
#
#      var ttw = tt.style('width');
#      var tth = tt.style('height');
#
#      var wscrY = window.scrollY;
#      var wscrX = window.scrollX;
#
#      var curX = (document.all) ? event.clientX + wscrX : event.pageX;
#      var curY = (document.all) ? event.clientY + wscrY : event.pageY;
#      var ttleft = ((curX - wscrX + xOffset * 2 + ttw) > window.innerWidth) ?
#                   curX - ttw - xOffset * 2 : curX + xOffset;
#
#      if (ttleft < wscrX + xOffset) {
#        ttleft = wscrX + xOffset;
#      }
#
#      var tttop = ((curY - wscrY + yOffset * 2 + tth) > window.innerHeight) ?
#                  curY - tth - yOffset * 2 : curY + yOffset;
#
#      if (tttop < wscrY + yOffset) {
#        tttop = curY + yOffset;
#      }
#
#      tt
#        .style('top', tttop + 'px')
#        .style('left', ttleft + 'px');
#    }
#
#    if (config.widgets.tooltip.enabled === true){
#      return {
#        showTooltip: showTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    } else {
#      return {
#        showTooltip: hideTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    };
#  };
#  /*
#   * network
#   */
#  function network(config){
#
#    // Constants for sizing
#    var width = config.width || 400;
#    var height = config.height || 400;
#    var temporal = config.temporal || false;
#    var tooltipSize = config.widgets.tooltip.size || '100px';
#
#
#    var labelCentered = config.label.centered || false;
#    var labelEnabled = config.label.enabled || false;
#    var labelColor = config.label.color || '#fff';
#
#    var curved = config.curved || false;
#    var directed = config.directed || false;
#
#    var radiusMinSize = config.radiusMinSize || 4;
#    var radiusMaxSize = config.radiusMaxSize || 16;
#    // variables to refec

# %%
n.plot(node_color={'a': 'green', 'b': 'blue', 'c': 'red'}, node_size={'a': 20, 'b': 10, 'c': 20})
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x2665553a90354b8ab1dc036572a8d244"></div>
# <div id="xc7f46d078280432c8ea27152354e689c"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 800.0, "height": 550.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": false, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "a", "size": 20.0, "color": "green", "opacity": 0.2, "id_as_label": true}, {"uid": "b", "size": 10.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "c", "size": 20.0, "color": "red", "opacity": 0.2, "id_as_label": true}], "links": [{"uid": "0x27c2bc38eb8", "size": 2.0, "color": "black", "opacity": 1, "source": "a", "target": "b", "directed": true, "curved": 0.5}, {"uid": "0x27c2bc78198", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "c", "directed": true, "curved": 0.5}]}
#
#  function tooltip(tooltipId, width){
#    // Local variable to hold tooltip div for
#    // manipulation in other functions.
#    var tt = d3.select('body')
#               .append('div')
#               .attr('class', 'tooltip')
#               .attr('id', tooltipId)
#               .style('pointer-events', 'none');
#
#    // Set a width if it is provided.
#    if (width) {
#      tt.style('width', width);
#    }
#
#    // Initially it is hidden.
#    hideTooltip();
#
#    /*
#     * Display tooltip with provided content.
#     * content is expected to be HTML string.
#     * event is d3.event for positioning.
#     */
#    function showTooltip(content, event) {
#      tt.style('opacity', 1.0)
#        .html(content);
#
#      updatePosition(event);
#    }
#
#    /*
#     * Hide the tooltip div.
#     */
#    function hideTooltip() {
#      tt.style('opacity', 0.0);
#    }
#
#    /*
#     * Figure out where to place the tooltip
#     * based on d3 mouse event.
#     */
#    function updatePosition(event) {
#      var xOffset = 20;
#      var yOffset = 10;
#
#      var ttw = tt.style('width');
#      var tth = tt.style('height');
#
#      var wscrY = window.scrollY;
#      var wscrX = window.scrollX;
#
#      var curX = (document.all) ? event.clientX + wscrX : event.pageX;
#      var curY = (document.all) ? event.clientY + wscrY : event.pageY;
#      var ttleft = ((curX - wscrX + xOffset * 2 + ttw) > window.innerWidth) ?
#                   curX - ttw - xOffset * 2 : curX + xOffset;
#
#      if (ttleft < wscrX + xOffset) {
#        ttleft = wscrX + xOffset;
#      }
#
#      var tttop = ((curY - wscrY + yOffset * 2 + tth) > window.innerHeight) ?
#                  curY - tth - yOffset * 2 : curY + yOffset;
#
#      if (tttop < wscrY + yOffset) {
#        tttop = curY + yOffset;
#      }
#
#      tt
#        .style('top', tttop + 'px')
#        .style('left', ttleft + 'px');
#    }
#
#    if (config.widgets.tooltip.enabled === true){
#      return {
#        showTooltip: showTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    } else {
#      return {
#        showTooltip: hideTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    };
#  };
#  /*
#   * network
#   */
#  function network(config){
#
#    // Constants for sizing
#    var width = config.width || 400;
#    var height = config.height || 400;
#    var temporal = config.temporal || false;
#    var tooltipSize = config.widgets.tooltip.size || '100px';
#
#
#    var labelCentered = config.label.centered || false;
#    var labelEnabled = config.label.enabled || false;
#    var labelColor = config.label.color || '#fff';
#
#    var curved = config.curved || false;
#    var directed = config.directed || false;
#
#    var radiusMinSize = config.radiusMinSize || 4;
#    var radiusMaxSize = config.radiusMaxSize || 16;
#    // variables to re

# %% [markdown]
# A better way to manage plot styles is to store all styles in a dictionary, whose entries are then passed to the plot function using the kwargs operator **. A major advantage of this is that we can store the plot style and apply the same style to multiple networks or to visualisations in multiple formats.

# %%
plot_style = {
    'node_color': {'a': 'orange', 'b': 'blue', 'c': 'red'}, 
    'node_size': {'a': 30, 'b': 10, 'c': 20}
}
n.plot(**plot_style)
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x2d4533145d694867b15441a2d1d99419"></div>
# <div id="xe6fc45b521ee4fa79b72be765f4c621f"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 800.0, "height": 550.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": false, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "a", "size": 30.0, "color": "orange", "opacity": 0.2, "id_as_label": true}, {"uid": "b", "size": 10.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "c", "size": 20.0, "color": "red", "opacity": 0.2, "id_as_label": true}], "links": [{"uid": "0x27c2bc38eb8", "size": 2.0, "color": "black", "opacity": 1, "source": "a", "target": "b", "directed": true, "curved": 0.5}, {"uid": "0x27c2bc78198", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "c", "directed": true, "curved": 0.5}]}
#
#  function tooltip(tooltipId, width){
#    // Local variable to hold tooltip div for
#    // manipulation in other functions.
#    var tt = d3.select('body')
#               .append('div')
#               .attr('class', 'tooltip')
#               .attr('id', tooltipId)
#               .style('pointer-events', 'none');
#
#    // Set a width if it is provided.
#    if (width) {
#      tt.style('width', width);
#    }
#
#    // Initially it is hidden.
#    hideTooltip();
#
#    /*
#     * Display tooltip with provided content.
#     * content is expected to be HTML string.
#     * event is d3.event for positioning.
#     */
#    function showTooltip(content, event) {
#      tt.style('opacity', 1.0)
#        .html(content);
#
#      updatePosition(event);
#    }
#
#    /*
#     * Hide the tooltip div.
#     */
#    function hideTooltip() {
#      tt.style('opacity', 0.0);
#    }
#
#    /*
#     * Figure out where to place the tooltip
#     * based on d3 mouse event.
#     */
#    function updatePosition(event) {
#      var xOffset = 20;
#      var yOffset = 10;
#
#      var ttw = tt.style('width');
#      var tth = tt.style('height');
#
#      var wscrY = window.scrollY;
#      var wscrX = window.scrollX;
#
#      var curX = (document.all) ? event.clientX + wscrX : event.pageX;
#      var curY = (document.all) ? event.clientY + wscrY : event.pageY;
#      var ttleft = ((curX - wscrX + xOffset * 2 + ttw) > window.innerWidth) ?
#                   curX - ttw - xOffset * 2 : curX + xOffset;
#
#      if (ttleft < wscrX + xOffset) {
#        ttleft = wscrX + xOffset;
#      }
#
#      var tttop = ((curY - wscrY + yOffset * 2 + tth) > window.innerHeight) ?
#                  curY - tth - yOffset * 2 : curY + yOffset;
#
#      if (tttop < wscrY + yOffset) {
#        tttop = curY + yOffset;
#      }
#
#      tt
#        .style('top', tttop + 'px')
#        .style('left', ttleft + 'px');
#    }
#
#    if (config.widgets.tooltip.enabled === true){
#      return {
#        showTooltip: showTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    } else {
#      return {
#        showTooltip: hideTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    };
#  };
#  /*
#   * network
#   */
#  function network(config){
#
#    // Constants for sizing
#    var width = config.width || 400;
#    var height = config.height || 400;
#    var temporal = config.temporal || false;
#    var tooltipSize = config.widgets.tooltip.size || '100px';
#
#
#    var labelCentered = config.label.centered || false;
#    var labelEnabled = config.label.enabled || false;
#    var labelColor = config.label.color || '#fff';
#
#    var curved = config.curved || false;
#    var directed = config.directed || false;
#
#    var radiusMinSize = config.radiusMinSize || 4;
#    var radiusMaxSize = config.radiusMaxSize || 16;
#    // variables to r

# %% [markdown]
# In any case, the plot parameters passed explicitly to the plot function will take preference over any node or edge properties. To conclude this section, let us plot a few networks that we read from our database file.

# %%
con = sqlite3.connect('networks.db')
n = pp.io.read_sql(con=con, sql='SELECT source, target FROM lotr', directed=True)
n.plot(node_size=5)
# Out:
# [08-17 17:36:03: ERROR] The edge "0x27c2c0c4e10" already exists in the Network
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-a0f50da8ad77> in <module>
#       1 con = sqlite3.connect('networks.db')
# ----> 2 n = pp.io.read_sql(con=con, sql='SELECT source, target FROM lotr', directed=True)
#       3 n.plot(node_size=5)
#
# c:\users\luka\documents\phd\pathpy3\pathpy\io\io.py in read_sql(filename, directed, loops, con, sql, table, **kwargs)
#     244
#     245     # construct network from pandas data frame
# --> 246     return from_dataframe(df, directed=directed, loops=loops, **kwargs)
#     247
#     248
#
# c:\users\luka\documents\phd\pathpy3\pathpy\io\io.py in from_dataframe(df, directed, loops, multiedges, **kwargs)
#     190             edge = Edge(net.nodes[v], net.nodes[w], uid=uid)
#     191         if loops or edge.v != edge.w:
# --> 192             net.add_edge(edge)
#     193
#     194         reserved_columns = set(['v', 'w', 'uid'])
#
# c:\users\luka\documents\phd\pathpy3\pathpy\core\network.py in add_edge(self, uid, *edge, **kwargs)
#     778
#     779         """
# --> 780         self.edges.add(*edge, uid=uid, **kwargs)
#     781         self._add_properties()
#     782
#
# C:\Anaconda\lib\site-packages\singledispatchmethod.py in _method(*args, **kwargs)
#      67         def _method(*args, **kwargs):
#      68             method = self.dispatcher.dispatch(args[0].__class__)
# ---> 69             return method.__get__(obj, cls)(*args, **kwargs)
#      70
#      71         _method.__isabstractmethod__ = self.__isabstractmethod__
#
# c:\users\luka\documents\phd\pathpy3\pathpy\core\edge.py in _(self, *edge, **kwargs)
#     671                 self._add(_edge)
#     672             else:
# --> 673                 self._if_exist(_edge.uid, **kwargs)
#     674         else:
#     675             # raise error if edge already exists
#
# c:\users\luka\documents\phd\pathpy3\pathpy\core\edge.py in _if_exist(self, edge, **kwargs)
#     756         # pylint: disable=unused-argument
#     757         LOG.error('The edge "%s" already exists in the Network', edge)
# --> 758         raise KeyError
#     759
#     760     def _add(self, edge: Edge) -> None:
#
# KeyError:

# %%
n = pp.io.read_sql(filename='networks.db', table='gentoo', directed=True)
n.plot(node_size=5)
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x91eb3b07562a4b89b36b183360814668"></div>
# <div id="xc0a71cb44da4496baccb5528b278652f"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 800.0, "height": 550.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": false, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "curved": true, "directed": true, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "seemant", "size": 5.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "jakub", "size": 5.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "stefaan", "size": 5.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "kerberos", "size": 5.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "samba", "size": 5.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "damon", "size": 5.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "gad.kadosh", "size": 5.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "vapier", "size": 5.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "eradicator", "size": 5.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "plasmaroo", "size": 5.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "uberlord", "size": 5.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "weeve", "size": 5.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "tetromino", "size": 5.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "battousai", "size": 5.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "je_fro", "size": 5.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "karstenrbecker", "size": 5.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "Tiger683", "size": 5.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "gcc-porting", "size": 5.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "ppc", "size": 5.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "toolchain", "size": 5.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "crypto", "size": 5.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "hardened", "size": 5.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "base-system", "size": 5.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "embedded", "size": 5.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "amd64", "size": 5.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "x86", "size": 5.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "kernel", "size": 5.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "net-dialup", "size": 5.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "8an", "size": 5.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "ftlofaro", "size": 5.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "smallone", "size": 5.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "paapaa125", "size": 5.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "joelinux", "size": 5.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "davec-gentoo", "size": 5.0, "color": "C

# %%
n = pp.io.read_sql(filename='networks.db', table='highschool', directed=False)
n.plot(node_size=5)
# Out:
# [08-17 17:37:08: ERROR] The edge "0x27c2c3cac50" already exists in the Network
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-1a4a238a767c> in <module>
# ----> 1 n = pp.io.read_sql(filename='networks.db', table='highschool', directed=False)
#       2 n.plot(node_size=5)
#
# c:\users\luka\documents\phd\pathpy3\pathpy\io\io.py in read_sql(filename, directed, loops, con, sql, table, **kwargs)
#     244
#     245     # construct network from pandas data frame
# --> 246     return from_dataframe(df, directed=directed, loops=loops, **kwargs)
#     247
#     248
#
# c:\users\luka\documents\phd\pathpy3\pathpy\io\io.py in from_dataframe(df, directed, loops, multiedges, **kwargs)
#     190             edge = Edge(net.nodes[v], net.nodes[w], uid=uid)
#     191         if loops or edge.v != edge.w:
# --> 192             net.add_edge(edge)
#     193
#     194         reserved_columns = set(['v', 'w', 'uid'])
#
# c:\users\luka\documents\phd\pathpy3\pathpy\core\network.py in add_edge(self, uid, *edge, **kwargs)
#     778
#     779         """
# --> 780         self.edges.add(*edge, uid=uid, **kwargs)
#     781         self._add_properties()
#     782
#
# C:\Anaconda\lib\site-packages\singledispatchmethod.py in _method(*args, **kwargs)
#      67         def _method(*args, **kwargs):
#      68             method = self.dispatcher.dispatch(args[0].__class__)
# ---> 69             return method.__get__(obj, cls)(*args, **kwargs)
#      70
#      71         _method.__isabstractmethod__ = self.__isabstractmethod__
#
# c:\users\luka\documents\phd\pathpy3\pathpy\core\edge.py in _(self, *edge, **kwargs)
#     671                 self._add(_edge)
#     672             else:
# --> 673                 self._if_exist(_edge.uid, **kwargs)
#     674         else:
#     675             # raise error if edge already exists
#
# c:\users\luka\documents\phd\pathpy3\pathpy\core\edge.py in _if_exist(self, edge, **kwargs)
#     756         # pylint: disable=unused-argument
#     757         LOG.error('The edge "%s" already exists in the Network', edge)
# --> 758         raise KeyError
#     759
#     760     def _add(self, edge: Edge) -> None:
#
# KeyError:

# %% [markdown]
# ## Network Layouts
#
# An important question in the drawing of networks is where nodes are placed. The positioning of nodes determines whether it is easy to spot patterns in the topology of the network. As a general rule, good network visualisations should have a small number of crossing edges and nodes should be placed away from each other such that we can easily distinguish them. If we make no other effort, pathpy will automatically use a simple, interactive force-directed layout algorithm. It is based on the idea that nodes connected by an edge are moved towards each other by an attractive force, while an additional repulsive force between all node pairs makes sure that nodes are not drawn on top pf each other. The simulation of those forces, and the computation of a steady-state of the resulting many-particle system is what determines the node positions in the default pathpy visualisation. Also, this is the basis upon which nodes move if you disturb the visualisation by dragging around nodes.
#
# While the default layout algorithm makes it simple to visualise networks, it has the disadvantage that the layout is actually calculated in JavaScript. This means that the positions of nodes are actually not stored in python, which makes it impossible to influence (or store) node positions from python. To solve this issue, `pathpy` provides a `layout` module that can be used to precompute node positions based on different layout algorithms. Moreover, it allows to manually optimise the parameters of those algorithms to generate a nice visualisation.
#
# The styling of node positions via a layout style follows the same idea like the styling of plots via a plot style. We can store the parameters in a dictionary and pass them to the `layout` function using the ** operator. To compute ode positions based on a certain number of iterations of the Fruchterman-Reingold algorithm with a specific force value we can write:

# %%
layout_style = {}
layout_style['layout'] = 'Fruchterman-Reingold'
layout_style['force'] = 0.2
layout_style['iterations'] = 500
layout = pp.layout(n, **layout_style)
print(layout)
# Out:
# {'seemant': array([-0.47902481, -1.45390265]), 'jakub': array([-0.64042905,  0.64492602]), 'stefaan': array([-0.58484015, -2.39844034]), 'kerberos': array([-0.84839619, -2.29027164]), 'samba': array([-0.65748465, -2.29365151]), 'damon': array([-0.46179439, -2.35466078]), 'gad.kadosh': array([-0.74880316, -2.3786585 ]), 'vapier': array([1.80977076, 1.35202975]), 'eradicator': array([1.52108427, 0.56435152]), 'plasmaroo': array([1.16728982, 2.26525851]), 'uberlord': array([0.78210857, 1.20411748]), 'weeve': array([1.17188598, 0.53693689]), 'tetromino': array([2.35718872, 1.94484994]), 'battousai': array([1.69593263, 1.98467682]), 'je_fro': array([2.52724999, 1.65726029]), 'karstenrbecker': array([2.70116999, 1.65652571]), 'Tiger683': array([2.71260456, 1.77277754]), 'gcc-porting': array([1.15581771, 0.878726  ]), 'ppc': array([1.4344253 , 0.27692027]), 'toolchain': array([1.06954274, 1.62587118]), 'crypto': array([0.73954848, 1.28271807]), 'hardened': array([1.01614696, 0.76073427]), 'base-system': array([0.95276337, 1.80217767]), 'embedded': array([0.69454232, 1.04260341]), 'amd64': array([1.91715257, 0.13682013]), 'x86': array([1.69074035, 0.33715013]), 'kernel': array([1.21111512, 1.19123914]), 'net-dialup': array([2.43606671, 1.81600483]), '8an': array([2.54261747, 1.94380462]), 'ftlofaro': array([2.69139537, 1.41867419]), 'smallone': array([2.75068334, 1.54347016]), 'paapaa125': array([2.46226689, 2.0269021 ]), 'joelinux': array([2.57053609, 1.78079061]), 'davec-gentoo': array([2.60341196, 1.53536641]), 'kcody': array([2.64879768, 1.89486021]), 'dragonheart': array([0.54032176, 1.66904598]), 'mholzer': array([-0.97073069,  0.63279745]), 'solar': array([1.46241098, 0.93753775]), 'ticho': array([-2.31965296,  0.92348783]), 'agriffis': array([ 0.34429408, -0.60574356]), 'mlspamcb': array([-1.23630879,  1.53512901]), 'cardoe': array([-1.54130217,  1.38335711]), 'bugzilla': array([-1.88413274, -0.20108635]), 'zzam': array([-0.96260644,  1.2972978 ]), 'squinky86': array([0.73775759, 0.19694132]), 'hanno': array([-1.23285995,  1.65914972]), 'andre': array([-0.56430568,  0.02545363]), 'truedfx': array([-0.19811189, -0.77030229]), 'lu_zero': array([0.20940116, 0.62208853]), 'askwar': array([-0.79786611, -0.3750835 ]), 'ka0ttic': array([-0.80713577,  1.22185864]), 'mail': array([-1.9322697 ,  2.11667807]), 'chrb': array([0.13725349, 2.22495972]), 'allanonjl': array([-2.41068571,  1.50310077]), 'strerror': array([-0.92993957, -0.48443935]), 'latexer': array([-0.84595212,  0.86876675]), 'lanius': array([-0.90665198,  0.39765529]), 'rphillips': array([-0.65226242,  1.05079818]), 'gentoo': array([-3.13610864, -0.30518717]), 'humpback': array([-1.53571884,  0.08688209]), 'caneko': array([-0.05183166,  1.28947626]), 'gentoobugs': array([-1.10400065,  0.45106681]), 'denilsonsa': array([0.03077185, 0.24625628]), 'aben': array([-1.48576681,  1.88788221]), 'bugzilla-gentoo': array([-1.08261557,  2.08361818]), 'markusle': array([-1.57075441,  0.45019439]), 'pfeifer': array([-1.52432793,  0.32267895]), 'ed': array([-0.55393776, -0.46113179]), 'andrei.ivanov': array([-0.88081115,  0.00884993]), 'alpeterson': array([-0.22607686,  0.15024236]), 'xkr47': array([-0.27713948, -0.00124718]), 'paolo.pedroni': array([0.14098632, 0.49221634]), 'david': array([-2.14271916,  0.50910055]), 'arj': array([-0.53750421,  0.20033605]), 'evan': array([-1.25635284,  0.04218075]), 'thedude0001': array([-0.0030923 ,  2.00883716]), 'mozilla': array([-1.11460532,  1.29375253]), 'toralf.foerster': array([-1.78432125,  0.88309668]), 'bugs.gentoo.org': array([-1.71607195,  1.69642899]), 'nunoplopes': array([-0.26738271,  1.4293518 ]), 'albertito': array([-1.73010243,  0.20882068]), 'malverian': array([-0.51817743,  1.77178854]), 'andy.dalton': array([-0.67069981,  1.39747245]), 'alex': array([-2.10211869,  0.28961474]), 'joey': array([-1.62954463,  1.28332017]), 'spida': array([-1.728837  ,  1.09506545]), 'kde': array([ 0.61142018, -0.21591016]), 'x11': array([ 0.73387974 ...

# %% [markdown]
# This computes a dictionary of node positions, where the node uids are the keys and two-dimensional coordinates are the values. We can now pass this specific layout to the plot function of the network. This will disable the interactive layout in JavaScript, fixing the node positions to the precalculated layout:

# %%
pp.plot(n, **plot_style, layout=layout)
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x028c148c37da46f2b4d77084cb58f6be"></div>
# <div id="x0872dcfb22ac4e85897be6a0eaa7e5a8"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 800.0, "height": 550.0, "unit": "px", "dpi": 96, "margin": null, "layout": "euclidean", "temporal": false, "coordinates": true, "euclidean": true, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "curved": true, "directed": true, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": true, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "seemant", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [343.7411689522999, 436.03765070726683], "id_as_label": true}, {"uid": "jakub", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [333.19883927740494, 298.94990619031], "id_as_label": true}, {"uid": "stefaan", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [336.8297009549357, 497.7313672810361], "id_as_label": true}, {"uid": "kerberos", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [319.61519295378787, 490.66618719250255], "id_as_label": true}, {"uid": "samba", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [332.0848306645123, 490.8869476902215], "id_as_label": true}, {"uid": "damon", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [344.86659599265886, 494.8718481666533], "id_as_label": true}, {"uid": "gad.kadosh", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [326.12024247261536, 496.43929051253605], "id_as_label": true}, {"uid": "vapier", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [493.2368502309061, 252.7645000800353], "id_as_label": true}, {"uid": "eradicator", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [474.380913671371, 304.212735446857], "id_as_label": true}, {"uid": "plasmaroo", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [451.2723653544672, 193.11576717699938], "id_as_label": true}, {"uid": "uberlord", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [426.11374764794004, 262.42558369338826], "id_as_label": true}, {"uid": "weeve", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [451.5725701219983, 306.00335797655737], "id_as_label": true}, {"uid": "tetromino", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [528.9921712927173, 214.04367239552772], "id_as_label": true}, {"uid": "battousai", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [485.8013630366704, 211.44232799110688], "id_as_label": true}, {"uid": "je_fro", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [540.0999458419369, 232.82796706642455], "id_as_label": true}, {"uid": "karstenrbecker", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [551.459758290058, 232.875947161326], "id_as_label": true}, {"uid": "Tiger683", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [552.206622392696, 225.28280707286137], "id_as_label": true}, {"uid": "gcc-porting", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [450.5230500132036, 283.67895465515755], "id_as_label": true}, {"uid": "ppc", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [468.7206693778809, 322.9866839003708], "id_as_label": true}, {"uid": "toolchain", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [444.8878872678451, 234.87818816417695], "id_as_label": true}, {"uid": "crypto", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [423.33387982835245, 257.2916830470681], "id_as_label": true}, {"uid": "hardened", "size":

# %% [markdown]
# ## Plotting spatially embedded networks
#
# Layout algorithms are important to visualise networks where nodes are not naturally embedded in a space. However, for a number of complex networks we can naturally assign coordinates to nodes. Examples include infrastructure networks like road, train, or flight networks where we have information on geographic coordinates of road junctions, train stations, or airports. We do not need a layout algorithm to calculate node positions, we can use node coordinates instead, which we can assign to the node attributes:

# %%
n.nodes['a']['coordinates'] = [0,0]
n.nodes['b']['coordinates'] = [0,1]
n.nodes['c']['coordinates'] = [1,0]
n.plot(**plot_style)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-e0e15b8d9287> in <module>
# ----> 1 n.nodes['a']['coordinates'] = [0,0]
#       2 n.nodes['b']['coordinates'] = [0,1]
#       3 n.nodes['c']['coordinates'] = [1,0]
#       4 n.plot(**plot_style)
#
# c:\users\luka\documents\phd\pathpy3\pathpy\core\node.py in __getitem__(self, key)
#     231         """Returns a node object."""
#     232         if isinstance(key, str):
# --> 233             _node = self._map[key]
#     234         elif isinstance(key, self._node_class) and key in self:
#     235             _node = key
#
# KeyError: 'a'

# %% [markdown]
# Like for other node attributes, specifying a layout for the network will override the node properties, i.e. in this case the node coordinates will be ignored:

# %%
n.plot(**plot_style, layout=layout)
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x1da8f58259904c0c880f87a736702c23"></div>
# <div id="x8fefc8c5f34f4b2bab14d52fcd8bfb94"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 800.0, "height": 550.0, "unit": "px", "dpi": 96, "margin": null, "layout": "euclidean", "temporal": false, "coordinates": true, "euclidean": true, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "curved": true, "directed": true, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": true, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "seemant", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [343.7411689522999, 436.03765070726683], "id_as_label": true}, {"uid": "jakub", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [333.19883927740494, 298.94990619031], "id_as_label": true}, {"uid": "stefaan", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [336.8297009549357, 497.7313672810361], "id_as_label": true}, {"uid": "kerberos", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [319.61519295378787, 490.66618719250255], "id_as_label": true}, {"uid": "samba", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [332.0848306645123, 490.8869476902215], "id_as_label": true}, {"uid": "damon", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [344.86659599265886, 494.8718481666533], "id_as_label": true}, {"uid": "gad.kadosh", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [326.12024247261536, 496.43929051253605], "id_as_label": true}, {"uid": "vapier", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [493.2368502309061, 252.7645000800353], "id_as_label": true}, {"uid": "eradicator", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [474.380913671371, 304.212735446857], "id_as_label": true}, {"uid": "plasmaroo", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [451.2723653544672, 193.11576717699938], "id_as_label": true}, {"uid": "uberlord", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [426.11374764794004, 262.42558369338826], "id_as_label": true}, {"uid": "weeve", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [451.5725701219983, 306.00335797655737], "id_as_label": true}, {"uid": "tetromino", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [528.9921712927173, 214.04367239552772], "id_as_label": true}, {"uid": "battousai", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [485.8013630366704, 211.44232799110688], "id_as_label": true}, {"uid": "je_fro", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [540.0999458419369, 232.82796706642455], "id_as_label": true}, {"uid": "karstenrbecker", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [551.459758290058, 232.875947161326], "id_as_label": true}, {"uid": "Tiger683", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [552.206622392696, 225.28280707286137], "id_as_label": true}, {"uid": "gcc-porting", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [450.5230500132036, 283.67895465515755], "id_as_label": true}, {"uid": "ppc", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [468.7206693778809, 322.9866839003708], "id_as_label": true}, {"uid": "toolchain", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [444.8878872678451, 234.87818816417695], "id_as_label": true}, {"uid": "crypto", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [423.33387982835245, 257.2916830470681], "id_as_label": true}, {"uid": "hardened", "size":

# %% [markdown]
# ## Plotting networks to PDF
#
# While it is convenient to interactively plot networks in a jupyter network, we often want to generate stand-alone visualisations that we can either share or embed in scientific publications. Apart from the possibility to directly export PNG and SVG visualisations from the interactive HTML widget, the plot function can be used to generate a stand-alone HTML visualisation of the network that can be opened in any browser and shared on the Web.

# %%
n.plot(**plot_style, filename='network.html')

# %% [markdown]
# If you want a vector graphics figure that can be embedded in a scientific paper, you can use the plot function to export network visualisations as PDF:

# %%
n.plot(**plot_style, layout=layout, filename='network.pdf')
# Out:
# [08-17 17:39:23: ERROR] No latexmk compiler found
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# c:\users\luka\documents\phd\pathpy3\pathpy\visualisations\fileformats\pdf.py in compile(self)
#      99         try:
# --> 100             subprocess.check_output(command, stderr=subprocess.STDOUT)
#     101         except Exception:
#
# C:\Anaconda\lib\subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#
# C:\Anaconda\lib\subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     486             raise CalledProcessError(retcode, process.args,
# --> 487                                      output=stdout, stderr=stderr)
#     488     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['latexmk', '--pdf', '-shell-escape', '--interaction=nonstopmode', 'default.tex']' returned non-zero exit status 3221225477.
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-1520bb319d3a> in <module>
# ----> 1 n.plot(**plot_style, layout=layout, filename='network.pdf')
#
# c:\users\luka\documents\phd\pathpy3\pathpy\visualisations\plot.py in plot(obj, filename, backend, **kwargs)
#     215
#     216             # save the figure
# --> 217             figure.save(filename)
#     218         else:
#     219             LOG.error('Plotting files in the format "%s" is not supported!',
#
# c:\users\luka\documents\phd\pathpy3\pathpy\visualisations\fileformats\pdf.py in save(self, filename)
#      56     def save(self, filename: str) -> None:
#      57         """Save the file"""
# ---> 58         temp_dir, temp_file = self.compile()
#      59
#      60         # create temp file name
#
# c:\users\luka\documents\phd\pathpy3\pathpy\visualisations\fileformats\pdf.py in compile(self)
#     102             # If compiler does not exist, try next in the list
#     103             LOG.error('No latexmk compiler found')
# --> 104             raise AttributeError
#     105         finally:
#     106             # change back to the current directory
#
# AttributeError:

# %% [markdown]
# An interesting feature of pathpy is that it builds on the package `tikz-network`, a powerful framework to draw graphs in LaTeX. If we want to generate a visualisation in which we retain the full power to style the network in LaTeX, we can export the network as a tex file that can be build with a LaTeX compiler:

# %%
n.plot(**plot_style, layout=layout, filename='network.tex')
