# %% [markdown]
# TODOs:
#     - put harmonize node  names for visualizations
#     - solve issue with plotting to pdf

# %% [markdown]
# # P01 - 12: Visualising networks with `pathpy`
#
# **April 23 2020**
# *Ingo Scholtes*
#
# A key feature of `pathpy` is its support for custiumizable interactive visualisations that can be embedded in jupyter notebooks or stored as stand-alone files. In the following, we show this functionality in some toy exammples before moving to real data sets in the next unit. We first import `pathpy` as usual.

# %%
import pathpy as pp
import sqlite3
# Out:
#     <script charset="utf-8">
#     // Load via requireJS if available (jupyter notebook environment)
#     try {
#     require.config({
#     paths: {
#     d3: "https://d3js.org/d3.v5.min.js".replace(".js", "")
#     }
#     });
#     console.log("OKAY: requireJS was detected");
#     }
#     catch(err){
#     console.log(err);
#     console.log("ERROR: NO requireJS was detected");
#     };
#     require(['d3'], function(d3){
#     console.log("OKAY: d3js was detected");
#     });
#     </script>

# %% [markdown]
# ## Interactive network visualisation in `jupyter`
#
# We first create a simple toy example by adding two edges between three nodes.

# %%
n = pp.Network(directed=False)
n.add_edges(('a', 'b'), ('b', 'c'))
print(n)
# Out:
# Uid:			0x1b122f209a0
# Type:			Network
# Directed:		False
# Multi-Edges:		False
# Number of nodes:	3
# Number of edges:	2

# %% [markdown]
# Calling the `print` function on a network instance will generate a string representation that can be printed on the console. The simplest way to graphically visualise the network in a jupyter noteboo is to simply type the variable name of the network:

# %%
n
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x2f4234202fd54cf18c49be446d411716"></div>
# <div id="x0285d6f3c07a4c6c9b45c6e360c1713d"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 1200.0, "height": 1000.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": false, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "a", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "b", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "c", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}], "links": [{"uid": "0x1b122f20c40", "size": 2.0, "color": "black", "opacity": 1, "source": "a", "target": "b", "directed": true, "curved": 0.5}, {"uid": "0x1b122f20ee0", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "c", "directed": true, "curved": 0.5}]}
#
#  function tooltip(tooltipId, width){
#    // Local variable to hold tooltip div for
#    // manipulation in other functions.
#    var tt = d3.select('body')
#               .append('div')
#               .attr('class', 'tooltip')
#               .attr('id', tooltipId)
#               .style('pointer-events', 'none');
#
#    // Set a width if it is provided.
#    if (width) {
#      tt.style('width', width);
#    }
#
#    // Initially it is hidden.
#    hideTooltip();
#
#    /*
#     * Display tooltip with provided content.
#     * content is expected to be HTML string.
#     * event is d3.event for positioning.
#     */
#    function showTooltip(content, event) {
#      tt.style('opacity', 1.0)
#        .html(content);
#
#      updatePosition(event);
#    }
#
#    /*
#     * Hide the tooltip div.
#     */
#    function hideTooltip() {
#      tt.style('opacity', 0.0);
#    }
#
#    /*
#     * Figure out where to place the tooltip
#     * based on d3 mouse event.
#     */
#    function updatePosition(event) {
#      var xOffset = 20;
#      var yOffset = 10;
#
#      var ttw = tt.style('width');
#      var tth = tt.style('height');
#
#      var wscrY = window.scrollY;
#      var wscrX = window.scrollX;
#
#      var curX = (document.all) ? event.clientX + wscrX : event.pageX;
#      var curY = (document.all) ? event.clientY + wscrY : event.pageY;
#      var ttleft = ((curX - wscrX + xOffset * 2 + ttw) > window.innerWidth) ?
#                   curX - ttw - xOffset * 2 : curX + xOffset;
#
#      if (ttleft < wscrX + xOffset) {
#        ttleft = wscrX + xOffset;
#      }
#
#      var tttop = ((curY - wscrY + yOffset * 2 + tth) > window.innerHeight) ?
#                  curY - tth - yOffset * 2 : curY + yOffset;
#
#      if (tttop < wscrY + yOffset) {
#        tttop = curY + yOffset;
#      }
#
#      tt
#        .style('top', tttop + 'px')
#        .style('left', ttleft + 'px');
#    }
#
#    if (config.widgets.tooltip.enabled === true){
#      return {
#        showTooltip: showTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    } else {
#      return {
#        showTooltip: hideTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    };
#  };
#  /*
#   * network
#   */
#  function network(config){
#
#    // Constants for sizing
#    var width = config.width || 400;
#    var height = config.height || 400;
#    var temporal = config.temporal || false;
#    var tooltipSize = config.widgets.tooltip.size || '100px';
#
#
#    var labelCentered = config.label.centered || false;
#    var labelEnabled = config.label.enabled || false;
#    var labelColor = config.label.color || '#fff';
#
#    var curved = config.curved || false;
#    var directed = config.directed || false;
#
#    var radiusMinSize = config.radiusMinSize || 4;
#    var radiusMaxSize = config.radiusMaxS

# %% [markdown]
# This will create an interactive HTML visualisation of the network, where we can zoom, pan, and drag nodes. The same visualisation is generated if we explicitly call the function `plot` on the network instance. Try to zoom and pan the network (by holding the shift key and using the mouse/mouse wheel). Try what happens if you drag a node and release the mouse button. Try to search for a node with a specific uid or name:

# %%
n.plot()
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x5c7aafd0b50e4da38893b837bb74276f"></div>
# <div id="x8615c0e510ad42bcb976c773df6d2a0e"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 1200.0, "height": 1000.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": false, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "a", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "b", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "c", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}], "links": [{"uid": "0x1b122f20c40", "size": 2.0, "color": "black", "opacity": 1, "source": "a", "target": "b", "directed": true, "curved": 0.5}, {"uid": "0x1b122f20ee0", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "c", "directed": true, "curved": 0.5}]}
#
#  function tooltip(tooltipId, width){
#    // Local variable to hold tooltip div for
#    // manipulation in other functions.
#    var tt = d3.select('body')
#               .append('div')
#               .attr('class', 'tooltip')
#               .attr('id', tooltipId)
#               .style('pointer-events', 'none');
#
#    // Set a width if it is provided.
#    if (width) {
#      tt.style('width', width);
#    }
#
#    // Initially it is hidden.
#    hideTooltip();
#
#    /*
#     * Display tooltip with provided content.
#     * content is expected to be HTML string.
#     * event is d3.event for positioning.
#     */
#    function showTooltip(content, event) {
#      tt.style('opacity', 1.0)
#        .html(content);
#
#      updatePosition(event);
#    }
#
#    /*
#     * Hide the tooltip div.
#     */
#    function hideTooltip() {
#      tt.style('opacity', 0.0);
#    }
#
#    /*
#     * Figure out where to place the tooltip
#     * based on d3 mouse event.
#     */
#    function updatePosition(event) {
#      var xOffset = 20;
#      var yOffset = 10;
#
#      var ttw = tt.style('width');
#      var tth = tt.style('height');
#
#      var wscrY = window.scrollY;
#      var wscrX = window.scrollX;
#
#      var curX = (document.all) ? event.clientX + wscrX : event.pageX;
#      var curY = (document.all) ? event.clientY + wscrY : event.pageY;
#      var ttleft = ((curX - wscrX + xOffset * 2 + ttw) > window.innerWidth) ?
#                   curX - ttw - xOffset * 2 : curX + xOffset;
#
#      if (ttleft < wscrX + xOffset) {
#        ttleft = wscrX + xOffset;
#      }
#
#      var tttop = ((curY - wscrY + yOffset * 2 + tth) > window.innerHeight) ?
#                  curY - tth - yOffset * 2 : curY + yOffset;
#
#      if (tttop < wscrY + yOffset) {
#        tttop = curY + yOffset;
#      }
#
#      tt
#        .style('top', tttop + 'px')
#        .style('left', ttleft + 'px');
#    }
#
#    if (config.widgets.tooltip.enabled === true){
#      return {
#        showTooltip: showTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    } else {
#      return {
#        showTooltip: hideTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    };
#  };
#  /*
#   * network
#   */
#  function network(config){
#
#    // Constants for sizing
#    var width = config.width || 400;
#    var height = config.height || 400;
#    var temporal = config.temporal || false;
#    var tooltipSize = config.widgets.tooltip.size || '100px';
#
#
#    var labelCentered = config.label.centered || false;
#    var labelEnabled = config.label.enabled || false;
#    var labelColor = config.label.color || '#fff';
#
#    var curved = config.curved || false;
#    var directed = config.directed || false;
#
#    var radiusMinSize = config.radiusMinSize || 4;
#    var radiusMaxSize = config.radiusMaxS

# %% [markdown]
# Using the two top-left buttons in the visualisatin you can export the current view of the network as a SVG vector graphics or a PNG pixel graphics file. By default a default style is applied to the network but pathpy allows to fully style the network based on (i) node and edge attributes that are automatically considered in the visualisation, or (ii) a custom style dictionary that can be passed to the plot function. If we want to change the color of nodes we can simply assign a `color` attribute to the nodes:

# %%
n.nodes['a']['color'] = 'red'
n.nodes['b']['color'] = 'green'
n.nodes['c']['color'] = 'blue'
n.plot()
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x07a99a74c6de4d88bf5481d73c807e2c"></div>
# <div id="x86dabd0b60da4a478d1dbe565adbea50"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 1200.0, "height": 1000.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": false, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "a", "size": 15.0, "color": "red", "opacity": 0.2, "id_as_label": true}, {"uid": "b", "size": 15.0, "color": "green", "opacity": 0.2, "id_as_label": true}, {"uid": "c", "size": 15.0, "color": "blue", "opacity": 0.2, "id_as_label": true}], "links": [{"uid": "0x1b122f20c40", "size": 2.0, "color": "black", "opacity": 1, "source": "a", "target": "b", "directed": true, "curved": 0.5}, {"uid": "0x1b122f20ee0", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "c", "directed": true, "curved": 0.5}]}
#
#  function tooltip(tooltipId, width){
#    // Local variable to hold tooltip div for
#    // manipulation in other functions.
#    var tt = d3.select('body')
#               .append('div')
#               .attr('class', 'tooltip')
#               .attr('id', tooltipId)
#               .style('pointer-events', 'none');
#
#    // Set a width if it is provided.
#    if (width) {
#      tt.style('width', width);
#    }
#
#    // Initially it is hidden.
#    hideTooltip();
#
#    /*
#     * Display tooltip with provided content.
#     * content is expected to be HTML string.
#     * event is d3.event for positioning.
#     */
#    function showTooltip(content, event) {
#      tt.style('opacity', 1.0)
#        .html(content);
#
#      updatePosition(event);
#    }
#
#    /*
#     * Hide the tooltip div.
#     */
#    function hideTooltip() {
#      tt.style('opacity', 0.0);
#    }
#
#    /*
#     * Figure out where to place the tooltip
#     * based on d3 mouse event.
#     */
#    function updatePosition(event) {
#      var xOffset = 20;
#      var yOffset = 10;
#
#      var ttw = tt.style('width');
#      var tth = tt.style('height');
#
#      var wscrY = window.scrollY;
#      var wscrX = window.scrollX;
#
#      var curX = (document.all) ? event.clientX + wscrX : event.pageX;
#      var curY = (document.all) ? event.clientY + wscrY : event.pageY;
#      var ttleft = ((curX - wscrX + xOffset * 2 + ttw) > window.innerWidth) ?
#                   curX - ttw - xOffset * 2 : curX + xOffset;
#
#      if (ttleft < wscrX + xOffset) {
#        ttleft = wscrX + xOffset;
#      }
#
#      var tttop = ((curY - wscrY + yOffset * 2 + tth) > window.innerHeight) ?
#                  curY - tth - yOffset * 2 : curY + yOffset;
#
#      if (tttop < wscrY + yOffset) {
#        tttop = curY + yOffset;
#      }
#
#      tt
#        .style('top', tttop + 'px')
#        .style('left', ttleft + 'px');
#    }
#
#    if (config.widgets.tooltip.enabled === true){
#      return {
#        showTooltip: showTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    } else {
#      return {
#        showTooltip: hideTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    };
#  };
#  /*
#   * network
#   */
#  function network(config){
#
#    // Constants for sizing
#    var width = config.width || 400;
#    var height = config.height || 400;
#    var temporal = config.temporal || false;
#    var tooltipSize = config.widgets.tooltip.size || '100px';
#
#
#    var labelCentered = config.label.centered || false;
#    var labelEnabled = config.label.enabled || false;
#    var labelColor = config.label.color || '#fff';
#
#    var curved = config.curved || false;
#    var directed = config.directed || false;
#
#    var radiusMinSize = config.radiusMinSize || 4;
#    var radiusMaxSize = config.radiusMaxSize || 16;
#    // variables to

# %% [markdown]
# We can additionally change the size of the nodes as follows:

# %%
n.nodes['a']['size'] = 20
n.nodes['b']['size'] = 10
n.nodes['c']['size'] = 20
n.plot()
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x310bce0241b34a68818a4afd2ac7b1dc"></div>
# <div id="x8e07edac3fc44213a5b291c84c7d4e26"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 1200.0, "height": 1000.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": false, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "a", "size": 20.0, "color": "red", "opacity": 0.2, "id_as_label": true}, {"uid": "b", "size": 10.0, "color": "green", "opacity": 0.2, "id_as_label": true}, {"uid": "c", "size": 20.0, "color": "blue", "opacity": 0.2, "id_as_label": true}], "links": [{"uid": "0x1b122f20c40", "size": 2.0, "color": "black", "opacity": 1, "source": "a", "target": "b", "directed": true, "curved": 0.5}, {"uid": "0x1b122f20ee0", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "c", "directed": true, "curved": 0.5}]}
#
#  function tooltip(tooltipId, width){
#    // Local variable to hold tooltip div for
#    // manipulation in other functions.
#    var tt = d3.select('body')
#               .append('div')
#               .attr('class', 'tooltip')
#               .attr('id', tooltipId)
#               .style('pointer-events', 'none');
#
#    // Set a width if it is provided.
#    if (width) {
#      tt.style('width', width);
#    }
#
#    // Initially it is hidden.
#    hideTooltip();
#
#    /*
#     * Display tooltip with provided content.
#     * content is expected to be HTML string.
#     * event is d3.event for positioning.
#     */
#    function showTooltip(content, event) {
#      tt.style('opacity', 1.0)
#        .html(content);
#
#      updatePosition(event);
#    }
#
#    /*
#     * Hide the tooltip div.
#     */
#    function hideTooltip() {
#      tt.style('opacity', 0.0);
#    }
#
#    /*
#     * Figure out where to place the tooltip
#     * based on d3 mouse event.
#     */
#    function updatePosition(event) {
#      var xOffset = 20;
#      var yOffset = 10;
#
#      var ttw = tt.style('width');
#      var tth = tt.style('height');
#
#      var wscrY = window.scrollY;
#      var wscrX = window.scrollX;
#
#      var curX = (document.all) ? event.clientX + wscrX : event.pageX;
#      var curY = (document.all) ? event.clientY + wscrY : event.pageY;
#      var ttleft = ((curX - wscrX + xOffset * 2 + ttw) > window.innerWidth) ?
#                   curX - ttw - xOffset * 2 : curX + xOffset;
#
#      if (ttleft < wscrX + xOffset) {
#        ttleft = wscrX + xOffset;
#      }
#
#      var tttop = ((curY - wscrY + yOffset * 2 + tth) > window.innerHeight) ?
#                  curY - tth - yOffset * 2 : curY + yOffset;
#
#      if (tttop < wscrY + yOffset) {
#        tttop = curY + yOffset;
#      }
#
#      tt
#        .style('top', tttop + 'px')
#        .style('left', ttleft + 'px');
#    }
#
#    if (config.widgets.tooltip.enabled === true){
#      return {
#        showTooltip: showTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    } else {
#      return {
#        showTooltip: hideTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    };
#  };
#  /*
#   * network
#   */
#  function network(config){
#
#    // Constants for sizing
#    var width = config.width || 400;
#    var height = config.height || 400;
#    var temporal = config.temporal || false;
#    var tooltipSize = config.widgets.tooltip.size || '100px';
#
#
#    var labelCentered = config.label.centered || false;
#    var labelEnabled = config.label.enabled || false;
#    var labelColor = config.label.color || '#fff';
#
#    var curved = config.curved || false;
#    var directed = config.directed || false;
#
#    var radiusMinSize = config.radiusMinSize || 4;
#    var radiusMaxSize = config.radiusMaxSize || 16;
#    // variables to

# %% [markdown]
# An alternative method to style the network is by means of a key-value arguments with node and edge properties that are passed to the plot function. We can either assign the same property to all nodes, or we can assign different properties to different nodes based on a dictionary:

# %%
n.plot(node_color='red', node_size=10)
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x73e7d2015f2c4f9e9d034c18a1f962d5"></div>
# <div id="xcc3be78293384ae58433662e81a0f24b"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 1200.0, "height": 1000.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": false, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "a", "size": 10.0, "color": "red", "opacity": 0.2, "id_as_label": true}, {"uid": "b", "size": 10.0, "color": "red", "opacity": 0.2, "id_as_label": true}, {"uid": "c", "size": 10.0, "color": "red", "opacity": 0.2, "id_as_label": true}], "links": [{"uid": "0x1b122f20c40", "size": 2.0, "color": "black", "opacity": 1, "source": "a", "target": "b", "directed": true, "curved": 0.5}, {"uid": "0x1b122f20ee0", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "c", "directed": true, "curved": 0.5}]}
#
#  function tooltip(tooltipId, width){
#    // Local variable to hold tooltip div for
#    // manipulation in other functions.
#    var tt = d3.select('body')
#               .append('div')
#               .attr('class', 'tooltip')
#               .attr('id', tooltipId)
#               .style('pointer-events', 'none');
#
#    // Set a width if it is provided.
#    if (width) {
#      tt.style('width', width);
#    }
#
#    // Initially it is hidden.
#    hideTooltip();
#
#    /*
#     * Display tooltip with provided content.
#     * content is expected to be HTML string.
#     * event is d3.event for positioning.
#     */
#    function showTooltip(content, event) {
#      tt.style('opacity', 1.0)
#        .html(content);
#
#      updatePosition(event);
#    }
#
#    /*
#     * Hide the tooltip div.
#     */
#    function hideTooltip() {
#      tt.style('opacity', 0.0);
#    }
#
#    /*
#     * Figure out where to place the tooltip
#     * based on d3 mouse event.
#     */
#    function updatePosition(event) {
#      var xOffset = 20;
#      var yOffset = 10;
#
#      var ttw = tt.style('width');
#      var tth = tt.style('height');
#
#      var wscrY = window.scrollY;
#      var wscrX = window.scrollX;
#
#      var curX = (document.all) ? event.clientX + wscrX : event.pageX;
#      var curY = (document.all) ? event.clientY + wscrY : event.pageY;
#      var ttleft = ((curX - wscrX + xOffset * 2 + ttw) > window.innerWidth) ?
#                   curX - ttw - xOffset * 2 : curX + xOffset;
#
#      if (ttleft < wscrX + xOffset) {
#        ttleft = wscrX + xOffset;
#      }
#
#      var tttop = ((curY - wscrY + yOffset * 2 + tth) > window.innerHeight) ?
#                  curY - tth - yOffset * 2 : curY + yOffset;
#
#      if (tttop < wscrY + yOffset) {
#        tttop = curY + yOffset;
#      }
#
#      tt
#        .style('top', tttop + 'px')
#        .style('left', ttleft + 'px');
#    }
#
#    if (config.widgets.tooltip.enabled === true){
#      return {
#        showTooltip: showTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    } else {
#      return {
#        showTooltip: hideTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    };
#  };
#  /*
#   * network
#   */
#  function network(config){
#
#    // Constants for sizing
#    var width = config.width || 400;
#    var height = config.height || 400;
#    var temporal = config.temporal || false;
#    var tooltipSize = config.widgets.tooltip.size || '100px';
#
#
#    var labelCentered = config.label.centered || false;
#    var labelEnabled = config.label.enabled || false;
#    var labelColor = config.label.color || '#fff';
#
#    var curved = config.curved || false;
#    var directed = config.directed || false;
#
#    var radiusMinSize = config.radiusMinSize || 4;
#    var radiusMaxSize = config.radiusMaxSize || 16;
#    // variables to ref

# %%
n.plot(node_color={'a': 'green', 'b': 'blue', 'c': 'red'}, node_size={'a': 20, 'b': 10, 'c': 20})
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="xe2a353d596264ab793ee962cc0927476"></div>
# <div id="x263003779c5a4be5ac1ffa3f8db1b179"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 1200.0, "height": 1000.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": false, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "a", "size": 20.0, "color": "green", "opacity": 0.2, "id_as_label": true}, {"uid": "b", "size": 10.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "c", "size": 20.0, "color": "red", "opacity": 0.2, "id_as_label": true}], "links": [{"uid": "0x1b122f20c40", "size": 2.0, "color": "black", "opacity": 1, "source": "a", "target": "b", "directed": true, "curved": 0.5}, {"uid": "0x1b122f20ee0", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "c", "directed": true, "curved": 0.5}]}
#
#  function tooltip(tooltipId, width){
#    // Local variable to hold tooltip div for
#    // manipulation in other functions.
#    var tt = d3.select('body')
#               .append('div')
#               .attr('class', 'tooltip')
#               .attr('id', tooltipId)
#               .style('pointer-events', 'none');
#
#    // Set a width if it is provided.
#    if (width) {
#      tt.style('width', width);
#    }
#
#    // Initially it is hidden.
#    hideTooltip();
#
#    /*
#     * Display tooltip with provided content.
#     * content is expected to be HTML string.
#     * event is d3.event for positioning.
#     */
#    function showTooltip(content, event) {
#      tt.style('opacity', 1.0)
#        .html(content);
#
#      updatePosition(event);
#    }
#
#    /*
#     * Hide the tooltip div.
#     */
#    function hideTooltip() {
#      tt.style('opacity', 0.0);
#    }
#
#    /*
#     * Figure out where to place the tooltip
#     * based on d3 mouse event.
#     */
#    function updatePosition(event) {
#      var xOffset = 20;
#      var yOffset = 10;
#
#      var ttw = tt.style('width');
#      var tth = tt.style('height');
#
#      var wscrY = window.scrollY;
#      var wscrX = window.scrollX;
#
#      var curX = (document.all) ? event.clientX + wscrX : event.pageX;
#      var curY = (document.all) ? event.clientY + wscrY : event.pageY;
#      var ttleft = ((curX - wscrX + xOffset * 2 + ttw) > window.innerWidth) ?
#                   curX - ttw - xOffset * 2 : curX + xOffset;
#
#      if (ttleft < wscrX + xOffset) {
#        ttleft = wscrX + xOffset;
#      }
#
#      var tttop = ((curY - wscrY + yOffset * 2 + tth) > window.innerHeight) ?
#                  curY - tth - yOffset * 2 : curY + yOffset;
#
#      if (tttop < wscrY + yOffset) {
#        tttop = curY + yOffset;
#      }
#
#      tt
#        .style('top', tttop + 'px')
#        .style('left', ttleft + 'px');
#    }
#
#    if (config.widgets.tooltip.enabled === true){
#      return {
#        showTooltip: showTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    } else {
#      return {
#        showTooltip: hideTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    };
#  };
#  /*
#   * network
#   */
#  function network(config){
#
#    // Constants for sizing
#    var width = config.width || 400;
#    var height = config.height || 400;
#    var temporal = config.temporal || false;
#    var tooltipSize = config.widgets.tooltip.size || '100px';
#
#
#    var labelCentered = config.label.centered || false;
#    var labelEnabled = config.label.enabled || false;
#    var labelColor = config.label.color || '#fff';
#
#    var curved = config.curved || false;
#    var directed = config.directed || false;
#
#    var radiusMinSize = config.radiusMinSize || 4;
#    var radiusMaxSize = config.radiusMaxSize || 16;
#    // variables to

# %% [markdown]
# A better way to manage plot styles is to store all styles in a dictionary, whose entries are then passed to the plot function using the kwargs operator **. A major advantage of this is that we can store the plot style and apply the same style to multiple networks or to visualisations in multiple formats.

# %%
plot_style = {
    'node_color': {'a': 'orange', 'b': 'blue', 'c': 'red'}, 
    'node_size': {'a': 30, 'b': 10, 'c': 20}
}
n.plot(**plot_style)
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x8958cb6f83d64fad95c0236fa1b4321a"></div>
# <div id="x0dbb96fcbf474d7da4ff116de7f3713d"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 1200.0, "height": 1000.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": false, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "a", "size": 30.0, "color": "orange", "opacity": 0.2, "id_as_label": true}, {"uid": "b", "size": 10.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "c", "size": 20.0, "color": "red", "opacity": 0.2, "id_as_label": true}], "links": [{"uid": "0x1b122f20c40", "size": 2.0, "color": "black", "opacity": 1, "source": "a", "target": "b", "directed": true, "curved": 0.5}, {"uid": "0x1b122f20ee0", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "c", "directed": true, "curved": 0.5}]}
#
#  function tooltip(tooltipId, width){
#    // Local variable to hold tooltip div for
#    // manipulation in other functions.
#    var tt = d3.select('body')
#               .append('div')
#               .attr('class', 'tooltip')
#               .attr('id', tooltipId)
#               .style('pointer-events', 'none');
#
#    // Set a width if it is provided.
#    if (width) {
#      tt.style('width', width);
#    }
#
#    // Initially it is hidden.
#    hideTooltip();
#
#    /*
#     * Display tooltip with provided content.
#     * content is expected to be HTML string.
#     * event is d3.event for positioning.
#     */
#    function showTooltip(content, event) {
#      tt.style('opacity', 1.0)
#        .html(content);
#
#      updatePosition(event);
#    }
#
#    /*
#     * Hide the tooltip div.
#     */
#    function hideTooltip() {
#      tt.style('opacity', 0.0);
#    }
#
#    /*
#     * Figure out where to place the tooltip
#     * based on d3 mouse event.
#     */
#    function updatePosition(event) {
#      var xOffset = 20;
#      var yOffset = 10;
#
#      var ttw = tt.style('width');
#      var tth = tt.style('height');
#
#      var wscrY = window.scrollY;
#      var wscrX = window.scrollX;
#
#      var curX = (document.all) ? event.clientX + wscrX : event.pageX;
#      var curY = (document.all) ? event.clientY + wscrY : event.pageY;
#      var ttleft = ((curX - wscrX + xOffset * 2 + ttw) > window.innerWidth) ?
#                   curX - ttw - xOffset * 2 : curX + xOffset;
#
#      if (ttleft < wscrX + xOffset) {
#        ttleft = wscrX + xOffset;
#      }
#
#      var tttop = ((curY - wscrY + yOffset * 2 + tth) > window.innerHeight) ?
#                  curY - tth - yOffset * 2 : curY + yOffset;
#
#      if (tttop < wscrY + yOffset) {
#        tttop = curY + yOffset;
#      }
#
#      tt
#        .style('top', tttop + 'px')
#        .style('left', ttleft + 'px');
#    }
#
#    if (config.widgets.tooltip.enabled === true){
#      return {
#        showTooltip: showTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    } else {
#      return {
#        showTooltip: hideTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    };
#  };
#  /*
#   * network
#   */
#  function network(config){
#
#    // Constants for sizing
#    var width = config.width || 400;
#    var height = config.height || 400;
#    var temporal = config.temporal || false;
#    var tooltipSize = config.widgets.tooltip.size || '100px';
#
#
#    var labelCentered = config.label.centered || false;
#    var labelEnabled = config.label.enabled || false;
#    var labelColor = config.label.color || '#fff';
#
#    var curved = config.curved || false;
#    var directed = config.directed || false;
#
#    var radiusMinSize = config.radiusMinSize || 4;
#    var radiusMaxSize = config.radiusMaxSize || 16;
#    // variables to

# %% [markdown]
# In any case, the plot parameters passed explicitly to the plot function will take preference over any node or edge properties. To conclude this section, let us plot a few networks that we read from our database file.

# %%
con = sqlite3.connect('networks.db')
n = pp.io.sql.read_network(con=con, sql='SELECT source, target FROM lotr', directed=True, multiedges=False)
# n.plot(node_size=5)
# Out:
# [09-02 13:33:01: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Gollum,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Gollum,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Gandalf,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Gollum,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Gandalf,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Gandalf,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Gandalf,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Gandalf,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Gandalf,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Meriadoc,Peregrin) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Gandalf,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Gandalf,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Gandalf,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sméagol,Déagol) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sméagol,Déagol) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sméagol,Déagol) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Gollum) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Gollum) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Isildur,Elendil) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Gollum) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Gollum,Déagol) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Gollum,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Gandalf,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Gollum) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Gollum) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Bilbo,Gollum) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Gandalf,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Gandalf,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Gandalf,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Fredegar) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Merry,Fredegar) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Merry,Fredegar) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Lobelia,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Maggot,Pippin) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Maggot,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Maggot,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Maggot,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Maggot,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Tom,Goldberry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Tom,Goldberry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Tom,Goldberry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Tom,Goldberry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Tom,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Tom,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Gandalf,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Tom,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Tom,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Tom,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Tom,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Gandalf,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Tom,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Tom,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Tom,Goldberry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Tom,Goldberry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Butterbur,Barliman) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Butterbur,Barliman) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Nob,Butterbur) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Butterbur) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Nob,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Bob,Bill) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Nob,Butterbur) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Merry,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Nob,Bob) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Elendil,Gil-galad) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Merry,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Beren,Barahir) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Beren,Thingol) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Beren,Lúthien) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Beren,Thingol) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Lúthien,Thingol) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Beren,Thingol) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Beren,Lúthien) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Gandalf,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Glorfindel,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Glorfindel,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Glorfindel,Elrond) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Glorfindel,Elrond) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Gandalf,Elrond) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Glorfindel,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Glorfindel,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Glorfindel,Elrond) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Gandalf,Elrond) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Elrond) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Lúthien) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Elrond) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Elrond) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Gandalf,Elrond) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Glóin) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Glóin) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Arwen,Elrond) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Gandalf,Elrond) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Gandalf,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Arwen,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Elrond) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Gandalf,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Gandalf,Elrond) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Sam,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:01: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# ...
# [09-02 13:33:02: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Bill) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Frodo,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Merry,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Frodo,Lotho) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Frodo,Lotho) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Pippin,Lotho) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Tom,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Frodo,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Meriadoc,Peregrin) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Frodo,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Merry,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Gandalf,Saruman) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Saruman,Wormtongue) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Saruman,Wormtongue) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Frodo,Saruman) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Frodo,Saruman) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Saruman,Wormtongue) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Saruman,Wormtongue) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Frodo,Wormtongue) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Pippin,Fredegar) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Frodo,Lotho) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Meriadoc,Peregrin) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Bill) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Elrond,Galadriel) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Galadriel) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Elrond,Galadriel) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Galadriel,Elrond) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Frodo,Bilbo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Frodo,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Sam,Gandalf) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Pippin,Frodo) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Pippin,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Frodo,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Frodo,Galadriel) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Frodo,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Merry,Sam) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!
# [09-02 13:33:02: WARNING] The edge (Pippin,Merry) exist already and will not be considered. To capture this edge, please enalbe multiedges and/or directed!

# %%
n = pp.io.sql.read_network(filename='networks.db', table='gentoo', directed=True)
# n.plot(node_size=5)

# %%
n = pp.io.sql.read_network(filename='networks.db', table='highschool', directed=False, multiedges=True)
# n.plot(node_size=5)

# %% [markdown]
# ## Network Layouts
#
# An important question in the drawing of networks is where nodes are placed. The positioning of nodes determines whether it is easy to spot patterns in the topology of the network. As a general rule, good network visualisations should have a small number of crossing edges and nodes should be placed away from each other such that we can easily distinguish them. If we make no other effort, pathpy will automatically use a simple, interactive force-directed layout algorithm. It is based on the idea that nodes connected by an edge are moved towards each other by an attractive force, while an additional repulsive force between all node pairs makes sure that nodes are not drawn on top pf each other. The simulation of those forces, and the computation of a steady-state of the resulting many-particle system is what determines the node positions in the default pathpy visualisation. Also, this is the basis upon which nodes move if you disturb the visualisation by dragging around nodes.
#
# While the default layout algorithm makes it simple to visualise networks, it has the disadvantage that the layout is actually calculated in JavaScript. This means that the positions of nodes are actually not stored in python, which makes it impossible to influence (or store) node positions from python. To solve this issue, `pathpy` provides a `layout` module that can be used to precompute node positions based on different layout algorithms. Moreover, it allows to manually optimise the parameters of those algorithms to generate a nice visualisation.
#
# The styling of node positions via a layout style follows the same idea like the styling of plots via a plot style. We can store the parameters in a dictionary and pass them to the `layout` function using the ** operator. To compute ode positions based on a certain number of iterations of the Fruchterman-Reingold algorithm with a specific force value we can write:

# %%
layout_style = {}
layout_style["node_size"] = 2
layout_style['layout'] = 'Fruchterman-Reingold'
layout_style['force'] = 0.2
layout_style['iterations'] = 500
layout = pp.layout(n, **layout_style)
print(layout)
# Out:
# {'642': array([ 1.40912366, -0.88249697]), '480': array([ 6.30143746, -1.45778582]), '275': array([-0.09974692,  2.74767893]), '211': array([ 5.88205966, -1.89989751]), '265': array([-0.73041314,  1.33835093]), '79': array([ 5.58247468, -2.27824374]), '454': array([ 1.31262833, -1.41217893]), '151': array([ 0.65419406, -1.04147613]), '1485': array([-0.33488405, -0.74002764]), '478': array([-1.54800491,  2.00013664]), '502': array([ 0.8980091 , -0.57768055]), '165': array([-0.89031065,  2.48456898]), '122': array([0.07961542, 2.39238955]), '65': array([-1.46438203,  1.93793517]), '400': array([-0.53128721,  1.80295607]), '601': array([ 5.73545825, -1.97600874]), '255': array([0.15639601, 2
# %% [markdown]
# This computes a dictionary of node positions, where the node uids are the keys and two-dimensional coordinates are the values. We can now pass this specific layout to the plot function of the network. This will disable the interactive layout in JavaScript, fixing the node positions to the precalculated layout:

# %%
# pp.plot(n, **plot_style, layout=layout)

# %% [markdown]
# ## Plotting spatially embedded networks
#
# Layout algorithms are important to visualise networks where nodes are not naturally embedded in a space. However, for a number of complex networks we can naturally assign coordinates to nodes. Examples include infrastructure networks like road, train, or flight networks where we have information on geographic coordinates of road junctions, train stations, or airports. We do not need a layout algorithm to calculate node positions, we can use node coordinates instead, which we can assign to the node attributes:

# %%
n = pp.Network() # why do I get the node properties of the older n?

n.add_node("a")
n.add_node("b")
n.add_node("c")

n.add_edge("a", "b")
n.add_edge("b", "c")

n.nodes['a']['coordinates'] = [0,0]
n.nodes['b']['coordinates'] = [0,1]
n.nodes['c']['coordinates'] = [1,0]
n.plot(**plot_style)
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x1243d1cd05764217a33051c713e9d660"></div>
# <div id="xcbf8562e267c4b7f8ec9305002a95c04"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 1200.0, "height": 1000.0, "unit": "px", "dpi": 96, "margin": null, "layout": "euclidean", "temporal": false, "coordinates": true, "euclidean": true, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "curved": true, "directed": true, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": true, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "a", "size": 30.0, "color": "orange", "opacity": 0.2, "coordinates": [119.0, 981.0], "id_as_label": true}, {"uid": "b", "size": 10.0, "color": "blue", "opacity": 0.2, "coordinates": [119.0, 19.0], "id_as_label": true}, {"uid": "c", "size": 20.0, "color": "red", "opacity": 0.2, "coordinates": [1081.0, 981.0], "id_as_label": true}], "links": [{"uid": "0x1b1230cfd90", "size": 2.0, "color": "black", "opacity": 1, "source": "a", "target": "b", "directed": true, "curved": 0.5}, {"uid": "0x1b1230cf460", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "c", "directed": true, "curved": 0.5}]}
#
#  function tooltip(tooltipId, width){
#    // Local variable to hold tooltip div for
#    // manipulation in other functions.
#    var tt = d3.select('body')
#               .append('div')
#               .attr('class', 'tooltip')
#               .attr('id', tooltipId)
#               .style('pointer-events', 'none');
#
#    // Set a width if it is provided.
#    if (width) {
#      tt.style('width', width);
#    }
#
#    // Initially it is hidden.
#    hideTooltip();
#
#    /*
#     * Display tooltip with provided content.
#     * content is expected to be HTML string.
#     * event is d3.event for positioning.
#     */
#    function showTooltip(content, event) {
#      tt.style('opacity', 1.0)
#        .html(content);
#
#      updatePosition(event);
#    }
#
#    /*
#     * Hide the tooltip div.
#     */
#    function hideTooltip() {
#      tt.style('opacity', 0.0);
#    }
#
#    /*
#     * Figure out where to place the tooltip
#     * based on d3 mouse event.
#     */
#    function updatePosition(event) {
#      var xOffset = 20;
#      var yOffset = 10;
#
#      var ttw = tt.style('width');
#      var tth = tt.style('height');
#
#      var wscrY = window.scrollY;
#      var wscrX = window.scrollX;
#
#      var curX = (document.all) ? event.clientX + wscrX : event.pageX;
#      var curY = (document.all) ? event.clientY + wscrY : event.pageY;
#      var ttleft = ((curX - wscrX + xOffset * 2 + ttw) > window.innerWidth) ?
#                   curX - ttw - xOffset * 2 : curX + xOffset;
#
#      if (ttleft < wscrX + xOffset) {
#        ttleft = wscrX + xOffset;
#      }
#
#      var tttop = ((curY - wscrY + yOffset * 2 + tth) > window.innerHeight) ?
#                  curY - tth - yOffset * 2 : curY + yOffset;
#
#      if (tttop < wscrY + yOffset) {
#        tttop = curY + yOffset;
#      }
#
#      tt
#        .style('top', tttop + 'px')
#        .style('left', ttleft + 'px');
#    }
#
#    if (config.widgets.tooltip.enabled === true){
#      return {
#        showTooltip: showTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    } else {
#      return {
#        showTooltip: hideTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    };
#  };
#  /*
#   * network
#   */
#  function network(config){
#
#    // Constants for sizing
#    var width = config.width || 400;
#    var height = config.height || 400;
#    var temporal = config.temporal || false;
#    var tooltipSize = config.widgets.tooltip.size || '100px';
#
#
#    var labelCentered = config.label.centered || false;
#    var labelEnabled = config.label.enabled || false;
#    var labelColor = config.label.color || '#fff';
#
#    var curved = config.curved || false;
#    var directed = config.directed || false;
#
#    var radiusMinSize = conf

# %% [markdown]
# Like for other node attributes, specifying a layout for the network will override the node properties, i.e. in this case the node coordinates will be ignored:

# %% [markdown]
# ## Plotting networks to PDF
#
# While it is convenient to interactively plot networks in a jupyter network, we often want to generate stand-alone visualisations that we can either share or embed in scientific publications. Apart from the possibility to directly export PNG and SVG visualisations from the interactive HTML widget, the plot function can be used to generate a stand-alone HTML visualisation of the network that can be opened in any browser and shared on the Web.

# %%
n.plot( filename='network.html', **plot_style)

# %% [markdown]
# If you want a vector graphics figure that can be embedded in a scientific paper, you can use the plot function to export network visualisations as PDF:

# %%
n.plot(**plot_style,  filename='network.pdf') #layout=layout,
# Out:
# [09-02 13:33:44: ERROR] No latexmk compiler found
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# c:\users\vince\documents\external packages\pathpy\pathpy\visualisations\fileformats\pdf.py in compile(self)
#      99         try:
# --> 100             subprocess.check_output(command, stderr=subprocess.STDOUT)
#     101         except Exception:
#
# c:\users\vince\anaconda3\envs\devenv\lib\subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     410
# --> 411     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     412                **kwargs).stdout
#
# c:\users\vince\anaconda3\envs\devenv\lib\subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     511         if check and retcode:
# --> 512             raise CalledProcessError(retcode, process.args,
#     513                                      output=stdout, stderr=stderr)
#
# CalledProcessError: Command '['latexmk', '--pdf', '-shell-escape', '--interaction=nonstopmode', 'default.tex']' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-94170e991ea2> in <module>
# ----> 1 n.plot(  filename='network.pdf') #layout=layout,
#
# c:\users\vince\documents\external packages\pathpy\pathpy\visualisations\plot.py in plot(obj, filename, backend, **kwargs)
#     215
#     216             # save the figure
# --> 217             figure.save(filename)
#     218         else:
#     219             LOG.error('Plotting files in the format "%s" is not supported!',
#
# c:\users\vince\documents\external packages\pathpy\pathpy\visualisations\fileformats\pdf.py in save(self, filename)
#      56     def save(self, filename: str) -> None:
#      57         """Save the file"""
# ---> 58         temp_dir, temp_file = self.compile()
#      59
#      60         # create temp file name
#
# c:\users\vince\documents\external packages\pathpy\pathpy\visualisations\fileformats\pdf.py in compile(self)
#     102             # If compiler does not exist, try next in the list
#     103             LOG.error('No latexmk compiler found')
# --> 104             raise AttributeError
#     105         finally:
#     106             # change back to the current directory
#
# AttributeError:

# %% [markdown]
# An interesting feature of pathpy is that it builds on the package `tikz-network`, a powerful framework to draw graphs in LaTeX. If we want to generate a visualisation in which we retain the full power to style the network in LaTeX, we can export the network as a tex file that can be build with a LaTeX compiler:

# %%
n.plot(**plot_style, layout=layout, filename='network.tex')
