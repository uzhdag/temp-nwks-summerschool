# %% [markdown]
# TODOs:
#     - put harmonize node  names for visualizations
#     - solve issue with plotting to pdf

# %% [markdown]
# # P01 - 12: Visualising networks with `pathpy`
#
# **April 23 2020**
# *Ingo Scholtes*
#
# A key feature of `pathpy` is its support for custiumizable interactive visualisations that can be embedded in jupyter notebooks or stored as stand-alone files. In the following, we show this functionality in some toy exammples before moving to real data sets in the next unit. We first import `pathpy` as usual.

# %%
import pathpy as pp
import sqlite3
# Out:
#     <script charset="utf-8">
#     // Load via requireJS if available (jupyter notebook environment)
#     try {
#     require.config({
#     paths: {
#     d3: "https://d3js.org/d3.v5.min.js".replace(".js", "")
#     }
#     });
#     console.log("OKAY: requireJS was detected");
#     }
#     catch(err){
#     console.log(err);
#     console.log("ERROR: NO requireJS was detected");
#     };
#     require(['d3'], function(d3){
#     console.log("OKAY: d3js was detected");
#     });
#     </script>

# %% [markdown]
# ## Interactive network visualisation in `jupyter`
#
# We first create a simple toy example by adding two edges between three nodes.

# %%
n = pp.Network(directed=False)
n.add_edges(('a', 'b'), ('b', 'c'))
print(n)
# Out:
# Uid:			0x260a0b7f820
# Type:			Network
# Directed:		False
# Multi-Edges:		False
# Number of nodes:	3
# Number of edges:	2

# %% [markdown]
# Calling the `print` function on a network instance will generate a string representation that can be printed on the console. The simplest way to graphically visualise the network in a jupyter noteboo is to simply type the variable name of the network:

# %%
n
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="xe85037ff13594368b88f898971454dfd"></div>
# <div id="x8c1fa9ef0072458d99c7ed0211b9e9d9"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 1200.0, "height": 1000.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": false, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "a", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "b", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "c", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}], "links": [{"uid": "0x260a0b7fac0", "size": 2.0, "color": "black", "opacity": 1, "source": "a", "target": "b", "directed": true, "curved": 0.5}, {"uid": "0x260a0b7fd00", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "c", "directed": true, "curved": 0.5}]}
#
#  function tooltip(tooltipId, width){
#    // Local variable to hold tooltip div for
#    // manipulation in other functions.
#    var tt = d3.select('body')
#               .append('div')
#               .attr('class', 'tooltip')
#               .attr('id', tooltipId)
#               .style('pointer-events', 'none');
#
#    // Set a width if it is provided.
#    if (width) {
#      tt.style('width', width);
#    }
#
#    // Initially it is hidden.
#    hideTooltip();
#
#    /*
#     * Display tooltip with provided content.
#     * content is expected to be HTML string.
#     * event is d3.event for positioning.
#     */
#    function showTooltip(content, event) {
#      tt.style('opacity', 1.0)
#        .html(content);
#
#      updatePosition(event);
#    }
#
#    /*
#     * Hide the tooltip div.
#     */
#    function hideTooltip() {
#      tt.style('opacity', 0.0);
#    }
#
#    /*
#     * Figure out where to place the tooltip
#     * based on d3 mouse event.
#     */
#    function updatePosition(event) {
#      var xOffset = 20;
#      var yOffset = 10;
#
#      var ttw = tt.style('width');
#      var tth = tt.style('height');
#
#      var wscrY = window.scrollY;
#      var wscrX = window.scrollX;
#
#      var curX = (document.all) ? event.clientX + wscrX : event.pageX;
#      var curY = (document.all) ? event.clientY + wscrY : event.pageY;
#      var ttleft = ((curX - wscrX + xOffset * 2 + ttw) > window.innerWidth) ?
#                   curX - ttw - xOffset * 2 : curX + xOffset;
#
#      if (ttleft < wscrX + xOffset) {
#        ttleft = wscrX + xOffset;
#      }
#
#      var tttop = ((curY - wscrY + yOffset * 2 + tth) > window.innerHeight) ?
#                  curY - tth - yOffset * 2 : curY + yOffset;
#
#      if (tttop < wscrY + yOffset) {
#        tttop = curY + yOffset;
#      }
#
#      tt
#        .style('top', tttop + 'px')
#        .style('left', ttleft + 'px');
#    }
#
#    if (config.widgets.tooltip.enabled === true){
#      return {
#        showTooltip: showTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    } else {
#      return {
#        showTooltip: hideTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    };
#  };
#  /*
#   * network
#   */
#  function network(config){
#
#    // Constants for sizing
#    var width = config.width || 400;
#    var height = config.height || 400;
#    var temporal = config.temporal || false;
#    var tooltipSize = config.widgets.tooltip.size || '100px';
#
#
#    var labelCentered = config.label.centered || false;
#    var labelEnabled = config.label.enabled || false;
#    var labelColor = config.label.color || '#fff';
#
#    var curved = config.curved || false;
#    var directed = config.directed || false;
#
#    var radiusMinSize = config.radiusMinSize || 4;
#    var radiusMaxSize = config.radiusMaxS

# %% [markdown]
# This will create an interactive HTML visualisation of the network, where we can zoom, pan, and drag nodes. The same visualisation is generated if we explicitly call the function `plot` on the network instance. Try to zoom and pan the network (by holding the shift key and using the mouse/mouse wheel). Try what happens if you drag a node and release the mouse button. Try to search for a node with a specific uid or name:

# %%
n.plot()
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x0dd832bc56d948e5938b6cc105188b30"></div>
# <div id="x545d6cfbc8874071a3c630d847ef3445"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 1200.0, "height": 1000.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": false, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "a", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "b", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}, {"uid": "c", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "id_as_label": true}], "links": [{"uid": "0x260a0b7fac0", "size": 2.0, "color": "black", "opacity": 1, "source": "a", "target": "b", "directed": true, "curved": 0.5}, {"uid": "0x260a0b7fd00", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "c", "directed": true, "curved": 0.5}]}
#
#  function tooltip(tooltipId, width){
#    // Local variable to hold tooltip div for
#    // manipulation in other functions.
#    var tt = d3.select('body')
#               .append('div')
#               .attr('class', 'tooltip')
#               .attr('id', tooltipId)
#               .style('pointer-events', 'none');
#
#    // Set a width if it is provided.
#    if (width) {
#      tt.style('width', width);
#    }
#
#    // Initially it is hidden.
#    hideTooltip();
#
#    /*
#     * Display tooltip with provided content.
#     * content is expected to be HTML string.
#     * event is d3.event for positioning.
#     */
#    function showTooltip(content, event) {
#      tt.style('opacity', 1.0)
#        .html(content);
#
#      updatePosition(event);
#    }
#
#    /*
#     * Hide the tooltip div.
#     */
#    function hideTooltip() {
#      tt.style('opacity', 0.0);
#    }
#
#    /*
#     * Figure out where to place the tooltip
#     * based on d3 mouse event.
#     */
#    function updatePosition(event) {
#      var xOffset = 20;
#      var yOffset = 10;
#
#      var ttw = tt.style('width');
#      var tth = tt.style('height');
#
#      var wscrY = window.scrollY;
#      var wscrX = window.scrollX;
#
#      var curX = (document.all) ? event.clientX + wscrX : event.pageX;
#      var curY = (document.all) ? event.clientY + wscrY : event.pageY;
#      var ttleft = ((curX - wscrX + xOffset * 2 + ttw) > window.innerWidth) ?
#                   curX - ttw - xOffset * 2 : curX + xOffset;
#
#      if (ttleft < wscrX + xOffset) {
#        ttleft = wscrX + xOffset;
#      }
#
#      var tttop = ((curY - wscrY + yOffset * 2 + tth) > window.innerHeight) ?
#                  curY - tth - yOffset * 2 : curY + yOffset;
#
#      if (tttop < wscrY + yOffset) {
#        tttop = curY + yOffset;
#      }
#
#      tt
#        .style('top', tttop + 'px')
#        .style('left', ttleft + 'px');
#    }
#
#    if (config.widgets.tooltip.enabled === true){
#      return {
#        showTooltip: showTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    } else {
#      return {
#        showTooltip: hideTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    };
#  };
#  /*
#   * network
#   */
#  function network(config){
#
#    // Constants for sizing
#    var width = config.width || 400;
#    var height = config.height || 400;
#    var temporal = config.temporal || false;
#    var tooltipSize = config.widgets.tooltip.size || '100px';
#
#
#    var labelCentered = config.label.centered || false;
#    var labelEnabled = config.label.enabled || false;
#    var labelColor = config.label.color || '#fff';
#
#    var curved = config.curved || false;
#    var directed = config.directed || false;
#
#    var radiusMinSize = config.radiusMinSize || 4;
#    var radiusMaxSize = config.radiusMaxS

# %% [markdown]
# Using the two top-left buttons in the visualisatin you can export the current view of the network as a SVG vector graphics or a PNG pixel graphics file. By default a default style is applied to the network but pathpy allows to fully style the network based on (i) node and edge attributes that are automatically considered in the visualisation, or (ii) a custom style dictionary that can be passed to the plot function. If we want to change the color of nodes we can simply assign a `color` attribute to the nodes:

# %%
n.nodes['a']['color'] = 'red'
n.nodes['b']['color'] = 'green'
n.nodes['c']['color'] = 'blue'
n.plot()
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="xf21732e73f384e00a49d1772b8ac5f32"></div>
# <div id="x192f71b2e10048918a8834af54c27425"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 1200.0, "height": 1000.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": false, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "a", "size": 15.0, "color": "red", "opacity": 0.2, "id_as_label": true}, {"uid": "b", "size": 15.0, "color": "green", "opacity": 0.2, "id_as_label": true}, {"uid": "c", "size": 15.0, "color": "blue", "opacity": 0.2, "id_as_label": true}], "links": [{"uid": "0x260a0b7fac0", "size": 2.0, "color": "black", "opacity": 1, "source": "a", "target": "b", "directed": true, "curved": 0.5}, {"uid": "0x260a0b7fd00", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "c", "directed": true, "curved": 0.5}]}
#
#  function tooltip(tooltipId, width){
#    // Local variable to hold tooltip div for
#    // manipulation in other functions.
#    var tt = d3.select('body')
#               .append('div')
#               .attr('class', 'tooltip')
#               .attr('id', tooltipId)
#               .style('pointer-events', 'none');
#
#    // Set a width if it is provided.
#    if (width) {
#      tt.style('width', width);
#    }
#
#    // Initially it is hidden.
#    hideTooltip();
#
#    /*
#     * Display tooltip with provided content.
#     * content is expected to be HTML string.
#     * event is d3.event for positioning.
#     */
#    function showTooltip(content, event) {
#      tt.style('opacity', 1.0)
#        .html(content);
#
#      updatePosition(event);
#    }
#
#    /*
#     * Hide the tooltip div.
#     */
#    function hideTooltip() {
#      tt.style('opacity', 0.0);
#    }
#
#    /*
#     * Figure out where to place the tooltip
#     * based on d3 mouse event.
#     */
#    function updatePosition(event) {
#      var xOffset = 20;
#      var yOffset = 10;
#
#      var ttw = tt.style('width');
#      var tth = tt.style('height');
#
#      var wscrY = window.scrollY;
#      var wscrX = window.scrollX;
#
#      var curX = (document.all) ? event.clientX + wscrX : event.pageX;
#      var curY = (document.all) ? event.clientY + wscrY : event.pageY;
#      var ttleft = ((curX - wscrX + xOffset * 2 + ttw) > window.innerWidth) ?
#                   curX - ttw - xOffset * 2 : curX + xOffset;
#
#      if (ttleft < wscrX + xOffset) {
#        ttleft = wscrX + xOffset;
#      }
#
#      var tttop = ((curY - wscrY + yOffset * 2 + tth) > window.innerHeight) ?
#                  curY - tth - yOffset * 2 : curY + yOffset;
#
#      if (tttop < wscrY + yOffset) {
#        tttop = curY + yOffset;
#      }
#
#      tt
#        .style('top', tttop + 'px')
#        .style('left', ttleft + 'px');
#    }
#
#    if (config.widgets.tooltip.enabled === true){
#      return {
#        showTooltip: showTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    } else {
#      return {
#        showTooltip: hideTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    };
#  };
#  /*
#   * network
#   */
#  function network(config){
#
#    // Constants for sizing
#    var width = config.width || 400;
#    var height = config.height || 400;
#    var temporal = config.temporal || false;
#    var tooltipSize = config.widgets.tooltip.size || '100px';
#
#
#    var labelCentered = config.label.centered || false;
#    var labelEnabled = config.label.enabled || false;
#    var labelColor = config.label.color || '#fff';
#
#    var curved = config.curved || false;
#    var directed = config.directed || false;
#
#    var radiusMinSize = config.radiusMinSize || 4;
#    var radiusMaxSize = config.radiusMaxSize || 16;
#    // variables to

# %% [markdown]
# We can additionally change the size of the nodes as follows:

# %%
n.nodes['a']['size'] = 20
n.nodes['b']['size'] = 10
n.nodes['c']['size'] = 20
n.plot()
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="xca69474456ca4a8e881500d6dcd6fae6"></div>
# <div id="x3296fea926db4f60a9856fde9a8b4df5"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 1200.0, "height": 1000.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": false, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "a", "size": 20.0, "color": "red", "opacity": 0.2, "id_as_label": true}, {"uid": "b", "size": 10.0, "color": "green", "opacity": 0.2, "id_as_label": true}, {"uid": "c", "size": 20.0, "color": "blue", "opacity": 0.2, "id_as_label": true}], "links": [{"uid": "0x260a0b7fac0", "size": 2.0, "color": "black", "opacity": 1, "source": "a", "target": "b", "directed": true, "curved": 0.5}, {"uid": "0x260a0b7fd00", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "c", "directed": true, "curved": 0.5}]}
#
#  function tooltip(tooltipId, width){
#    // Local variable to hold tooltip div for
#    // manipulation in other functions.
#    var tt = d3.select('body')
#               .append('div')
#               .attr('class', 'tooltip')
#               .attr('id', tooltipId)
#               .style('pointer-events', 'none');
#
#    // Set a width if it is provided.
#    if (width) {
#      tt.style('width', width);
#    }
#
#    // Initially it is hidden.
#    hideTooltip();
#
#    /*
#     * Display tooltip with provided content.
#     * content is expected to be HTML string.
#     * event is d3.event for positioning.
#     */
#    function showTooltip(content, event) {
#      tt.style('opacity', 1.0)
#        .html(content);
#
#      updatePosition(event);
#    }
#
#    /*
#     * Hide the tooltip div.
#     */
#    function hideTooltip() {
#      tt.style('opacity', 0.0);
#    }
#
#    /*
#     * Figure out where to place the tooltip
#     * based on d3 mouse event.
#     */
#    function updatePosition(event) {
#      var xOffset = 20;
#      var yOffset = 10;
#
#      var ttw = tt.style('width');
#      var tth = tt.style('height');
#
#      var wscrY = window.scrollY;
#      var wscrX = window.scrollX;
#
#      var curX = (document.all) ? event.clientX + wscrX : event.pageX;
#      var curY = (document.all) ? event.clientY + wscrY : event.pageY;
#      var ttleft = ((curX - wscrX + xOffset * 2 + ttw) > window.innerWidth) ?
#                   curX - ttw - xOffset * 2 : curX + xOffset;
#
#      if (ttleft < wscrX + xOffset) {
#        ttleft = wscrX + xOffset;
#      }
#
#      var tttop = ((curY - wscrY + yOffset * 2 + tth) > window.innerHeight) ?
#                  curY - tth - yOffset * 2 : curY + yOffset;
#
#      if (tttop < wscrY + yOffset) {
#        tttop = curY + yOffset;
#      }
#
#      tt
#        .style('top', tttop + 'px')
#        .style('left', ttleft + 'px');
#    }
#
#    if (config.widgets.tooltip.enabled === true){
#      return {
#        showTooltip: showTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    } else {
#      return {
#        showTooltip: hideTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    };
#  };
#  /*
#   * network
#   */
#  function network(config){
#
#    // Constants for sizing
#    var width = config.width || 400;
#    var height = config.height || 400;
#    var temporal = config.temporal || false;
#    var tooltipSize = config.widgets.tooltip.size || '100px';
#
#
#    var labelCentered = config.label.centered || false;
#    var labelEnabled = config.label.enabled || false;
#    var labelColor = config.label.color || '#fff';
#
#    var curved = config.curved || false;
#    var directed = config.directed || false;
#
#    var radiusMinSize = config.radiusMinSize || 4;
#    var radiusMaxSize = config.radiusMaxSize || 16;
#    // variables to

# %% [markdown]
# An alternative method to style the network is by means of a key-value arguments with node and edge properties that are passed to the plot function. We can either assign the same property to all nodes, or we can assign different properties to different nodes based on a dictionary:

# %%
n.plot(node_color='red', node_size=10)
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x036b483167264c3585ae4fce62fafedf"></div>
# <div id="x819b6d55917b4c75b4852ab9bbdf6fe0"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 1200.0, "height": 1000.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": false, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "a", "size": 10.0, "color": "red", "opacity": 0.2, "id_as_label": true}, {"uid": "b", "size": 10.0, "color": "red", "opacity": 0.2, "id_as_label": true}, {"uid": "c", "size": 10.0, "color": "red", "opacity": 0.2, "id_as_label": true}], "links": [{"uid": "0x260a0b7fac0", "size": 2.0, "color": "black", "opacity": 1, "source": "a", "target": "b", "directed": true, "curved": 0.5}, {"uid": "0x260a0b7fd00", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "c", "directed": true, "curved": 0.5}]}
#
#  function tooltip(tooltipId, width){
#    // Local variable to hold tooltip div for
#    // manipulation in other functions.
#    var tt = d3.select('body')
#               .append('div')
#               .attr('class', 'tooltip')
#               .attr('id', tooltipId)
#               .style('pointer-events', 'none');
#
#    // Set a width if it is provided.
#    if (width) {
#      tt.style('width', width);
#    }
#
#    // Initially it is hidden.
#    hideTooltip();
#
#    /*
#     * Display tooltip with provided content.
#     * content is expected to be HTML string.
#     * event is d3.event for positioning.
#     */
#    function showTooltip(content, event) {
#      tt.style('opacity', 1.0)
#        .html(content);
#
#      updatePosition(event);
#    }
#
#    /*
#     * Hide the tooltip div.
#     */
#    function hideTooltip() {
#      tt.style('opacity', 0.0);
#    }
#
#    /*
#     * Figure out where to place the tooltip
#     * based on d3 mouse event.
#     */
#    function updatePosition(event) {
#      var xOffset = 20;
#      var yOffset = 10;
#
#      var ttw = tt.style('width');
#      var tth = tt.style('height');
#
#      var wscrY = window.scrollY;
#      var wscrX = window.scrollX;
#
#      var curX = (document.all) ? event.clientX + wscrX : event.pageX;
#      var curY = (document.all) ? event.clientY + wscrY : event.pageY;
#      var ttleft = ((curX - wscrX + xOffset * 2 + ttw) > window.innerWidth) ?
#                   curX - ttw - xOffset * 2 : curX + xOffset;
#
#      if (ttleft < wscrX + xOffset) {
#        ttleft = wscrX + xOffset;
#      }
#
#      var tttop = ((curY - wscrY + yOffset * 2 + tth) > window.innerHeight) ?
#                  curY - tth - yOffset * 2 : curY + yOffset;
#
#      if (tttop < wscrY + yOffset) {
#        tttop = curY + yOffset;
#      }
#
#      tt
#        .style('top', tttop + 'px')
#        .style('left', ttleft + 'px');
#    }
#
#    if (config.widgets.tooltip.enabled === true){
#      return {
#        showTooltip: showTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    } else {
#      return {
#        showTooltip: hideTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    };
#  };
#  /*
#   * network
#   */
#  function network(config){
#
#    // Constants for sizing
#    var width = config.width || 400;
#    var height = config.height || 400;
#    var temporal = config.temporal || false;
#    var tooltipSize = config.widgets.tooltip.size || '100px';
#
#
#    var labelCentered = config.label.centered || false;
#    var labelEnabled = config.label.enabled || false;
#    var labelColor = config.label.color || '#fff';
#
#    var curved = config.curved || false;
#    var directed = config.directed || false;
#
#    var radiusMinSize = config.radiusMinSize || 4;
#    var radiusMaxSize = config.radiusMaxSize || 16;
#    // variables to ref

# %%
n.plot(node_color={'a': 'green', 'b': 'blue', 'c': 'red'}, node_size={'a': 20, 'b': 10, 'c': 20})
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="xfa7f53d2b30f4efa95432d968d8129a5"></div>
# <div id="x03bc1d0cd1e941058812d408e940a199"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 1200.0, "height": 1000.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": false, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "a", "size": 20.0, "color": "green", "opacity": 0.2, "id_as_label": true}, {"uid": "b", "size": 10.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "c", "size": 20.0, "color": "red", "opacity": 0.2, "id_as_label": true}], "links": [{"uid": "0x260a0b7fac0", "size": 2.0, "color": "black", "opacity": 1, "source": "a", "target": "b", "directed": true, "curved": 0.5}, {"uid": "0x260a0b7fd00", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "c", "directed": true, "curved": 0.5}]}
#
#  function tooltip(tooltipId, width){
#    // Local variable to hold tooltip div for
#    // manipulation in other functions.
#    var tt = d3.select('body')
#               .append('div')
#               .attr('class', 'tooltip')
#               .attr('id', tooltipId)
#               .style('pointer-events', 'none');
#
#    // Set a width if it is provided.
#    if (width) {
#      tt.style('width', width);
#    }
#
#    // Initially it is hidden.
#    hideTooltip();
#
#    /*
#     * Display tooltip with provided content.
#     * content is expected to be HTML string.
#     * event is d3.event for positioning.
#     */
#    function showTooltip(content, event) {
#      tt.style('opacity', 1.0)
#        .html(content);
#
#      updatePosition(event);
#    }
#
#    /*
#     * Hide the tooltip div.
#     */
#    function hideTooltip() {
#      tt.style('opacity', 0.0);
#    }
#
#    /*
#     * Figure out where to place the tooltip
#     * based on d3 mouse event.
#     */
#    function updatePosition(event) {
#      var xOffset = 20;
#      var yOffset = 10;
#
#      var ttw = tt.style('width');
#      var tth = tt.style('height');
#
#      var wscrY = window.scrollY;
#      var wscrX = window.scrollX;
#
#      var curX = (document.all) ? event.clientX + wscrX : event.pageX;
#      var curY = (document.all) ? event.clientY + wscrY : event.pageY;
#      var ttleft = ((curX - wscrX + xOffset * 2 + ttw) > window.innerWidth) ?
#                   curX - ttw - xOffset * 2 : curX + xOffset;
#
#      if (ttleft < wscrX + xOffset) {
#        ttleft = wscrX + xOffset;
#      }
#
#      var tttop = ((curY - wscrY + yOffset * 2 + tth) > window.innerHeight) ?
#                  curY - tth - yOffset * 2 : curY + yOffset;
#
#      if (tttop < wscrY + yOffset) {
#        tttop = curY + yOffset;
#      }
#
#      tt
#        .style('top', tttop + 'px')
#        .style('left', ttleft + 'px');
#    }
#
#    if (config.widgets.tooltip.enabled === true){
#      return {
#        showTooltip: showTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    } else {
#      return {
#        showTooltip: hideTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    };
#  };
#  /*
#   * network
#   */
#  function network(config){
#
#    // Constants for sizing
#    var width = config.width || 400;
#    var height = config.height || 400;
#    var temporal = config.temporal || false;
#    var tooltipSize = config.widgets.tooltip.size || '100px';
#
#
#    var labelCentered = config.label.centered || false;
#    var labelEnabled = config.label.enabled || false;
#    var labelColor = config.label.color || '#fff';
#
#    var curved = config.curved || false;
#    var directed = config.directed || false;
#
#    var radiusMinSize = config.radiusMinSize || 4;
#    var radiusMaxSize = config.radiusMaxSize || 16;
#    // variables to

# %% [markdown]
# A better way to manage plot styles is to store all styles in a dictionary, whose entries are then passed to the plot function using the kwargs operator **. A major advantage of this is that we can store the plot style and apply the same style to multiple networks or to visualisations in multiple formats.

# %%
plot_style = {
    'node_color': {'a': 'orange', 'b': 'blue', 'c': 'red'}, 
    'node_size': {'a': 30, 'b': 10, 'c': 20}
}
n.plot(**plot_style)
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x3faef6e075694a0285467f98338f1873"></div>
# <div id="x4547a81f1a1a46b1bdc4f371dd302ed2"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 1200.0, "height": 1000.0, "unit": "px", "dpi": 96, "margin": null, "layout": "force", "temporal": false, "coordinates": false, "euclidean": false, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": false, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "a", "size": 30.0, "color": "orange", "opacity": 0.2, "id_as_label": true}, {"uid": "b", "size": 10.0, "color": "blue", "opacity": 0.2, "id_as_label": true}, {"uid": "c", "size": 20.0, "color": "red", "opacity": 0.2, "id_as_label": true}], "links": [{"uid": "0x260a0b7fac0", "size": 2.0, "color": "black", "opacity": 1, "source": "a", "target": "b", "directed": true, "curved": 0.5}, {"uid": "0x260a0b7fd00", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "c", "directed": true, "curved": 0.5}]}
#
#  function tooltip(tooltipId, width){
#    // Local variable to hold tooltip div for
#    // manipulation in other functions.
#    var tt = d3.select('body')
#               .append('div')
#               .attr('class', 'tooltip')
#               .attr('id', tooltipId)
#               .style('pointer-events', 'none');
#
#    // Set a width if it is provided.
#    if (width) {
#      tt.style('width', width);
#    }
#
#    // Initially it is hidden.
#    hideTooltip();
#
#    /*
#     * Display tooltip with provided content.
#     * content is expected to be HTML string.
#     * event is d3.event for positioning.
#     */
#    function showTooltip(content, event) {
#      tt.style('opacity', 1.0)
#        .html(content);
#
#      updatePosition(event);
#    }
#
#    /*
#     * Hide the tooltip div.
#     */
#    function hideTooltip() {
#      tt.style('opacity', 0.0);
#    }
#
#    /*
#     * Figure out where to place the tooltip
#     * based on d3 mouse event.
#     */
#    function updatePosition(event) {
#      var xOffset = 20;
#      var yOffset = 10;
#
#      var ttw = tt.style('width');
#      var tth = tt.style('height');
#
#      var wscrY = window.scrollY;
#      var wscrX = window.scrollX;
#
#      var curX = (document.all) ? event.clientX + wscrX : event.pageX;
#      var curY = (document.all) ? event.clientY + wscrY : event.pageY;
#      var ttleft = ((curX - wscrX + xOffset * 2 + ttw) > window.innerWidth) ?
#                   curX - ttw - xOffset * 2 : curX + xOffset;
#
#      if (ttleft < wscrX + xOffset) {
#        ttleft = wscrX + xOffset;
#      }
#
#      var tttop = ((curY - wscrY + yOffset * 2 + tth) > window.innerHeight) ?
#                  curY - tth - yOffset * 2 : curY + yOffset;
#
#      if (tttop < wscrY + yOffset) {
#        tttop = curY + yOffset;
#      }
#
#      tt
#        .style('top', tttop + 'px')
#        .style('left', ttleft + 'px');
#    }
#
#    if (config.widgets.tooltip.enabled === true){
#      return {
#        showTooltip: showTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    } else {
#      return {
#        showTooltip: hideTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    };
#  };
#  /*
#   * network
#   */
#  function network(config){
#
#    // Constants for sizing
#    var width = config.width || 400;
#    var height = config.height || 400;
#    var temporal = config.temporal || false;
#    var tooltipSize = config.widgets.tooltip.size || '100px';
#
#
#    var labelCentered = config.label.centered || false;
#    var labelEnabled = config.label.enabled || false;
#    var labelColor = config.label.color || '#fff';
#
#    var curved = config.curved || false;
#    var directed = config.directed || false;
#
#    var radiusMinSize = config.radiusMinSize || 4;
#    var radiusMaxSize = config.radiusMaxSize || 16;
#    // variables to

# %% [markdown]
# In any case, the plot parameters passed explicitly to the plot function will take preference over any node or edge properties. To conclude this section, let us plot a few networks that we read from our database file.

# %%
con = sqlite3.connect('networks.db')
n = pp.io.sql.read_network(con=con, sql='SELECT source, target FROM lotr', directed=True, multiedges=True)
# n.plot(node_size=5)

# %%
n = pp.io.sql.read_network(filename='networks.db', table='gentoo', directed=True)
# n.plot(node_size=5)

# %%
n = pp.io.sql.read_network(filename='networks.db', table='highschool', directed=False, multiedges=True)
# n.plot(node_size=5)

# %% [markdown]
# ## Network Layouts
#
# An important question in the drawing of networks is where nodes are placed. The positioning of nodes determines whether it is easy to spot patterns in the topology of the network. As a general rule, good network visualisations should have a small number of crossing edges and nodes should be placed away from each other such that we can easily distinguish them. If we make no other effort, pathpy will automatically use a simple, interactive force-directed layout algorithm. It is based on the idea that nodes connected by an edge are moved towards each other by an attractive force, while an additional repulsive force between all node pairs makes sure that nodes are not drawn on top pf each other. The simulation of those forces, and the computation of a steady-state of the resulting many-particle system is what determines the node positions in the default pathpy visualisation. Also, this is the basis upon which nodes move if you disturb the visualisation by dragging around nodes.
#
# While the default layout algorithm makes it simple to visualise networks, it has the disadvantage that the layout is actually calculated in JavaScript. This means that the positions of nodes are actually not stored in python, which makes it impossible to influence (or store) node positions from python. To solve this issue, `pathpy` provides a `layout` module that can be used to precompute node positions based on different layout algorithms. Moreover, it allows to manually optimise the parameters of those algorithms to generate a nice visualisation.
#
# The styling of node positions via a layout style follows the same idea like the styling of plots via a plot style. We can store the parameters in a dictionary and pass them to the `layout` function using the ** operator. To compute ode positions based on a certain number of iterations of the Fruchterman-Reingold algorithm with a specific force value we can write:

# %%
layout_style = {}
layout_style['layout'] = 'Fruchterman-Reingold'
layout_style['force'] = 0.2
layout_style['iterations'] = 500
layout = pp.layout(n, **layout_style)
print(layout)
# Out:
# {'1204': array([ 0.4693582 , -0.77058493]), '681': array([ 3.4041749 , -1.13022401]), '156': array([-0.76106033, -0.00425883]), '134': array([-3.72670997,  3.2366316 ]), '504': array([ 3.23342307, -0.29993812]), '15': array([-4.09905174,  4.00232029]), '388': array([-3.87411584,  3.32627893]), '20': array([0.4051089 , 0.82621345]), '200': array([-4.13211099,  3.91979594]), '170': array([ 2.27911649, -0.79919783]), '1228': array([ 0.65610736, -0.59547236]), '1342': array([ 0.95045605, -0.82897164]), '1805': array([ 1.490932  , -0.57427516]), '725': array([2.18410502, 0.82309226]), '272': array([ 2.54943533, -0.83938478]), '753': array([-0.61637402, -0.22667473]), '65': array([ 3.14952597, -0.73195387]), '489': array([2.76103648, 0.2841287 ]), '582': array([-0.97337841,  0.98478557]), '232': array([-4.59914813,  3.61768453]), '520': array([-1.52334253,  1.40999551]), '89': array([-4.54168998,  3.70982261]), '87': array([-3.81834033,  3.44425414]), '245': array([0.05323383, 0.20343075]), '601': array([-4.11042614,  3.52306097]), '488': array([-4.42205156,  3.56299498]), '265': array([ 2.42819955, -0.25662439]), '429': array([ 3.30963994, -0.61277085]), '1201': array([ 0.95721633, -0.70433419]), '242': array([-3.97539245,  3.76384466]), '448': array([-3.96385431,  3.64115654]), '285': array([-4.56231876,  3.80803059]), '927': array([2.40698969, 0.92221251]), '145': array([2.90938052, 0.37413624]), '970': array([ 3.46372291, -1.40580096]), '3': array([ 2.60725809, -0.49233605]), '201': array([-0.56888871,  0.6700988 ]), '124': array([ 3.58458292, -1.32135717]), '494': array([ 2.35381906, -0.50436517]), '62': array([3.38507624, 0.63261867]), '255': array([3.5631493 , 1.06978851]), '577': array([-1.02271041, -0.28624018]), '945': array([2.66236968, 0.00326552]), '791': array([-3.89540759,  4.09472891]), '211': array([-4.13098521,  3.70069567]), '165': array([3.48781067, 0.01140955]), '954': array([2.11786085, 0.27154158]), '984': array([ 2.18061505, -0.05286243]), '177': array([ 2.69888306, -0.23877807]), '605': array([-1.31845997,  1.23277442]), '866': array([-0.32812694, -0.02845519]), '151': array([-0.40124088, -0.06499244]), '468': array([-4.29592958,  3.68450244]), '642': array([-0.65183807,  0.63141789]), '694': array([-0.80763177, -0.17173125]), '119': array([2.71082773, 0.71561118]), '498': array([3.28003727, 0.20337971]), '454': array([-1.05139673,  0.31828059]), '771': array([-4.05134322,  4.23344718]), '1423': array([ 0.44908326, -0.4381236 ]), '1594': array([ 0.925657  , -0.47208638]), '210': array([-4.41952898,  3.84781161]), '874': array([-1.41993954,  0.27504598]), '1332': array([0.92241435, 0.03183528]), '1828': array([ 0.8060031 , -0.56639411]), '640': array([-0.81371793,  0.27958385]), '79': array([-4.23235267,  3.21340898]), '845': array([-4.26319269,  3.80584765]), '826': array([-3.98141956,  3.88259138]), '778': array([ 2.10884895, -0.42915624]), '275': array([3.54159244, 0.78497311]), '1412': array([ 0.77585812, -0.44412397]), '48': array([-4.30920721,  3.52008195]), '295': array([ 2.78944823, -0.17724001]), '587': array([ 2.2006269 , -0.46636579]), '576': array([-1.60242144,  1.29474443]), '809': array([ 3.13844955, -0.84291041]), '425': array([2.88889102, 0.56924335]), '122': array([3.09020935, 0.85167313]), '400': array([2.62923031, 0.09316068]), '869': array([0.31353282, 0.29335601]), '650': array([3.20559167, 0.40426332]), '441': array([ 3.17594906, -0.51532449]), '372': array([ 3.04205322, -0.81489915]), '159': array([-0.73682469,  0.33899821]), '496': array([-3.2122278 ,  2.87779801]), '268': array([ 3.17562057, -0.07750602]), '120': array([-4.7068452 ,  3.74136772]), '28': array([ 2.87457452, -0.39340855]), '21': array([-4.00107974,  4.07926087]), '173': array([ 3.39381367, -0.36677224]), '471': array([ 3.27167389, -1.15136366]), '857': array([2.59700203, 0.1961897 ]), '407': array([ 2.9503097 , -0.39867968]), '1260': array([ 0.03777653, -0.54894665]), '1345': array([ 0.870738  , -0.36176948]), '364': ar ...

# %% [markdown]
# This computes a dictionary of node positions, where the node uids are the keys and two-dimensional coordinates are the values. We can now pass this specific layout to the plot function of the network. This will disable the interactive layout in JavaScript, fixing the node positions to the precalculated layout:

# %%
pp.plot(n, **plot_style, layout=layout)
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x5392b2521daa4eb1bc9c367b82b866ca"></div>
# <div id="x0b7fa5703c254538be15bc58c627f049"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 1200.0, "height": 1000.0, "unit": "px", "dpi": 96, "margin": null, "layout": "euclidean", "temporal": false, "coordinates": true, "euclidean": true, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "curved": false, "directed": false, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": true, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "1204", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [787.0371853106143, 413.0647490315812], "id_as_label": true}, {"uid": "681", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [1165.6273886127442, 371.03161889835064], "id_as_label": true}, {"uid": "156", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [653.085563789617, 536.1745726700349], "id_as_label": true}, {"uid": "134", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [138.17333496913488, 604.9574065739666], "id_as_label": true}, {"uid": "504", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [1104.3266987053667, 434.66072013306814], "id_as_label": true}, {"uid": "15", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [34.85097124902086, 589.652609559723], "id_as_label": true}, {"uid": "388", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [118.99852222806703, 613.5313610668733], "id_as_label": true}, {"uid": "20", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [711.3017365219692, 431.81575706227204], "id_as_label": true}, {"uid": "200", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [40.85678424581624, 598.7989365114261], "id_as_label": true}, {"uid": "170", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [998.2507335516773, 377.48910039891825], "id_as_label": true}, {"uid": "1228", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [799.8092332679423, 388.5031864026894], "id_as_label": true}, {"uid": "1342", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [841.006709693303, 387.6015603811353], "id_as_label": true}, {"uid": "1805", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [901.7455316967767, 402.69349674420994], "id_as_label": true}, {"uid": "725", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [973.9942864416118, 568.872380403586], "id_as_label": true}, {"uid": "272", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [1034.8703787455224, 373.88739904211764], "id_as_label": true}, {"uid": "753", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [682.700101992551, 541.3124219246786], "id_as_label": true}, {"uid": "65", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [1129.5868671247208, 413.35862112669474], "id_as_label": true}, {"uid": "489", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [1060.7956272539773, 514.4235514034382], "id_as_label": true}, {"uid": "582", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [561.7559102297416, 506.1117737600231], "id_as_label": true}, {"uid": "232", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [39.67068105877729, 666.1596556722808], "id_as_label": true}, {"uid": "520", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [475.0797146693984, 515.0093507688887], "id_as_label": true}, {"uid": "89", "size": 15.0, "color": "CornflowerBlue", "opacity": 0.2, "coordinates": [34.37943592359329, 654.05097438308

# %% [markdown]
# ## Plotting spatially embedded networks
#
# Layout algorithms are important to visualise networks where nodes are not naturally embedded in a space. However, for a number of complex networks we can naturally assign coordinates to nodes. Examples include infrastructure networks like road, train, or flight networks where we have information on geographic coordinates of road junctions, train stations, or airports. We do not need a layout algorithm to calculate node positions, we can use node coordinates instead, which we can assign to the node attributes:

# %%
n = pp.Network() # why do I get the node properties of the older n?

n.add_node("a")
n.add_node("b")
n.add_node("c")

n.add_edge("a", "b")
n.add_edge("b", "c")

n.nodes['a']['coordinates'] = [0,0]
n.nodes['b']['coordinates'] = [0,1]
n.nodes['c']['coordinates'] = [1,0]
n.plot(**plot_style)
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x6cf0fb5ce70d4ab89cf22ce099e6d37f"></div>
# <div id="xf0cef1f9e4244297bab5ff8523b46c19"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 1200.0, "height": 1000.0, "unit": "px", "dpi": 96, "margin": null, "layout": "euclidean", "temporal": false, "coordinates": true, "euclidean": true, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "curved": true, "directed": true, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": true, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "a", "size": 30.0, "color": "orange", "opacity": 0.2, "coordinates": [119.0, 981.0], "id_as_label": true}, {"uid": "b", "size": 10.0, "color": "blue", "opacity": 0.2, "coordinates": [119.0, 19.0], "id_as_label": true}, {"uid": "c", "size": 20.0, "color": "red", "opacity": 0.2, "coordinates": [1081.0, 981.0], "id_as_label": true}], "links": [{"uid": "0x260a1d01160", "size": 2.0, "color": "black", "opacity": 1, "source": "a", "target": "b", "directed": true, "curved": 0.5}, {"uid": "0x260a1d01910", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "c", "directed": true, "curved": 0.5}]}
#
#  function tooltip(tooltipId, width){
#    // Local variable to hold tooltip div for
#    // manipulation in other functions.
#    var tt = d3.select('body')
#               .append('div')
#               .attr('class', 'tooltip')
#               .attr('id', tooltipId)
#               .style('pointer-events', 'none');
#
#    // Set a width if it is provided.
#    if (width) {
#      tt.style('width', width);
#    }
#
#    // Initially it is hidden.
#    hideTooltip();
#
#    /*
#     * Display tooltip with provided content.
#     * content is expected to be HTML string.
#     * event is d3.event for positioning.
#     */
#    function showTooltip(content, event) {
#      tt.style('opacity', 1.0)
#        .html(content);
#
#      updatePosition(event);
#    }
#
#    /*
#     * Hide the tooltip div.
#     */
#    function hideTooltip() {
#      tt.style('opacity', 0.0);
#    }
#
#    /*
#     * Figure out where to place the tooltip
#     * based on d3 mouse event.
#     */
#    function updatePosition(event) {
#      var xOffset = 20;
#      var yOffset = 10;
#
#      var ttw = tt.style('width');
#      var tth = tt.style('height');
#
#      var wscrY = window.scrollY;
#      var wscrX = window.scrollX;
#
#      var curX = (document.all) ? event.clientX + wscrX : event.pageX;
#      var curY = (document.all) ? event.clientY + wscrY : event.pageY;
#      var ttleft = ((curX - wscrX + xOffset * 2 + ttw) > window.innerWidth) ?
#                   curX - ttw - xOffset * 2 : curX + xOffset;
#
#      if (ttleft < wscrX + xOffset) {
#        ttleft = wscrX + xOffset;
#      }
#
#      var tttop = ((curY - wscrY + yOffset * 2 + tth) > window.innerHeight) ?
#                  curY - tth - yOffset * 2 : curY + yOffset;
#
#      if (tttop < wscrY + yOffset) {
#        tttop = curY + yOffset;
#      }
#
#      tt
#        .style('top', tttop + 'px')
#        .style('left', ttleft + 'px');
#    }
#
#    if (config.widgets.tooltip.enabled === true){
#      return {
#        showTooltip: showTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    } else {
#      return {
#        showTooltip: hideTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    };
#  };
#  /*
#   * network
#   */
#  function network(config){
#
#    // Constants for sizing
#    var width = config.width || 400;
#    var height = config.height || 400;
#    var temporal = config.temporal || false;
#    var tooltipSize = config.widgets.tooltip.size || '100px';
#
#
#    var labelCentered = config.label.centered || false;
#    var labelEnabled = config.label.enabled || false;
#    var labelColor = config.label.color || '#fff';
#
#    var curved = config.curved || false;
#    var directed = config.directed || false;
#
#    var radiusMinSize = conf

# %% [markdown]
# Like for other node attributes, specifying a layout for the network will override the node properties, i.e. in this case the node coordinates will be ignored:

# %%
n.plot(**plot_style, layout=layout)
# Out:
# <style>
# #pp_container {
#   padding: 5px 0 10px 0;
#   margin: auto;
# }
#
# #controls {
#   width: 100%;
#   float: right;
#   margin-bottom: 5px;
# }
#
#
# .control {
#     display:inline-block;
#   padding: 5px 6px 5px 6px;
# }
#
# /* Button  */
# .control button {
#     background-color: #6cc6d9; /* Green */
#     border: none;
#     color: white;
#     padding: 5px 10px;
#     margin: 0px 2px 0px 2px;
#     border-radius: 4px;
#     text-align: center;
#     text-decoration: none;
#     display: inline-block;
#     font-size: 16px;
#     -webkit-transition-duration: 0.4s; /* Safari */
#     transition-duration: 0.4s;
# }
#
# .control button:hover {
#     background-color: #555; /* Gray */
#   color: white;
# }
#
# .control button.active {
#   color: white;
#   background: #555;
# }
#
# .pp_vl {
#   border-left: 3px solid #808080;
#   height: 30px;
# }
#
#
# p.search_title {
#   display: inline;
#   text-align: left;
#   font-weight: normal;
#   color: #777;
# }
#
# #pp_search {
#       padding: 5px 10px;
# }
#
# #pp_search_form #search {
#     margin-left: 0px;
# }
#
#
# .arrow {
#     fill: #555;
#     stroke: #555;
#     stroke-width: 0px;
#     stroke-opacity: .3;
# }
#
# .edge {
#     fill: none;
#     stroke: #555;
#     stroke-width: 1.5px;
#     stroke-opacity: .3;
# }
#
# .nlabel{
#     pointer-events: none;
# }
#
# .node {
#     fill: #99ccff;
#     stroke: #fff;
#     stroke-width: 1.0px;
#     stroke-opacity: 1;
# }
#
# .node_highlight {
#     stroke: #555;
#     stroke-width: 4.0px;        /
# }
#
# .node_search {
#     /* fill: #F38630; Not working yet*/
#     stroke: #555;
#     stroke-width: 4.0px;
# }
#
#
# .edge_active {
#   fill:none;
#   stroke: #555;
#   stroke-width: 2px;
#   stroke-opacity: 1;
# }
#
#
# .edge_highlight {
#   stroke: #555;
#   stroke-width: 4px;
#   stroke-opacity: 1;
# }
#
#
# .tooltip {
#   position: absolute;
#   top: 100px;
#   left: 100px;
#   -moz-border-radius:5px;
#   border-radius: 5px;
#   border: 2px solid #000;
#   background: #fff;
#   opacity: .9;
#   color: black;
#   padding: 10px;
#   width: 300px;
#   font-size: 12px;
#   z-index: 10;
# }
#
# .tooltip p.main {
#   font-size: 15px;
#   text-align: center;
#   padding:0;
#   margin:0;
# }
#
# hr.tooltip-hr {
#   padding:1px 0 0 0;
#   margin:3px 0 3px 0;
# }
#
# #pp_slider_label {
#     font-size: 12px;
# }
#
# .ticks {
#     font-size: 10px;
# }
#
# .track,
# .track-inset,
# .track-overlay {
#     stroke-linecap: round;
# }
#
# .track {
#     stroke: #000;
#     stroke-opacity: 0.3;
#     stroke-width: 10px;
# }
#
# .track-past {
#     stroke: #ffa500;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
# }
#
# .track-future {
#     stroke: #008000;
#     stroke-width: 8px;
#     stroke-opacity: 0.2;
#     stroke-linecap: round;
#
# }
#
# .track-aggregation {
#     stroke: #ff0000;
#     stroke-width: 8px;
#     stroke-opacity: 0.3;
#     stroke-linecap: round;
#
# }
#
# .track-inset {
#     stroke: #dcdcdc;
#     stroke-width: 8px;
# }
#
# .track-overlay {
#     pointer-events: stroke;
#     stroke-width: 50px;
#     stroke: transparent;
#     cursor: crosshair;
# }
#
# .handle {
#     fill: #fff;
#     stroke: #000;
#     stroke-opacity: 0.5;
#     stroke-width: 1.25px;
# }
#
# </style>
# <div id="x24b3fda3a9684826ac661c3ff5dc03a6"></div>
# <div id="x275acbaff18f49e199f61aa20ddc3a82"></div>
# <script charset="utf-8">
#
#  var d3 = require("d3");
#
#  var config = {"width": 1200.0, "height": 1000.0, "unit": "px", "dpi": 96, "margin": null, "layout": "euclidean", "temporal": false, "coordinates": true, "euclidean": true, "min_max_node_size": null, "min_max_edge_size": null, "keep_aspect_ratio": true, "template": null, "css": null, "backend": ["tikz"], "fileformat": ["tex"], "latex_class_options": "", "interactiv": {"backend": ["d3js"], "fileformat": ["html"]}, "animation": {"enabled": false, "begin": null, "end": null, "steps": 20, "speed": 100, "unit": "seconds"}, "label": {"centered": true, "enabled": true, "color": "white"}, "curved": true, "directed": true, "widgets": {"tooltip": {"enabled": false, "size": "100px"}, "save": {"title": "Save", "enabled": true, "tooltip": "Save the network as [svg] or [png]."}, "zoom": {"title": "Zoom", "enabled": true, "tooltip": "Zoom-in with [+] <br> zoom-out with [-] <br> or reset zoom with [Reset]. <br> Furthermore, with [Shift+mouse wheel] you can also zoom."}, "filter": {"title": "Filter", "enabled": false, "tooltip": "Filter the nodes base on given groups.", "groups": ["all"]}, "search": {"title": "Search", "enabled": true, "tooltip": "Search for a node in the network."}, "layout": {"title": "Layout", "enabled": true, "tooltip": "Change the layout of the Network. Per default a [Force] directed layout is used. If x and y coordinates are given, an [Coord] layout can be used."}, "animation": {"title": "Animation", "enabled": true, "tooltip": "Play and pause animation of the temproal network."}, "aggregation": {"title": "Aggregation", "enabled": true, "tooltip": "Aggregate time steps.", "past": 2, "future": 2, "aggregation": 1}}}
#
#  var data = {"nodes": [{"uid": "a", "size": 30.0, "color": "orange", "opacity": 0.2, "coordinates": [119.0, 981.0], "id_as_label": true}, {"uid": "b", "size": 10.0, "color": "blue", "opacity": 0.2, "coordinates": [119.0, 19.0], "id_as_label": true}, {"uid": "c", "size": 20.0, "color": "red", "opacity": 0.2, "coordinates": [1081.0, 981.0], "id_as_label": true}], "links": [{"uid": "0x260a1d018e0", "size": 2.0, "color": "black", "opacity": 1, "source": "a", "target": "b", "directed": true, "curved": 0.5}, {"uid": "0x260a1d01070", "size": 2.0, "color": "black", "opacity": 1, "source": "b", "target": "c", "directed": true, "curved": 0.5}]}
#
#  function tooltip(tooltipId, width){
#    // Local variable to hold tooltip div for
#    // manipulation in other functions.
#    var tt = d3.select('body')
#               .append('div')
#               .attr('class', 'tooltip')
#               .attr('id', tooltipId)
#               .style('pointer-events', 'none');
#
#    // Set a width if it is provided.
#    if (width) {
#      tt.style('width', width);
#    }
#
#    // Initially it is hidden.
#    hideTooltip();
#
#    /*
#     * Display tooltip with provided content.
#     * content is expected to be HTML string.
#     * event is d3.event for positioning.
#     */
#    function showTooltip(content, event) {
#      tt.style('opacity', 1.0)
#        .html(content);
#
#      updatePosition(event);
#    }
#
#    /*
#     * Hide the tooltip div.
#     */
#    function hideTooltip() {
#      tt.style('opacity', 0.0);
#    }
#
#    /*
#     * Figure out where to place the tooltip
#     * based on d3 mouse event.
#     */
#    function updatePosition(event) {
#      var xOffset = 20;
#      var yOffset = 10;
#
#      var ttw = tt.style('width');
#      var tth = tt.style('height');
#
#      var wscrY = window.scrollY;
#      var wscrX = window.scrollX;
#
#      var curX = (document.all) ? event.clientX + wscrX : event.pageX;
#      var curY = (document.all) ? event.clientY + wscrY : event.pageY;
#      var ttleft = ((curX - wscrX + xOffset * 2 + ttw) > window.innerWidth) ?
#                   curX - ttw - xOffset * 2 : curX + xOffset;
#
#      if (ttleft < wscrX + xOffset) {
#        ttleft = wscrX + xOffset;
#      }
#
#      var tttop = ((curY - wscrY + yOffset * 2 + tth) > window.innerHeight) ?
#                  curY - tth - yOffset * 2 : curY + yOffset;
#
#      if (tttop < wscrY + yOffset) {
#        tttop = curY + yOffset;
#      }
#
#      tt
#        .style('top', tttop + 'px')
#        .style('left', ttleft + 'px');
#    }
#
#    if (config.widgets.tooltip.enabled === true){
#      return {
#        showTooltip: showTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    } else {
#      return {
#        showTooltip: hideTooltip,
#        hideTooltip: hideTooltip,
#        updatePosition: updatePosition
#      };
#    };
#  };
#  /*
#   * network
#   */
#  function network(config){
#
#    // Constants for sizing
#    var width = config.width || 400;
#    var height = config.height || 400;
#    var temporal = config.temporal || false;
#    var tooltipSize = config.widgets.tooltip.size || '100px';
#
#
#    var labelCentered = config.label.centered || false;
#    var labelEnabled = config.label.enabled || false;
#    var labelColor = config.label.color || '#fff';
#
#    var curved = config.curved || false;
#    var directed = config.directed || false;
#
#    var radiusMinSize = conf

# %% [markdown]
# ## Plotting networks to PDF
#
# While it is convenient to interactively plot networks in a jupyter network, we often want to generate stand-alone visualisations that we can either share or embed in scientific publications. Apart from the possibility to directly export PNG and SVG visualisations from the interactive HTML widget, the plot function can be used to generate a stand-alone HTML visualisation of the network that can be opened in any browser and shared on the Web.

# %%
n.plot( filename='network.html', **plot_style)

# %% [markdown]
# If you want a vector graphics figure that can be embedded in a scientific paper, you can use the plot function to export network visualisations as PDF:

# %%
layout
# Out:
# {'1204': array([0.47911569, 1.32382104]),
#  '681': array([3.58552021, 1.66871085]),
#  '156': array([-0.6199828 ,  0.31368156]),
#  '134': array([-4.84493542, -0.25069466]),
#  '504': array([3.0825364, 1.146622 ]),
#  '15': array([-5.69271503, -0.12511589]),
#  '388': array([-5.0022684 , -0.32104558]),
#  '20': array([-0.14230804,  1.16996546]),
#  '200': array([-5.64343619, -0.20016324]),
#  '170': array([2.21216297, 1.61572599]),
#  '1228': array([0.58391277, 1.52535332]),
#  '1342': array([0.92194589, 1.53275134]),
#  '1805': array([1.42031946, 1.40891913]),
#  '725': array([2.01313421, 0.04538984]),
#  '272': array([2.51263411, 1.64527864]),
#  '753': array([-0.37698989,  0.27152453]),
#  '65': array([3.28980088, 1.32140976]),
#  '489': array([2.7253557 , 0.49215282]),
#  '582': array([-1.36935995,  0.56035253]),
#  '232': array([-5.6531684 , -0.75287073]),
#  '520': array([-2.08055459,  0.48734622]),
#  '89': array([-5.69658407, -0.6535167 ]),
#  '87': array([-5.06868759, -0.21037582]),
#  '245': array([-0.1512774,  0.9480721]),
#  '601': array([-5.30218042, -0.39870298]),
#  '488': array([-5.5075793 , -0.63530947]),
#  '265': array([2.29300566, 1.06620022]),
#  '429': array([3.1195986 , 1.51382096]),
#  '1201': array([0.89649743, 1.66080334]),
#  '242': array([-5.42276655, -0.15521532]),
#  '448': array([-5.31423452, -0.22017829]),
#  '285': array([-5.79014003, -0.61703387]),
#  '927': array([ 2.23848028, -0.08765432]),
#  '145': array([2.82263673, 0.38020045]),
#  '970': array([3.68200206, 1.91379471]),
#  '3': array([2.52898728, 1.30317143]),
#  '201': array([-0.89181185,  0.72350561]),
#  '124': array([3.77319433, 1.85159329]),
#  '494': array([2.25377164, 1.32095761]),
#  '62': array([3.27977304, 0.14064553]),
#  '255': array([ 3.31875853, -0.34884826]),
#  '577': array([-0.60219548, -0.07185113]),
#  '945': array([2.63274599, 0.76098402]),
#  '791': array([-5.65585374,  0.09483053]),
#  '211': array([-5.45900382, -0.31687013]),
#  '165': array([3.34492377, 0.79649961]),
#  '954': array([1.96922707, 0.61328705]),
#  '984': array([2.13028347, 0.8835834 ]),
#  '177': array([2.72464454, 0.97205855]),
#  '605': array([-1.79841234,  0.50128658]),
#  '866': array([-0.30348435,  0.59352981]),
#  '151': array([-0.30749266,  0.49884571]),
#  '468': array([-5.53769622, -0.46506201]),
#  '642': array([-0.88243558,  0.5496061 ]),
#  '694': array([-0.54290328,  0.16255185]),
#  '119': array([2.49529283, 0.08298652]),
#  '498': array([3.1677    , 0.58205797]),
#  '454': array([-1.04256485,  0.20442835]),
#  '771': array([-5.85997236,  0.04221052]),
#  '1423': array([0.35784002, 1.42032318]),
#  '1594': array([0.83334747, 1.43222949]),
#  '210': array([-5.74347914, -0.47713804]),
#  '874': array([-1.30731923, -0.03440292]),
#  '1332': array([0.81856787, 0.94811251]),
#  '1828': array([0.72775176, 1.53607394]),
#  '640': array([-0.82898157,  0.32207517]),
#  '79': array([-5.11241151, -0.6693935 ]),
#  '845': array([-5.61916729, -0.37171252]),
#  '826': array([-5.52817871, -0.09569058]),
#  '778': array([2.00262586, 1.25370965]),
#  '275': array([ 3.31380137, -0.06051874]),
#  '1412': array([0.69508916, 1.38435739]),
#  '48': array([-5.40919292, -0.56277191]),
#  '295': array([2.59863224, 1.07643004]),
#  '587': array([2.10110009, 1.29057729]),
#  '576': array([-2.07772683,  0.62159154]),
#  '809': array([3.31278387, 1.42328203]),
#  '425': array([2.65924087, 0.21284712]),
#  '122': array([ 2.87217735, -0.09370354]),
#  '400': array([2.60701785, 0.68218889]),
#  '869': array([0.14766474, 0.77702523]),
#  '650': array([3.02811181, 0.36285234]),
#  '441': array([2.99788767, 1.40981789]),
#  '372': array([2.96646076, 1.71481083]),
#  '159': array([-0.80790467,  0.42258851]),
#  '496': array([-4.24863425, -0.05705376]),
#  '268': array([3.03389632, 0.87166763]),
#  '120': array([-5.81683913, -0.77166728]),
#  '28': array([2.76425182, 1.25388498]),
#  '21': array([-5.70153117e+00, -4.99411643e-04]),
#  '173': array([3.12055345, 1.28959849]),
#  '471': array([3.38969935, 1.78045896]),
#  '857': array([2.49535016, 0.61348252]),
#  '407': array([2.8783779 , 1.18321483]),
#  '1260': array([-0.05682013,  1.63703788]),
#  '1345': array([0.78190274, 1.30353384]),
#  '364': array([2.51562862, 0.73025806]),
#  '1359': array([0.12124439, 1.02108739]),
#  '634': array([0.27785898, 0.87442271]),
#  '240': array([2.63847412e+00, 7.99121192e-04]),
#  '428': array([2.50926328, 0.39359198]),
#  '1401': array([0.44877906, 1.16073367]),
#  '147': array([2.52602446, 1.43397714]),
#  '1214': array([1.22163414, 1.52609345]),
#  '478': array([3.10889494, 1.64910876]),
#  '502': array([-0.29519243,  0.72470379]),
#  '106': array([1.88393831, 1.48468461]),
#  '1238': array([-2.31215188,  0.39391681]),
#  '687': array([-2.60078104,  0.31104477]),
#  '101': array([2.55257353, 0.25066054]),
#  '691': array([0.35869309, 0.71949923]),
#  '1237': array([0.20507114, 1.33143856]),
#  '1485': array([0.29738643, 1.75940008]),
#  '1295': array([0.99612  , 1.4265677]),
#  '327': array([2.884586  , 1.50601823]),
#  '525': array([-0.77233761,  0.04157175]),
#  '480': array([-5.80179256,  0.16109435]),
#  '751': array([-5.88431418, -0.27256689]),
#  '45': array([-5.19423673, -0.58041765]),
#  '475': array([3.74167243, 1.99266887])}

# %%
n.plot(**plot_style, layout=layout, filename='network.pdf')
# Out:
# [09-01 18:03:18: ERROR] No latexmk compiler found
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# c:\users\vince\documents\external packages\pathpy\pathpy\visualisations\fileformats\pdf.py in compile(self)
#      99         try:
# --> 100             subprocess.check_output(command, stderr=subprocess.STDOUT)
#     101         except Exception:
#
# c:\users\vince\anaconda3\envs\devenv\lib\subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     410
# --> 411     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     412                **kwargs).stdout
#
# c:\users\vince\anaconda3\envs\devenv\lib\subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     511         if check and retcode:
# --> 512             raise CalledProcessError(retcode, process.args,
#     513                                      output=stdout, stderr=stderr)
#
# CalledProcessError: Command '['latexmk', '--pdf', '-shell-escape', '--interaction=nonstopmode', 'default.tex']' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-1520bb319d3a> in <module>
# ----> 1 n.plot(**plot_style, layout=layout, filename='network.pdf')
#
# c:\users\vince\documents\external packages\pathpy\pathpy\visualisations\plot.py in plot(obj, filename, backend, **kwargs)
#     215
#     216             # save the figure
# --> 217             figure.save(filename)
#     218         else:
#     219             LOG.error('Plotting files in the format "%s" is not supported!',
#
# c:\users\vince\documents\external packages\pathpy\pathpy\visualisations\fileformats\pdf.py in save(self, filename)
#      56     def save(self, filename: str) -> None:
#      57         """Save the file"""
# ---> 58         temp_dir, temp_file = self.compile()
#      59
#      60         # create temp file name
#
# c:\users\vince\documents\external packages\pathpy\pathpy\visualisations\fileformats\pdf.py in compile(self)
#     102             # If compiler does not exist, try next in the list
#     103             LOG.error('No latexmk compiler found')
# --> 104             raise AttributeError
#     105         finally:
#     106             # change back to the current directory
#
# AttributeError:

# %% [markdown]
# An interesting feature of pathpy is that it builds on the package `tikz-network`, a powerful framework to draw graphs in LaTeX. If we want to generate a visualisation in which we retain the full power to style the network in LaTeX, we can export the network as a tex file that can be build with a LaTeX compiler:

# %%
n.plot(**plot_style, layout=layout, filename='network.tex')
